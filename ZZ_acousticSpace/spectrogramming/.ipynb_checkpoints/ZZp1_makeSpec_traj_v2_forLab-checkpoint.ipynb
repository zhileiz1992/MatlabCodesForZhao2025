# %% [markdown]
# ## 0. Goal
# Prepare the MO datasets for shotgun VAE training.
# 1. Make spectrograms for all warble syllables. Using the Pearson method and optimized parameters from call clustering pipeline. <br>
# Differ from v1:
# Increase the silent pad from 50ms to 80ms, to accommendate the longest window size

# %%
import os, sys, importlib, librosa, glob, h5py, tqdm
from scipy.io import wavfile
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from joblib import Parallel, delayed
import random
import umap, hdbscan
from collections import Counter
import seaborn as sns
from torch.utils.data import Dataset, DataLoader
import torch
from matplotlib.colors import ListedColormap

plt.rcParams['pdf.fonttype'] = 42

# %%
# import my utility script
cluster_script_path = '/home/zz367/ProjectsU/EphysMONAO/Jupyter/MatlabCodes/ZZ_callClustering/'
sys.path.insert(1, cluster_script_path)
import vae_goffinet, hopkins
importlib.reload(vae_goffinet)
# Out:
# <module 'vae_goffinet' from '/home/zz367/ProjectsU/EphysMONAO/Jupyter/MatlabCodes/ZZ_callClustering/vae_goffinet.py'>

# %%
# create a custom colormap for spectrogram
jet = plt.get_cmap('jet', 255)
# Extract jet colors and prepend black at the beginning
jet_colors = jet(np.linspace(0, 1, 255))
custom_colors = np.vstack([[0, 0, 0, 1], jet_colors])  # Black for 0, then jet
custom_cmap = ListedColormap(custom_colors)

# %% [markdown]
# ## 1. Inputs

# %%
fd_data = FD_DATA
fd_save = FD_SPEC
bd = BIRD_ID
# color limits when calculating spectrograms, depending on the audio amplitude, may differ between birds
clim = [1.5,7]
# what syllable to analyze, empty means all syllable with annotation, could be a subset syl=['v', 'b']
syl = []

# %%
# define parameters for spectrograms
X_SHAPE = [128, 128]
p = {
    'get_spec': vae_goffinet.get_specZZ, # spectrogram maker
    'max_dur': 1e9, # maximum syllable duration
    'min_freq': 250, # minimum frequency
    'max_freq': 7500, # maximum frequency, default 7500
    'num_freq_bins': X_SHAPE[0], # hard-coded
    'num_time_bins': X_SHAPE[1], # hard-coded
    'nperseg': 256, # FFT
    'noverlap': 236, # FFT, determines window overlap when calculating spectrograms
    'spec_min_val': 1.5, # minimum log-spectrogram value
    'spec_max_val': 7, # maximum log-spectrogram value
    'fs': 20000, # audio samplerate
    'mel': False, # frequency spacing, mel or linear
    'time_stretch': False, # stretch short syllables?
    'within_syll_normalize': False, # normalize spectrogram values on a # spectrogram-by-spectrogram basis
    'pad': 0.08  # when extracting syllables for calculating spectrograms, pad a little before syllable onset and after syllable onset, unit is sec
}

# %% [markdown]
# ## 2. Loop through birds, make spectrograms

# %%
# for bi in range(1, len(birdIDs)):
# for bi in range(1):
# bd = birdIDs[bi]
# print(f'Processing for {bd}...')
# change the color limit
p['spec_min_val'] = clim[0]
p['spec_max_val'] = clim[1]
win_ms = p['nperseg']/p['fs']*1000
hop_ms = (p['nperseg']-p['noverlap'])/p['fs']*1000
print(f'Spectrogram window size (ms): {win_ms:.3f}')
print(f'Spectrogram window hop (ms): {hop_ms:.3f}')
## given the current run a name
run_name = f'spec_goffinet_traj_{p["nperseg"]}_{p["noverlap"]}'
print(run_name)

# save to specific folder
# fd_save = os.path.join(fd_z4, 'zz367', 'EphysMONAO', 'Analyzed', 'vaeWav', bd, 'Traj', 'Spectrogram2')
if not os.path.exists(fd_save):
    os.makedirs(fd_save)
fn_h5 = os.path.join(fd_save, f'{bd}.{run_name}.h5')
fn_info = os.path.join(fd_save, f'{bd}.{run_name}.info.csv')
print(fn_h5)
print(fn_info)

# %%
## grab all wav files
fns_wav = sorted(glob.glob(os.path.join(fd_data, '*.wav')))
fns_label = sorted(glob.glob(os.path.join(fd_data, '*.label.txt')))
print(len(fns_wav))

# %%
## calculate spectrogram
print('Calculating spectrograms...')
with Parallel(n_jobs=48, verbose=5) as parallel:
    res = parallel(delayed(vae_goffinet.ZZ_specFromWavTraj_v1)(fn, p, syl) for fn in fns_wav)

# flatten the result
temp = [aa[0] for aa in res]
specs = [arr for sublist in temp if sublist for arr in sublist]
df_list = [aa[1] for aa in res]
info = pd.concat([df for df in df_list if not df.empty], ignore_index=True)
print(len(specs), info.shape)

# %%
# plot some example spectrograms
nrow = 3
ncol = 8
random.seed(1118)
idx_rd = random.sample(range(len(specs)), nrow*ncol)
fig, axes = plt.subplots(nrow, ncol, figsize=(14, nrow*2.5))
xmax = max([specs[ii].shape[1] for ii in idx_rd])
for ii in range(len(idx_rd)):
    plot_i = ii//ncol
    plot_j = ii%ncol
    ax = axes[plot_i][plot_j]
    ax.imshow(specs[idx_rd[ii]], aspect='auto', cmap=custom_cmap, vmin=0, vmax=1, origin='lower')
    ax.set_title(info.loc[idx_rd[ii], 'label'])
    # set y tick labels
    query_freqs = [1000, 3000, 5000, 7000]
    target_freqs = info.loc[idx_rd[ii], 'spec_f']
    indices = np.arange(len(target_freqs))
    # Interpolate: given a value, find where it lies in the index space
    interp_indices = np.interp(query_freqs, target_freqs, indices)
    ax.set_yticks(interp_indices)
    ax.set_yticklabels(query_freqs)
    # ax.set_xlim(0, xmax)
    ax.axvline(x=p['pad']*1000/hop_ms, color='white', linestyle='--')
plt.tight_layout()
plt.show()
# save figure
fn_fig = os.path.join(fd_save, f'{bd}.{run_name}.pdf')
fig.savefig(fn_fig)

## save results
# save padded spectrograms as h5 file 
with h5py.File(fn_h5, "w") as f:
    for i, spec in enumerate(specs):
        f.create_dataset(f"spec_{i}", data=spec, compression="gzip")

# save meta info as well
print(info.shape)
info.to_csv(fn_info)
# Out:
# Processing for pair4RigACU68...
# Spectrogram window size (ms): 12.800
# Spectrogram window hop (ms): 1.000
# spec_goffinet_traj_256_236
# /mnt/z4/zz367/EphysMONAO/Analyzed/vaeWav/pair4RigACU68/Traj/Spectrogram2/pair4RigACU68.spec_goffinet_traj_256_236.h5
# /mnt/z4/zz367/EphysMONAO/Analyzed/vaeWav/pair4RigACU68/Traj/Spectrogram2/pair4RigACU68.spec_goffinet_traj_256_236.info.csv
# 4100
# Calculating spectrograms...
# [Parallel(n_jobs=48)]: Using backend LokyBackend with 48 concurrent workers.
# [Parallel(n_jobs=48)]: Done  66 tasks      | elapsed:   10.4s
# [Parallel(n_jobs=48)]: Done 192 tasks      | elapsed:   12.5s
# [Parallel(n_jobs=48)]: Done 354 tasks      | elapsed:   15.2s
# [Parallel(n_jobs=48)]: Done 552 tasks      | elapsed:   18.7s
# [Parallel(n_jobs=48)]: Done 786 tasks      | elapsed:   22.8s
# [Parallel(n_jobs=48)]: Done 1056 tasks      | elapsed:   28.2s
# [Parallel(n_jobs=48)]: Done 1362 tasks      | elapsed:   34.0s
# [Parallel(n_jobs=48)]: Done 1704 tasks      | elapsed:   40.6s
# [Parallel(n_jobs=48)]: Done 2082 tasks      | elapsed:   47.3s
# [Parallel(n_jobs=48)]: Done 2496 tasks      | elapsed:   53.8s
# [Parallel(n_jobs=48)]: Done 2946 tasks      | elapsed:  1.0min
# [Parallel(n_jobs=48)]: Done 3432 tasks      | elapsed:  1.2min
# [Parallel(n_jobs=48)]: Done 3954 tasks      | elapsed:  1.4min
# [Parallel(n_jobs=48)]: Done 4100 out of 4100 | elapsed:  1.4min finished
# 149279 (149279, 12)
# (149279, 12)
# Processing for pair4RigBCU53...
# Spectrogram window size (ms): 12.800
# Spectrogram window hop (ms): 1.000
# spec_goffinet_traj_256_236
# /mnt/z4/zz367/EphysMONAO/Analyzed/vaeWav/pair4RigBCU53/Traj/Spectrogram2/pair4RigBCU53.spec_goffinet_traj_256_236.h5
# /mnt/z4/zz367/EphysMONAO/Analyzed/vaeWav/pair4RigBCU53/Traj/Spectrogram2/pair4RigBCU53.spec_goffinet_traj_256_236.info.csv
# 2645
# Calculating spectrograms...
# [Parallel(n_jobs=48)]: Using backend LokyBackend with 48 concurrent workers.
# [Parallel(n_jobs=48)]: Done   1 out of   1 | elapsed:   28.1s finished
# [Parallel(n_jobs=48)]: Done  67 tasks      | elapsed:   37.3s
# [Parallel(n_jobs=48)]: Done 193 tasks      | elapsed:   39.3s
# [Parallel(n_jobs=48)]: Done 355 tasks      | elapsed:   41.8s
# [Parallel(n_jobs=48)]: Done 553 tasks      | elapsed:   44.9s
# [Parallel(n_jobs=48)]: Done 787 tasks      | elapsed:   49.1s
# [Parallel(n_jobs=48)]: Done 1057 tasks      | elapsed:   54.0s
# [Parallel(n_jobs=48)]: Done 1363 tasks      | elapsed:   59.7s
# [Parallel(n_jobs=48)]: Done 1705 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=48)]: Done 2083 tasks      | elapsed:  1.2min
# [Parallel(n_jobs=48)]: Done 2497 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=48)]: Done 2645 out of 2645 | elapsed:  1.3min finished
# 68004 (68004, 12)
# (68004, 12)
# Processing for pair2RigBCU25...
# Spectrogram window size (ms): 12.800
# Spectrogram window hop (ms): 1.000
# spec_goffinet_traj_256_236
# /mnt/z4/zz367/EphysMONAO/Analyzed/vaeWav/pair2RigBCU25/Traj/Spectrogram2/pair2RigBCU25.spec_goffinet_traj_256_236.h5
# /mnt/z4/zz367/EphysMONAO/Analyzed/vaeWav/pair2RigBCU25/Traj/Spectrogram2/pair2RigBCU25.spec_goffinet_traj_256_236.info.csv
# 2600
# Calculating spectrograms...
# [Parallel(n_jobs=48)]: Using backend LokyBackend with 48 concurrent workers.
# /home/zz367/miniconda3/envs/wseg_VAE/lib/python3.10/site-packages/joblib/externals/loky/process_executor.py:752: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# [Parallel(n_jobs=48)]: Done  66 tasks      | elapsed:   47.7s
# [Parallel(n_jobs=48)]: Done 192 tasks      | elapsed:   49.9s
# [Parallel(n_jobs=48)]: Done 354 tasks      | elapsed:   52.2s
# [Parallel(n_jobs=48)]: Done 552 tasks      | elapsed:   54.6s
# [Parallel(n_jobs=48)]: Done 786 tasks      | elapsed:   57.4s
# [Parallel(n_jobs=48)]: Done 1056 tasks      | elapsed:  1.0min
# [Parallel(n_jobs=48)]: Done 1362 tasks      | elapsed:  1.2min
# [Parallel(n_jobs=48)]: Done 1704 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=48)]: Done 2082 tasks      | elapsed:  1.5min
# [Parallel(n_jobs=48)]: Done 2496 tasks      | elapsed:  1.7min
# [Parallel(n_jobs=48)]: Done 2600 out of 2600 | elapsed:  1.7min finished
# 58790 (58790, 12)
# (58790, 12)

# %%
len(specs)
# Out:
# 43

# %%
p['pad']*1000/hop_ms
# Out:
# 80.0

# %%
idx_rd[13]
# Out:
# 35507

# %%
info.iloc[idx_rd[13],:]
# Out:
# fn_wav        /mnt/z4/zz367/EphysMONAO/Analyzed/vaeWav/pair5...
# s_idx                                                        36
# istart                                                   174180
# iend                                                     175080
# label                                                         x
# spec_f        [250.0, 307.0866141732283, 364.1732283464567, ...
# spec_t        [0.0, 0.001, 0.001999999999999999, 0.003, 0.00...
# i_start                                                  172580
# i_end                                                    176680
# zero_start                                                    0
# zero_end                                                      0
# rel_ori                                                    1600
# Name: 35507, dtype: object

# %%
info['fn_wav'][idx_rd[13]]
# Out:
# '/mnt/z4/zz367/EphysMONAO/Analyzed/vaeWav/pair5RigCCU29/Audio/2024-09-06/warble_00039_00020_1_pair5RigCCU29_CU68RigACU53RigBCU29RigC_240906_131512_chan0.wav'
