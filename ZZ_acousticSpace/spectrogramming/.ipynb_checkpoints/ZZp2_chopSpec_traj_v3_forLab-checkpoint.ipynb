# %% [markdown]
# ## 0. Goal
# Prepare the MO datasets for shotgun VAE training: Chop spectrogram of syllables into sliding windows <br>
# Differ from v2: vary the number of windows for each syllable, make it proportional to the syllable duration: num_win = syllable_dur / win_dur, if syllable_dur<win_dur, take one window

# %%
import os, sys, importlib, librosa, glob, h5py, tqdm, pickle
from scipy.io import wavfile
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from joblib import Parallel, delayed
import random
import umap, hdbscan
from collections import Counter
import seaborn as sns
from torch.utils.data import Dataset, DataLoader
import torch
from matplotlib.colors import ListedColormap

plt.rcParams['pdf.fonttype'] = 42

# %%
# import my utility script
cluster_script_path = '/home/zz367/ProjectsU/EphysMONAO/Jupyter/MatlabCodes/ZZ_callClustering/'
sys.path.insert(1, cluster_script_path)
import vae_goffinet, hopkins
importlib.reload(vae_goffinet)
# Out:
# <module 'vae_goffinet' from '/home/zz367/ProjectsU/EphysMONAO/Jupyter/MatlabCodes/ZZ_callClustering/vae_goffinet.py'>

# %%
# create a custom colormap for spectrogram
jet = plt.get_cmap('jet', 255)
# Extract jet colors and prepend black at the beginning
jet_colors = jet(np.linspace(0, 1, 255))
custom_colors = np.vstack([[0, 0, 0, 1], jet_colors])  # Black for 0, then jet
custom_cmap = ListedColormap(custom_colors)

# %% [markdown]
# ## 1. Inputs

# %%
fd_spec = FD_SPEC
bd = BIRD_ID
fd_save = FD_CHOP
# color limits when calculating spectrograms, depending on the audio amplitude, may differ between birds
clim = [1.5,7]
# what syllable to analyze, empty means all syllable with annotation
syl = ['v', 'b', 'h', 'e', 'x']
# what spectroram dataset to use, see ZZp1_makeSpec_traj_v1.ipynb
spec_suffix = 'Spectrogram2'
spec_run = 'spec_goffinet_traj_256_236'

# %%
# define parameters for spectrograms
X_SHAPE = [128, 128]
p = {
    'get_spec': vae_goffinet.get_specZZ, # spectrogram maker
    'max_dur': 1e9, # maximum syllable duration
    'min_freq': 250, # minimum frequency
    'max_freq': 7500, # maximum frequency, default 7500
    'num_freq_bins': X_SHAPE[0], # hard-coded
    'num_time_bins': X_SHAPE[1], # hard-coded
    'nperseg': 256, # FFT
    'noverlap': 236, # FFT, determines window overlap when calculating spectrograms
    'spec_min_val': 1.5, # minimum log-spectrogram value
    'spec_max_val': 7, # maximum log-spectrogram value
    'fs': 20000, # audio samplerate
    'mel': False, # frequency spacing, mel or linear
    'time_stretch': False, # stretch short syllables?
    'within_syll_normalize': False, # normalize spectrogram values on a # spectrogram-by-spectrogram basis
    'pad': 0.08,  # when extracting syllables for calculating spectrograms, pad before syllable onset and after syllable onset, unit is sec
    'win_frame': 32,  # duration of the sliding window, unit is spectrogram column
    'hop_frame': 1, # how much to slide for consecutive window, unit is spectrogram column
    'win_pad': 32, # how much to include before syllable onset, unit is spectrogram column, default to one sliding window
}

# %% [markdown]
# ## 2. Loop through birds, chop spectrograms

# %%
# how many syllables to sample per category
num_syl = 100000
# define a proportion factor: how many windows to sample per sliding window duration of the syllable
win_prop = 1

# %%
# bi = 3 
# # for bi in range(1, len(birdIDs)):
# # for bi in range(1):
# bd = birdIDs[bi]
# print(f'Processing for {bd}...')
# change the color limit
p['spec_min_val'] = clim[0]
p['spec_max_val'] = clim[1]
win_ms = p['nperseg']/p['fs']*1000
hop_ms = (p['nperseg']-p['noverlap'])/p['fs']*1000
print(f'Spectrogram window size (ms): {win_ms:.3f}')
print(f'Spectrogram window hop (ms): {hop_ms:.3f}')
# calculate sliding window duration
slide_win_ms = p['win_frame'] * hop_ms
slide_hop_ms = p['hop_frame'] * hop_ms
slide_pad_ms = p['win_pad'] * hop_ms
print(f'Sliding window {p["win_frame"]} spec columns, slide by {p["hop_frame"]} columns, pad by {p["win_pad"]} columns')
print(f'Sliding window {slide_win_ms} ms, slide by {slide_hop_ms} ms, pad by {slide_pad_ms} ms')
## given the current run a name
run_name = f'traj_chop_{p["win_frame"]}_{p["hop_frame"]}_{p["win_pad"]}'
print(run_name)

# save to specific folder
# fd_save = os.path.join(fd_z4, 'zz367', 'EphysMONAO', 'Analyzed', 'vaeWav', bd, 'Traj', 'Chop3')
if not os.path.exists(fd_save):
    os.makedirs(fd_save)
fn_h5 = os.path.join(fd_save, f'{bd}.{run_name}.chop.h5')
fn_info = os.path.join(fd_save, f'{bd}.{run_name}.chop.info.csv')
print(fn_h5)
print(fn_info)

# %%
# load the calculated spectrogram dataset
# fd_spec = os.path.join(fd_z4, 'zz367', 'EphysMONAO', 'Analyzed', 'vaeWav', bd, 'Traj', spec_suffix)
fn_spec = os.path.join(fd_spec, f'{bd}.{spec_run}.h5')
fn_spec_info = os.path.join(fd_spec, f'{bd}.{spec_run}.info.csv')
info_spec = pd.read_csv(fn_spec_info, delimiter=',', index_col=0)
print(info_spec.shape)
info_spec.head()

# %%
# sample roughly equal number of syllables for each category, record the row index
print(Counter(info_spec['label']))
idx_rd = []
random.seed(1992)
for s in syl:
    idx_syl = list(info_spec[info_spec['label']==s].index)
    # sample 
    sample_num = min([num_syl, len(idx_syl)])
    i_r = random.sample(idx_syl, sample_num)
    print(f'{s}: total {len(idx_syl)} syllables \t sampled {len(i_r)} syllables')
    idx_rd.append(i_r)
# save the sampled index to disk for future use
fn_idx = os.path.join(fd_save, f'{bd}.{run_name}.idx_rd.pkl')
with open(fn_idx, 'wb') as f:
    pickle.dump(idx_rd, f)
print(fn_idx)
# Out:
# Processing for pair2RigBCU25...
# Spectrogram window size (ms): 12.800
# Spectrogram window hop (ms): 1.000
# Sliding window 32 spec columns, slide by 1 columns, pad by 32 columns
# Sliding window 32.0 ms, slide by 1.0 ms, pad by 32.0 ms
# traj_chop_32_1_32
# /mnt/z4/zz367/EphysMONAO/Analyzed/vaeWav/pair2RigBCU25/Traj/Chop3/pair2RigBCU25.traj_chop_32_1_32.chop.h5
# /mnt/z4/zz367/EphysMONAO/Analyzed/vaeWav/pair2RigBCU25/Traj/Chop3/pair2RigBCU25.traj_chop_32_1_32.chop.info.csv
# (58790, 12)
# Counter({'x': 21523, 'v': 16452, 'h': 13331, 'b': 5253, 'e': 2231})
# v: total 16452 syllables 	 sampled 16452 syllables
# b: total 5253 syllables 	 sampled 5253 syllables
# h: total 13331 syllables 	 sampled 13331 syllables
# e: total 2231 syllables 	 sampled 2231 syllables
# x: total 21523 syllables 	 sampled 21523 syllables
# /mnt/z4/zz367/EphysMONAO/Analyzed/vaeWav/pair2RigBCU25/Traj/Chop3/pair2RigBCU25.traj_chop_32_1_32.idx_rd.pkl

# %%
# sample spectrogram windows from each sampled syllable
res_all = []
# loop through syllable categories
# si = 3
for si in range(len(syl)):
    i_r = idx_rd[si]
    ## Sample spectrogram windows
    print(f'Sampling spectrogram windows from {syl[si]}...')
    with Parallel(n_jobs=48, verbose=5) as parallel:
        res = parallel(delayed(vae_goffinet.ZZ_sampleSpecWin_v2)(fn_spec, ri, p, win_prop=1, resize=True) for ri in i_r)
    res_all += res
# Out:
# Sampling spectrogram windows from v...
# [Parallel(n_jobs=48)]: Using backend LokyBackend with 48 concurrent workers.
# [Parallel(n_jobs=48)]: Done  66 tasks      | elapsed:   11.0s
# [Parallel(n_jobs=48)]: Done 192 tasks      | elapsed:   13.3s
# [Parallel(n_jobs=48)]: Done 354 tasks      | elapsed:   15.5s
# [Parallel(n_jobs=48)]: Done 552 tasks      | elapsed:   18.4s
# [Parallel(n_jobs=48)]: Done 786 tasks      | elapsed:   22.1s
# [Parallel(n_jobs=48)]: Done 1056 tasks      | elapsed:   26.6s
# [Parallel(n_jobs=48)]: Done 1362 tasks      | elapsed:   31.3s
# [Parallel(n_jobs=48)]: Done 1704 tasks      | elapsed:   36.5s
# [Parallel(n_jobs=48)]: Done 2082 tasks      | elapsed:   41.6s
# [Parallel(n_jobs=48)]: Done 2496 tasks      | elapsed:   47.7s
# [Parallel(n_jobs=48)]: Done 2946 tasks      | elapsed:   53.9s
# [Parallel(n_jobs=48)]: Done 3432 tasks      | elapsed:  1.0min
# [Parallel(n_jobs=48)]: Done 3954 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=48)]: Done 4512 tasks      | elapsed:  1.2min
# [Parallel(n_jobs=48)]: Done 5106 tasks      | elapsed:  1.4min
# [Parallel(n_jobs=48)]: Done 5736 tasks      | elapsed:  1.5min
# [Parallel(n_jobs=48)]: Done 6402 tasks      | elapsed:  1.6min
# [Parallel(n_jobs=48)]: Done 7104 tasks      | elapsed:  1.7min
# [Parallel(n_jobs=48)]: Done 7842 tasks      | elapsed:  1.8min
# [Parallel(n_jobs=48)]: Done 8616 tasks      | elapsed:  2.0min
# [Parallel(n_jobs=48)]: Done 9426 tasks      | elapsed:  2.1min
# [Parallel(n_jobs=48)]: Done 10272 tasks      | elapsed:  2.2min
# [Parallel(n_jobs=48)]: Done 11154 tasks      | elapsed:  2.3min
# [Parallel(n_jobs=48)]: Done 12072 tasks      | elapsed:  2.4min
# [Parallel(n_jobs=48)]: Done 13026 tasks      | elapsed:  2.5min
# [Parallel(n_jobs=48)]: Done 14016 tasks      | elapsed:  2.6min
# [Parallel(n_jobs=48)]: Done 15042 tasks      | elapsed:  2.7min
# [Parallel(n_jobs=48)]: Done 16104 tasks      | elapsed:  2.8min
# [Parallel(n_jobs=48)]: Done 16452 out of 16452 | elapsed:  2.9min finished
# [Parallel(n_jobs=48)]: Using backend LokyBackend with 48 concurrent workers.
# Sampling spectrogram windows from b...
# [Parallel(n_jobs=48)]: Done  66 tasks      | elapsed:    0.9s
# [Parallel(n_jobs=48)]: Done 288 tasks      | elapsed:    3.1s
# [Parallel(n_jobs=48)]: Done 610 tasks      | elapsed:    6.0s
# [Parallel(n_jobs=48)]: Done 840 tasks      | elapsed:    7.6s
# [Parallel(n_jobs=48)]: Done 1074 tasks      | elapsed:    9.4s
# [Parallel(n_jobs=48)]: Done 1344 tasks      | elapsed:   11.1s
# [Parallel(n_jobs=48)]: Done 1650 tasks      | elapsed:   12.9s
# [Parallel(n_jobs=48)]: Done 1992 tasks      | elapsed:   15.1s
# [Parallel(n_jobs=48)]: Done 2370 tasks      | elapsed:   17.2s
# [Parallel(n_jobs=48)]: Done 2784 tasks      | elapsed:   19.1s
# [Parallel(n_jobs=48)]: Done 3234 tasks      | elapsed:   20.9s
# [Parallel(n_jobs=48)]: Done 3720 tasks      | elapsed:   22.8s
# [Parallel(n_jobs=48)]: Done 4242 tasks      | elapsed:   24.9s
# [Parallel(n_jobs=48)]: Done 4800 tasks      | elapsed:   26.9s
# [Parallel(n_jobs=48)]: Done 5253 out of 5253 | elapsed:   28.4s finished
# [Parallel(n_jobs=48)]: Using backend LokyBackend with 48 concurrent workers.
# [Parallel(n_jobs=48)]: Done  69 tasks      | elapsed:    0.1s
# Sampling spectrogram windows from h...
# [Parallel(n_jobs=48)]: Done 297 tasks      | elapsed:    0.6s
# [Parallel(n_jobs=48)]: Done 936 tasks      | elapsed:    1.6s
# [Parallel(n_jobs=48)]: Done 1728 tasks      | elapsed:    2.6s
# [Parallel(n_jobs=48)]: Done 2664 tasks      | elapsed:    3.6s
# [Parallel(n_jobs=48)]: Done 3744 tasks      | elapsed:    4.4s
# [Parallel(n_jobs=48)]: Done 4968 tasks      | elapsed:    5.7s
# [Parallel(n_jobs=48)]: Done 6336 tasks      | elapsed:    7.2s
# [Parallel(n_jobs=48)]: Done 7848 tasks      | elapsed:    8.4s
# [Parallel(n_jobs=48)]: Done 12219 tasks      | elapsed:   11.5s
# [Parallel(n_jobs=48)]: Done 13029 tasks      | elapsed:   11.9s
# [Parallel(n_jobs=48)]: Done 13236 out of 13331 | elapsed:   12.0s remaining:    0.1s
# [Parallel(n_jobs=48)]: Done 13331 out of 13331 | elapsed:   12.1s finished
# [Parallel(n_jobs=48)]: Using backend LokyBackend with 48 concurrent workers.
# Sampling spectrogram windows from e...
# [Parallel(n_jobs=48)]: Done  66 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=48)]: Done 300 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=48)]: Done 1200 tasks      | elapsed:    1.1s
# [Parallel(n_jobs=48)]: Done 2231 out of 2231 | elapsed:    1.8s finished
# [Parallel(n_jobs=48)]: Using backend LokyBackend with 48 concurrent workers.
# [Parallel(n_jobs=48)]: Done  66 tasks      | elapsed:    0.1s
# Sampling spectrogram windows from x...
# [Parallel(n_jobs=48)]: Done 294 tasks      | elapsed:    0.4s
# [Parallel(n_jobs=48)]: Done 936 tasks      | elapsed:    1.3s
# [Parallel(n_jobs=48)]: Done 1728 tasks      | elapsed:    2.6s
# [Parallel(n_jobs=48)]: Done 2664 tasks      | elapsed:    3.8s
# [Parallel(n_jobs=48)]: Done 3744 tasks      | elapsed:    5.2s
# [Parallel(n_jobs=48)]: Done 4968 tasks      | elapsed:    6.7s
# [Parallel(n_jobs=48)]: Done 6336 tasks      | elapsed:    8.5s
# [Parallel(n_jobs=48)]: Done 7848 tasks      | elapsed:   10.4s
# [Parallel(n_jobs=48)]: Done 9504 tasks      | elapsed:   12.5s
# [Parallel(n_jobs=48)]: Done 11304 tasks      | elapsed:   14.8s
# [Parallel(n_jobs=48)]: Done 13248 tasks      | elapsed:   17.6s
# [Parallel(n_jobs=48)]: Done 15336 tasks      | elapsed:   20.2s
# [Parallel(n_jobs=48)]: Done 17568 tasks      | elapsed:   23.1s
# [Parallel(n_jobs=48)]: Done 19944 tasks      | elapsed:   26.2s
# [Parallel(n_jobs=48)]: Done 21523 out of 21523 | elapsed:   28.2s finished

# %%
# flatten the result
temp = [aa[0] for aa in res_all]
specs = [arr for sublist in temp if sublist for arr in sublist]
df_list = [aa[1] for aa in res_all]
info = pd.concat([df for df in df_list if not df.empty], ignore_index=True)
print(len(specs), info.shape)
# Out:
# 323887 (323887, 4)

# %%
# plot some example spectrograms
nrow = 3
ncol = 10
random.seed(1118)
plot_rd = random.sample(range(len(specs)), nrow*ncol)
fig, axes = plt.subplots(nrow, ncol, figsize=(14, nrow*2.5))
xmax = max([specs[ii].shape[1] for ii in plot_rd])
for ii in range(len(plot_rd)):
    plot_i = ii//ncol
    plot_j = ii%ncol
    ax = axes[plot_i][plot_j]
    ax.imshow(specs[plot_rd[ii]], aspect='auto', cmap=custom_cmap, vmin=0, vmax=1, origin='lower')
plt.tight_layout()
plt.show()
# save figure
fn_fig = os.path.join(fd_save, f'{bd}.{run_name}.pdf')
fig.savefig(fn_fig)

# %%
# save padded spectrograms as h5 file 
spec_win_all = np.stack(specs, axis=0)
print(spec_win_all.shape)
with h5py.File(fn_h5, 'w') as f:
    f.create_dataset('spec_win_all', data=spec_win_all)

# also save the meta info
mapped_spec = info_spec.iloc[info['ri'].values].reset_index(drop=True)
# Combine both dataframes
info_combined = pd.concat([info.reset_index(drop=True), mapped_spec], axis=1)
info_combined.to_csv(fn_info)
# Out:
# (323887, 128, 128)
