# %% [markdown]
# ## 0. Goal
# Vary the inputs to UMAP:
# 1. The number of selected syllable renditions
# 2. The hop length
# 3. Input all sliding windows, or randomly select a subset

# %%
import os, sys, importlib, librosa, glob, h5py, tqdm, pickle
from scipy.io import wavfile
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from joblib import Parallel, delayed
import random
import umap, hdbscan
from collections import Counter, OrderedDict
import seaborn as sns
from torch.utils.data import Dataset, DataLoader, TensorDataset
import torch
from matplotlib.colors import ListedColormap
from matplotlib.patches import Patch
from skimage import transform
import gc
import colorsys
from sklearn.preprocessing import StandardScaler
from sklearn.neighbors import NearestNeighbors

plt.rcParams['pdf.fonttype'] = 42

# %%
# import my utility script
cluster_script_path = '/home/zz367/ProjectsU/EphysMONAO/Jupyter/MatlabCodes/ZZ_callClustering/'
sys.path.insert(1, cluster_script_path)
import vae_goffinet, hopkins
importlib.reload(vae_goffinet)
# Out:
# <module 'vae_goffinet' from '/home/zz367/ProjectsU/EphysMONAO/Jupyter/MatlabCodes/ZZ_callClustering/vae_goffinet.py'>

# %%
# create a custom colormap for spectrogram
jet = plt.get_cmap('jet', 255)
# Extract jet colors and prepend black at the beginning
jet_colors = jet(np.linspace(0, 1, 255))
custom_colors = np.vstack([[0, 0, 0, 1], jet_colors])  # Black for 0, then jet
custom_cmap = ListedColormap(custom_colors)

# %% [markdown]
# ## 1. Inputs

# %%
fd_z4 = '/mnt/z4'
fd_data = os.path.join(fd_z4, 'zz367', 'EphysMONAO', 'Analyzed', 'vaeWav')
birdID = 'pair5RigCCU29'
# color limits when calculating spectrograms, depending on the audio amplitude, may differ between birds
clims = [1.5,7]
# what syllable pairs to analyze
v_all = ['v4', 'v5']
# what spectogram datasets to use
spec_suffix = 'Spectrogram1'
spec_run = 'spec_goffinet_traj_256_236'
# what VAE run to use
vae_suffix = 'VAE1'
vae_run = 'traj_chop_32_2_32'
fd_vae = os.path.join(fd_data, birdID, 'Traj', vae_suffix, vae_run)
# where the VAE latents results are saved
apply_suffix = 'applySyl1'
apply_run = f'latent.{vae_run}'
fd_latent = os.path.join(fd_data, birdID, 'Traj', apply_suffix, apply_run)
print(fd_latent)
# Out:
# /mnt/z4/zz367/EphysMONAO/Analyzed/vaeWav/pair5RigCCU29/Traj/applySyl1/latent.traj_chop_32_2_32

# %%
# where to save results
fd_save = os.path.join(fd_data, birdID, 'Traj', apply_suffix, 'paramSearch2')
if not os.path.exists(fd_save):
    os.makedirs(fd_save)
print(fd_save)
# Out:
# /mnt/z4/zz367/EphysMONAO/Analyzed/vaeWav/pair5RigCCU29/Traj/applySyl1/paramSearch2

# %%
# grab the info on syllales
fn_merged = os.path.join(fd_latent, f'{birdID}.info_merged.csv')
info_syl = pd.read_csv(fn_merged, index_col=0)
# construct a unique syllable id
info_syl['syl_id'] = [f'{info_syl["fn_wav"][ii]}_{info_syl["s_idx"][ii]}' for ii in info_syl.index]
info_syl = info_syl.reset_index()  # reset index for easy merging later

# %%
param_umap = {'n_components':2, 'n_neighbors':25, 'min_dist':0, 'metric':'euclidean'}

# %% [markdown]
# ## 2. Vary the number of syllables to select

# %%
num_list = [30, 100, 300, 1000, 10000]

# %%
# set a threshold to get confident cluster only 
hdbscan_thre = 0.9

# %%
for num_syl in num_list[4:5]:
    # grab the latent data and info for each call subytpe
    fns_latent = sorted(glob.glob(os.path.join(fd_latent, 'latentM.v*.csv')))
    # read in all data
    latent_comb = np.empty((0, 32))
    info_comb = pd.DataFrame()
    for v in v_all:
        fn = sorted(glob.glob(os.path.join(fd_latent, f'latentM.{v}.csv')))[0]
        latent = np.loadtxt(fn, delimiter=',')
        fn_info = os.path.join(os.path.dirname(fn), f'info.{v}.csv')
        info = pd.read_csv(fn_info, index_col=0)

        # merge the syllable info to sliding window info
        merged_info = info.merge(info_syl, left_on='ri', right_on='index', how='left')

        #### sample data as UMAP inputs
        info_pass = merged_info[merged_info['hdbscan_prob']>=hdbscan_thre]
        if info_pass.empty:
            continue
        # get unique syllable id
        syl_uniq = sorted(list(set(info_pass['syl_id'])))
        # same syllables
        num_sample = min([num_syl, len(syl_uniq)])
        print(f'Total syllable {len(set(merged_info["syl_id"]))}. Pass threshold {len(syl_uniq)}. Sampled {num_sample}')
        random.seed(1118)
        syl_rd = random.sample(syl_uniq, num_sample)

        # get the latent data
        iwin = merged_info[merged_info['syl_id'].isin(syl_rd)].index
        info_rd = merged_info.iloc[iwin, :]
        latent_rd = latent[iwin, :]
        print(latent_rd.shape, info_rd.shape)

        latent_comb = np.vstack([latent_comb, latent_rd])
        info_comb = pd.concat([info_comb, info_rd], ignore_index=True)

    # set a run name 
    syl_str = ''.join(v_all)
    run_name = f'{syl_str}.nsyl{num_syl}'
    fd_save_run = os.path.join(fd_save, run_name)
    if not os.path.exists(fd_save_run):
        os.makedirs(fd_save_run)
    print(fd_save_run)

    umap_model, embed = vae_goffinet.ZZ_runUMAP_v1(latent_comb, param_umap, random_state=1118, meta_info=info_comb)

    # save the embedding
    fn_embed = os.path.join(fd_save_run, f'{birdID}.{run_name}.embedding.csv')
    embed.to_csv(fn_embed)

    #### plot results, different color for different call subtypes
    col_full = ['#a65628','#4daf4a','#984ea3','#e41a1c','#ff7f00','#f781bf','#377eb8','#737373']
    col_dict = OrderedDict(zip(v_all, col_full[0:len(v_all)]))
    # get the syl id
    syl_comb = list(set(info_comb['syl_id']))
    fig, ax = plt.subplots(nrows=1, ncols=1, figsize=[5, 5])
    for si in range(len(syl_comb)):
        ss = syl_comb[si]
        embed_s = embed[embed['syl_id']==ss]
        embed_s.index = range(embed_s.shape[0])
        x = np.array(embed_s['umap1'])
        y = np.array(embed_s['umap2'])
        v = embed_s['call_subtype'][0]
        ax.plot(x, y,  marker='o', linestyle='-', color=col_dict[v], markersize=3, linewidth=1, alpha=0.05)
        # mark the start with triangle, and end with square
        ax.plot(x[0], y[0], marker='^', markersize=6, color='blue', alpha=0.25)
        ax.plot(x[-1], y[-1], marker='s', markersize=6, color='red', alpha=0.25)
    # add legend
    legends = [Patch(facecolor=col_dict[name], label=name) for name in col_dict.keys()]
    ax.legend(handles=legends, loc='lower right', fontsize=12)
    ax.set_title(f'{birdID}: {run_name}', fontsize=10)
    ax.set_xlabel('UMAP axis 1', fontsize=12)
    ax.set_ylabel('UMAP axis 2', fontsize=12)
    # # plt.tight_layout()
    # save fig
    fn_fig =os.path.join(fd_save_run, f'{birdID}.{run_name}.embedding.pdf')
    fig.savefig(fn_fig)
# Out:
# Total syllable 2421. Pass threshold 1228. Sampled 1228
# (126857, 32) (126857, 21)
# Total syllable 1519. Pass threshold 1359. Sampled 1359
# (138592, 32) (138592, 21)
# /mnt/z4/zz367/EphysMONAO/Analyzed/vaeWav/pair5RigCCU29/Traj/applySyl1/paramSearch2/v4v5.nsyl10000
# UMAP(min_dist=0, n_jobs=1, n_neighbors=25, random_state=1118, verbose=True)
# Thu Jul 24 17:03:56 2025 Construct fuzzy simplicial set
# Thu Jul 24 17:03:56 2025 Finding Nearest Neighbors
# Thu Jul 24 17:03:56 2025 Building RP forest with 31 trees
# /home/zz367/miniconda3/envs/wseg_VAE/lib/python3.10/site-packages/umap/umap_.py:1945: UserWarning: n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(f"n_jobs value {self.n_jobs} overridden to 1 by setting random_state. Use no seed for parallelism.")
# Thu Jul 24 17:03:59 2025 NN descent for 18 iterations
# 	 1  /  18
# 	 2  /  18
# 	Stopping threshold met -- exiting after 2 iterations
# Thu Jul 24 17:04:11 2025 Finished Nearest Neighbor Search
# Thu Jul 24 17:04:12 2025 Construct embedding
# Epochs completed:   0%|            0/200 [00:00]
# 	completed  0  /  200 epochs
# 	completed  20  /  200 epochs
# 	completed  40  /  200 epochs
# 	completed  60  /  200 epochs
# 	completed  80  /  200 epochs
# 	completed  100  /  200 epochs
# 	completed  120  /  200 epochs
# 	completed  140  /  200 epochs
# 	completed  160  /  200 epochs
# 	completed  180  /  200 epochs
# IOStream.flush timed out
# IOStream.flush timed out
# Thu Jul 24 17:06:25 2025 Finished embedding

# %% [markdown]
# ## 3. Whether to input continuous windows or sample randomly

# %%
num_syl = 10000
# grab the latent data and info for each call subytpe
fns_latent = sorted(glob.glob(os.path.join(fd_latent, 'latentM.v*.csv')))
# read in all data
latent_comb = np.empty((0, 32))
info_comb = pd.DataFrame()
for v in v_all:
    fn = sorted(glob.glob(os.path.join(fd_latent, f'latentM.{v}.csv')))[0]
    latent = np.loadtxt(fn, delimiter=',')
    fn_info = os.path.join(os.path.dirname(fn), f'info.{v}.csv')
    info = pd.read_csv(fn_info, index_col=0)

    # merge the syllable info to sliding window info
    merged_info = info.merge(info_syl, left_on='ri', right_on='index', how='left')

    #### sample data as UMAP inputs
    info_pass = merged_info[merged_info['hdbscan_prob']>=hdbscan_thre]
    if info_pass.empty:
        continue
    # get unique syllable id
    syl_uniq = sorted(list(set(info_pass['syl_id'])))
    # same syllables
    num_sample = min([num_syl, len(syl_uniq)])
    print(f'Total syllable {len(set(merged_info["syl_id"]))}. Pass threshold {len(syl_uniq)}. Sampled {num_sample}')
    random.seed(1118)
    syl_rd = random.sample(syl_uniq, num_sample)

    # get the latent data
    iwin = merged_info[merged_info['syl_id'].isin(syl_rd)].index
    info_rd = merged_info.iloc[iwin, :]
    latent_rd = latent[iwin, :]
    print(latent_rd.shape, info_rd.shape)

    latent_comb = np.vstack([latent_comb, latent_rd])
    info_comb = pd.concat([info_comb, info_rd], ignore_index=True)
# Out:
# Total syllable 2421. Pass threshold 1228. Sampled 1228
# (126857, 32) (126857, 21)
# Total syllable 1519. Pass threshold 1359. Sampled 1359
# (138592, 32) (138592, 21)

# %%
# randomly sample windows
total_win = 60000 # roughly equal to num_syl=300
random.seed(1992)
idx_rd = random.sample(range(latent_comb.shape[0]), total_win)
d = latent_comb[idx_rd,:].copy()
info = info_comb.iloc[idx_rd,:].copy()
print(d.shape, info.shape)
# Out:
# (60000, 32) (60000, 21)

# %%
umap_model, embed = vae_goffinet.ZZ_runUMAP_v1(d, param_umap, random_state=1118, meta_info=info)
# Out:
# /home/zz367/miniconda3/envs/wseg_VAE/lib/python3.10/site-packages/umap/umap_.py:1945: UserWarning: n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(f"n_jobs value {self.n_jobs} overridden to 1 by setting random_state. Use no seed for parallelism.")
# UMAP(min_dist=0, n_jobs=1, n_neighbors=25, random_state=1118, verbose=True)
# Fri Jul 25 10:29:16 2025 Construct fuzzy simplicial set
# Fri Jul 25 10:29:16 2025 Finding Nearest Neighbors
# Fri Jul 25 10:29:16 2025 Building RP forest with 17 trees
# Fri Jul 25 10:29:17 2025 NN descent for 16 iterations
# 	 1  /  16
# 	 2  /  16
# 	 3  /  16
# 	Stopping threshold met -- exiting after 3 iterations
# Fri Jul 25 10:29:19 2025 Finished Nearest Neighbor Search
# Fri Jul 25 10:29:20 2025 Construct embedding
# Epochs completed:   0%|            0/200 [00:00]
# 	completed  0  /  200 epochs
# 	completed  20  /  200 epochs
# 	completed  40  /  200 epochs
# 	completed  60  /  200 epochs
# 	completed  80  /  200 epochs
# 	completed  100  /  200 epochs
# 	completed  120  /  200 epochs
# 	completed  140  /  200 epochs
# 	completed  160  /  200 epochs
# 	completed  180  /  200 epochs
# Fri Jul 25 10:29:45 2025 Finished embedding

# %%
# then use trained umap model to transform the entire data
res = umap_model.transform(latent_comb)
embed = info_comb.copy()
for ii in range(latent_comb.shape[1]):
    embed[f'vae{ii}'] = latent_comb[:,ii]
for jj in range(res.shape[1]):
    embed[f'umap{jj+1}'] = res[:,jj]
# Out:
# Fri Jul 25 11:16:10 2025 Worst tree score: 0.87633333
# Fri Jul 25 11:16:10 2025 Mean tree score: 0.88121275
# Fri Jul 25 11:16:10 2025 Best tree score: 0.88766667
# Fri Jul 25 11:16:11 2025 Forward diversification reduced edges from 1500000 to 436587
# Fri Jul 25 11:16:13 2025 Reverse diversification reduced edges from 436587 to 436587
# Fri Jul 25 11:16:15 2025 Degree pruning reduced edges from 475330 to 475330
# Fri Jul 25 11:16:15 2025 Resorting data and graph based on tree order
# Fri Jul 25 11:16:15 2025 Building and compiling search function
# Epochs completed:   0%|            0/30 [00:00]
# 	completed  0  /  30 epochs
# 	completed  3  /  30 epochs
# 	completed  6  /  30 epochs
# 	completed  9  /  30 epochs
# 	completed  12  /  30 epochs
# 	completed  15  /  30 epochs
# 	completed  18  /  30 epochs
# 	completed  21  /  30 epochs
# 	completed  24  /  30 epochs
# 	completed  27  /  30 epochs

# %%
#### plot results, different color for different call subtypes
col_full = ['#a65628','#4daf4a','#984ea3','#e41a1c','#ff7f00','#f781bf','#377eb8','#737373']
col_dict = OrderedDict(zip(v_all, col_full[0:len(v_all)]))
# get the syl id
syl_comb = list(set(info_comb['syl_id']))
fig, ax = plt.subplots(nrows=1, ncols=1, figsize=[5, 5])
for si in range(len(syl_comb)):
    ss = syl_comb[si]
    embed_s = embed[embed['syl_id']==ss]
    embed_s.index = range(embed_s.shape[0])
    x = np.array(embed_s['umap1'])
    y = np.array(embed_s['umap2'])
    v = embed_s['call_subtype'][0]
    ax.plot(x, y,  marker='o', linestyle='-', color=col_dict[v], markersize=3, linewidth=1, alpha=0.05)
    # mark the start with triangle, and end with square
    ax.plot(x[0], y[0], marker='^', markersize=6, color='blue', alpha=0.25)
    ax.plot(x[-1], y[-1], marker='s', markersize=6, color='red', alpha=0.25)
# add legend
legends = [Patch(facecolor=col_dict[name], label=name) for name in col_dict.keys()]
ax.legend(handles=legends, loc='upper left', fontsize=12)
ax.set_title(f'{birdID}: {run_name}', fontsize=10)
ax.set_xlabel('UMAP axis 1', fontsize=12)
ax.set_ylabel('UMAP axis 2', fontsize=12)
# Out:
# Text(0, 0.5, 'UMAP axis 2')

# %% [markdown]
# ## 4. Use denser sliding: hop=1ms or 4ms

# %%
# where the VAE latents results are saved
apply_suffix = 'applySyl2'
apply_run = f'latent.{vae_run}'
fd_latent = os.path.join(fd_data, birdID, 'Traj', apply_suffix, apply_run)
print(fd_latent)
# Out:
# /mnt/z4/zz367/EphysMONAO/Analyzed/vaeWav/pair5RigCCU29/Traj/applySyl2/latent.traj_chop_32_2_32

# %%
# grab the info on syllales
fn_merged = os.path.join(fd_latent, f'{birdID}.info_merged.csv')
info_syl = pd.read_csv(fn_merged, index_col=0)
# construct a unique syllable id
info_syl['syl_id'] = [f'{info_syl["fn_wav"][ii]}_{info_syl["s_idx"][ii]}' for ii in info_syl.index]
info_syl = info_syl.reset_index()  # reset index for easy merging later

# %%
num_syl = 10000
# grab the latent data and info for each call subytpe
fns_latent = sorted(glob.glob(os.path.join(fd_latent, 'latentM.v*.csv')))
# read in all data
latent_comb = np.empty((0, 32))
info_comb = pd.DataFrame()
for v in v_all:
    fn = sorted(glob.glob(os.path.join(fd_latent, f'latentM.{v}.csv')))[0]
    latent = np.loadtxt(fn, delimiter=',')
    fn_info = os.path.join(os.path.dirname(fn), f'info.{v}.csv')
    info = pd.read_csv(fn_info, index_col=0)

    # merge the syllable info to sliding window info
    merged_info = info.merge(info_syl, left_on='ri', right_on='index', how='left')

    #### sample data as UMAP inputs
    info_pass = merged_info[merged_info['hdbscan_prob']>=hdbscan_thre]
    if info_pass.empty:
        continue
    # get unique syllable id
    syl_uniq = sorted(list(set(info_pass['syl_id'])))
    # same syllables
    num_sample = min([num_syl, len(syl_uniq)])
    print(f'Total syllable {len(set(merged_info["syl_id"]))}. Pass threshold {len(syl_uniq)}. Sampled {num_sample}')
    random.seed(1118)
    syl_rd = random.sample(syl_uniq, num_sample)

    # get the latent data
    iwin = merged_info[merged_info['syl_id'].isin(syl_rd)].index
    info_rd = merged_info.iloc[iwin, :]
    latent_rd = latent[iwin, :]
    print(latent_rd.shape, info_rd.shape)

    latent_comb = np.vstack([latent_comb, latent_rd])
    info_comb = pd.concat([info_comb, info_rd], ignore_index=True)
# Out:
# Total syllable 2421. Pass threshold 1228. Sampled 1228
# (253072, 32) (253072, 21)
# Total syllable 1519. Pass threshold 1359. Sampled 1359
# (276462, 32) (276462, 21)

# %%
print(latent_comb.shape, info_comb.shape)
# Out:
# (529534, 32) (529534, 21)

# %%
umap_model, embed = vae_goffinet.ZZ_runUMAP_v1(latent_comb, param_umap, random_state=1118, meta_info=info_comb)
# Out:
# UMAP(min_dist=0, n_jobs=1, n_neighbors=25, random_state=1118, verbose=True)
# Fri Jul 25 14:56:50 2025 Construct fuzzy simplicial set
# Fri Jul 25 14:56:50 2025 Finding Nearest Neighbors
# Fri Jul 25 14:56:50 2025 Building RP forest with 41 trees
# /home/zz367/miniconda3/envs/wseg_VAE/lib/python3.10/site-packages/umap/umap_.py:1945: UserWarning: n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(f"n_jobs value {self.n_jobs} overridden to 1 by setting random_state. Use no seed for parallelism.")
# Fri Jul 25 14:56:56 2025 NN descent for 19 iterations
# 	 1  /  19
# 	 2  /  19
# 	Stopping threshold met -- exiting after 2 iterations
# Fri Jul 25 14:57:20 2025 Finished Nearest Neighbor Search
# Fri Jul 25 14:57:23 2025 Construct embedding
# Epochs completed:   0%|            0/200 [00:00]
# 	completed  0  /  200 epochs
# 	completed  20  /  200 epochs
# 	completed  40  /  200 epochs
# 	completed  60  /  200 epochs
# 	completed  80  /  200 epochs
# 	completed  100  /  200 epochs
# 	completed  120  /  200 epochs
# 	completed  140  /  200 epochs
# 	completed  160  /  200 epochs
# 	completed  180  /  200 epochs
# Fri Jul 25 15:02:56 2025 Finished embedding

# %%
# save the embedding
fn_embed = os.path.join(fd_save_run, f'{birdID}.{run_name}.hop1ms.embedding.csv')
embed.to_csv(fn_embed)

# %%
print(fn_embed)
# Out:
# /mnt/z4/zz367/EphysMONAO/Analyzed/vaeWav/pair5RigCCU29/Traj/applySyl1/paramSearch2/v4v5.nsyl10000/pair5RigCCU29.v4v5.nsyl10000.hop1ms.embedding.csv

# %%
#### plot results, different color for different call subtypes
col_full = ['#a65628','#4daf4a','#984ea3','#e41a1c','#ff7f00','#f781bf','#377eb8','#737373']
col_dict = OrderedDict(zip(v_all, col_full[0:len(v_all)]))
# get the syl id
syl_comb = list(set(info_comb['syl_id']))
fig, ax = plt.subplots(nrows=1, ncols=1, figsize=[5, 5])
for si in range(len(syl_comb)):
    ss = syl_comb[si]
    embed_s = embed[embed['syl_id']==ss]
    embed_s.index = range(embed_s.shape[0])
    x = np.array(embed_s['umap1'])
    y = np.array(embed_s['umap2'])
    v = embed_s['call_subtype'][0]
    ax.plot(x, y,  marker='o', linestyle='-', color=col_dict[v], markersize=3, linewidth=1, alpha=0.05)
    # mark the start with triangle, and end with square
    ax.plot(x[0], y[0], marker='^', markersize=6, color='blue', alpha=0.25)
    ax.plot(x[-1], y[-1], marker='s', markersize=6, color='red', alpha=0.25)
# add legend
legends = [Patch(facecolor=col_dict[name], label=name) for name in col_dict.keys()]
ax.legend(handles=legends, loc='lower right', fontsize=12)
ax.set_title(f'{birdID}: {run_name}', fontsize=10)
ax.set_xlabel('UMAP axis 1', fontsize=12)
ax.set_ylabel('UMAP axis 2', fontsize=12)
# Out:
# Text(0, 0.5, 'UMAP axis 2')

# %%
## find the index of a specific syllable
syl_to_find = '/mnt/z4/zz367/EphysMONAO/Analyzed/vaeWav/pair5RigCCU29/Audio/2024-09-12/warble_00028_00009_1_pair5RigCCU29_CU68RigACU53RigBCU29RigC_240912_123106_chan0.wav_16'
syl_comb.index(syl_to_find)
# Out:
# 2475
