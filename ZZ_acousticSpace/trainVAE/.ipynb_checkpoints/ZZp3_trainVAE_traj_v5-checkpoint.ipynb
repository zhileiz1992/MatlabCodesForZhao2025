# %% [markdown]
# ## 0. Goal
# Train the VAE on chopped spectrogram dataset. Use the dataset where number of windows is proportional to the syllable duration. <br>
# Vary the sliding window duration: 16, 24, 32, 40, 48, 64, 80ms

# %%
import os, sys, importlib, librosa, glob, h5py, tqdm, pickle, gc
from scipy.io import wavfile
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from joblib import Parallel, delayed
import random
import umap, hdbscan
from collections import Counter
import seaborn as sns
from torch.utils.data import Dataset, DataLoader
import torch
from matplotlib.colors import ListedColormap

plt.rcParams['pdf.fonttype'] = 42

# %%
# import my utility script
cluster_script_path = '/home/zz367/ProjectsU/EphysMONAO/Jupyter/MatlabCodes/ZZ_callClustering/'
sys.path.insert(1, cluster_script_path)
import vae_goffinet, hopkins
importlib.reload(vae_goffinet)
# Out:
# <module 'vae_goffinet' from '/home/zz367/ProjectsU/EphysMONAO/Jupyter/MatlabCodes/ZZ_callClustering/vae_goffinet.py'>

# %%
# create a custom colormap for spectrogram
jet = plt.get_cmap('jet', 255)
# Extract jet colors and prepend black at the beginning
jet_colors = jet(np.linspace(0, 1, 255))
custom_colors = np.vstack([[0, 0, 0, 1], jet_colors])  # Black for 0, then jet
custom_cmap = ListedColormap(custom_colors)

# %% [markdown]
# ## 1. Inputs

# %%
fd_z4 = '/mnt/z4'
fd_data = os.path.join(fd_z4, 'zz367', 'EphysMONAO', 'Analyzed', 'vaeWav')
birdIDs = ['pair5RigCCU29', 'pair4RigACU68', 'pair4RigBCU53', 'pair2RigBCU25']
# color limits when calculating spectrograms, depending on the audio amplitude, may differ between birds
# clims = [[1.5,7], [1.5,7], [1.5,8.5], [1.5,8]]
clims = [[1.5,7], [1.5,7], [1.5,8.5], [1.5,8.5]]
# what syllable to analyze, empty means all syllable with annotation
syl = ['v', 'b', 'h', 'e', 'x']
# what spectroram dataset to use, see ZZp1_makeSpec_traj_v1.ipynb
spec_suffix = 'Spectrogram2'
spec_run = 'spec_goffinet_traj_256_236'
# where to save chopped spec 
chop_suffix = 'Chop5'
# where to save VAE results
vae_suffix = 'VAE5'

# %%
# define parameters for spectrograms
X_SHAPE = [128, 128]
p = {
    'get_spec': vae_goffinet.get_specZZ, # spectrogram maker
    'max_dur': 1e9, # maximum syllable duration
    'min_freq': 250, # minimum frequency
    'max_freq': 7500, # maximum frequency, default 7500
    'num_freq_bins': X_SHAPE[0], # hard-coded
    'num_time_bins': X_SHAPE[1], # hard-coded
    'nperseg': 256, # FFT
    'noverlap': 236, # FFT, determines window overlap when calculating spectrograms
    'spec_min_val': 1.5, # minimum log-spectrogram value
    'spec_max_val': 7, # maximum log-spectrogram value
    'fs': 20000, # audio samplerate
    'mel': False, # frequency spacing, mel or linear
    'time_stretch': False, # stretch short syllables?
    'within_syll_normalize': False, # normalize spectrogram values on a # spectrogram-by-spectrogram basis
    'pad': 0.08,  # when extracting syllables for calculating spectrograms, pad before syllable onset and after syllable onset, unit is sec
    'win_frame': 32,  # duration of the sliding window, unit is spectrogram column
    'hop_frame': 1, # how much to slide for consecutive window, unit is spectrogram column
    'win_pad': 32, # how much to include before syllable onset, unit is spectrogram column, default to one sliding window
}

# %%
# vary sliding window duration
win_list =  [16,   24,  32,  40,  48,  64, 80]
ratio_list = [0.25, 0.5, 0.5, 0.5, 0.5, 1,  1]  # adjust the number of syllables to sample, set a ratio relative to the total number of syllables

# %% [markdown]
# ## 2. Chop spectrograms into windows, then run VAE

# %%
for wi in range(1, len(win_list)):
# for wi in range(1):
    win_frame = win_list[wi]
    # replace parameters 
    p['win_frame'] = win_frame
    p['win_pad'] = win_frame

    # how many syllables to sample per category
    syl_ratio = ratio_list[wi]

    bi = 0 
    # # for bi in range(len(birdIDs)):
    # for bi in range(1):
    bd = birdIDs[bi]
    print(f'Processing for {bd}...')
    # change the color limit
    p['spec_min_val'] = clims[bi][0]
    p['spec_max_val'] = clims[bi][1]
    win_ms = p['nperseg']/p['fs']*1000
    hop_ms = (p['nperseg']-p['noverlap'])/p['fs']*1000
    print(f'Spectrogram window size (ms): {win_ms:.3f}')
    print(f'Spectrogram window hop (ms): {hop_ms:.3f}')
    # calculate sliding window duration
    slide_win_ms = p['win_frame'] * hop_ms
    slide_hop_ms = p['hop_frame'] * hop_ms
    slide_pad_ms = p['win_pad'] * hop_ms
    print(f'Sliding window {p["win_frame"]} spec columns, slide by {p["hop_frame"]} columns, pad by {p["win_pad"]} columns')
    print(f'Sliding window {slide_win_ms} ms, slide by {slide_hop_ms} ms, pad by {slide_pad_ms} ms')
    ## given the current run a name
    run_name = f'traj_chop_{p["win_frame"]}_{p["hop_frame"]}_{p["win_pad"]}'
    print(run_name)

    # save to specific folder
    fd_save = os.path.join(fd_z4, 'zz367', 'EphysMONAO', 'Analyzed', 'vaeWav', bd, 'Traj', chop_suffix)
    if not os.path.exists(fd_save):
        os.makedirs(fd_save)
    fn_h5 = os.path.join(fd_save, f'{bd}.{run_name}.chop.h5')
    fn_info = os.path.join(fd_save, f'{bd}.{run_name}.chop.info.csv')
    print(fn_h5)
    print(fn_info)

    # load the calculated spectrogram dataset
    fd_spec = os.path.join(fd_z4, 'zz367', 'EphysMONAO', 'Analyzed', 'vaeWav', bd, 'Traj', spec_suffix)
    fn_spec = os.path.join(fd_spec, f'{bd}.{spec_run}.h5')
    fn_spec_info = os.path.join(fd_spec, f'{bd}.{spec_run}.info.csv')
    info_spec = pd.read_csv(fn_spec_info, delimiter=',', index_col=0)
    print(info_spec.shape)
    info_spec.head()

    # sample syllables for each category recording to the desired ratio, record the row index
    print(Counter(info_spec['label']))
    idx_rd = []
    random.seed(1992)
    for s in syl:
        idx_syl = list(info_spec[info_spec['label']==s].index)
        # sample 
        # sample_num = min([num_syl, len(idx_syl)])
        sample_num = int(syl_ratio * len(idx_syl))
        i_r = random.sample(idx_syl, sample_num)
        print(f'{s}: total {len(idx_syl)} syllables \t sampled {len(i_r)} syllables')
        idx_rd.append(i_r)
    # save the sampled index to disk for future use
    fn_idx = os.path.join(fd_save, f'{bd}.{run_name}.idx_rd.pkl')
    with open(fn_idx, 'wb') as f:
        pickle.dump(idx_rd, f)
    print(fn_idx)

    # sample spectrogram windows from each sampled syllable
    res_all = []
    # loop through syllable categories
    # si = 3
    for si in range(len(syl)):
        i_r = idx_rd[si]
        ## Sample spectrogram windows
        print(f'Sampling spectrogram windows from {syl[si]}...')
        with Parallel(n_jobs=48, verbose=0) as parallel:
            res = parallel(delayed(vae_goffinet.ZZ_sampleSpecWin_v2)(fn_spec, ri, p, win_prop=1, resize=True) for ri in i_r)
        res_all += res

    # flatten the result
    temp = [aa[0] for aa in res_all]
    specs = [arr for sublist in temp if sublist for arr in sublist]
    df_list = [aa[1] for aa in res_all]
    info = pd.concat([df for df in df_list if not df.empty], ignore_index=True)
    print(len(specs), info.shape)

    # plot some example spectrograms
    nrow = 3
    ncol = 10
    random.seed(1118)
    plot_rd = random.sample(range(len(specs)), nrow*ncol)
    fig, axes = plt.subplots(nrow, ncol, figsize=(14, nrow*2.5))
    xmax = max([specs[ii].shape[1] for ii in plot_rd])
    for ii in range(len(plot_rd)):
        plot_i = ii//ncol
        plot_j = ii%ncol
        ax = axes[plot_i][plot_j]
        ax.imshow(specs[plot_rd[ii]], aspect='auto', cmap=custom_cmap, vmin=0, vmax=1, origin='lower')
    plt.tight_layout()
    plt.show()
    # save figure
    fn_fig = os.path.join(fd_save, f'{bd}.{run_name}.pdf')
    fig.savefig(fn_fig)

    # save padded spectrograms as h5 file 
    spec_win_all = np.stack(specs, axis=0)
    print(spec_win_all.shape)
    with h5py.File(fn_h5, 'w') as f:
        f.create_dataset('spec_win_all', data=spec_win_all)

    # also save the meta info
    mapped_spec = info_spec.iloc[info['ri'].values].reset_index(drop=True)
    # Combine both dataframes
    info_combined = pd.concat([info.reset_index(drop=True), mapped_spec], axis=1)
    info_combined.to_csv(fn_info)
    
    # release RAM
    del info_spec, res, res_all, info, temp, specs, df_list, spec_win_all, mapped_spec, info_combined
    gc.collect()
    
    ## Run VAE
    rn = run_name
    chop_run = run_name
    fd_save = os.path.join(fd_data, bd, 'Traj', vae_suffix, rn)
    if not os.path.exists(fd_save):
        os.makedirs(fd_save)

    print(f'Processing for {bd} {rn}...')
    print(f'Save results to {fd_save}')
    ## load spectrograms and meta info
    fn_spec = os.path.join(fd_data, bd, 'Traj', chop_suffix, f'{bd}.{chop_run}.chop.h5')
    fn_info = os.path.join(fd_data, bd, 'Traj', chop_suffix, f'{bd}.{chop_run}.chop.info.csv')

    info = pd.read_csv(fn_info, index_col=0)

    print(info.shape)


    ## train VAE network
    # create dataloader from h5 file
    train_data = vae_goffinet.SpecDataset(fn_spec)
    # set a random seed
    g = torch.Generator()
    g.manual_seed(42)
    train_dataloader = DataLoader(train_data, batch_size=64, shuffle=True, num_workers=4, generator=g)  # set shuffle to true
    loaders = {'train':train_dataloader, 'test':train_dataloader}

    # init VAE model then train
    model = vae_goffinet.VAE(save_dir=fd_save)
    model.train_loop(loaders, epochs=51, test_freq=None, vis_freq=None, save_freq=10)

    # save model
    fn_model = os.path.join(fd_save, f'{bd}_checkpoint_final.tar')
    model.save_state(fn_model)

    ## Obtain latent representation
    train_dataloader = DataLoader(train_data, batch_size=64, shuffle=False, num_workers=4)  # set shuffle to false to match the order in id_pd

    # loop through dataloader, obtain model latent space
    latent_m = np.zeros((info.shape[0], 32))
    latent_d = np.zeros((info.shape[0], 32))
    recon = np.zeros((info.shape[0], X_SHAPE[0], X_SHAPE[1]))
    model.eval()
    count = 0
    for i, data in tqdm.tqdm(enumerate(train_dataloader)):
        data = data.to('cuda:0')
        with torch.no_grad():
            _, _, rec, mu, d = model.forwardZZ(data, return_latent_rec=True)
            a = rec.shape[0]
            latent_m[count:(count+a),:] = mu
            latent_d[count:(count+a),:] = d
            recon[count:(count+a),:,:] = rec
            count += a

    # save the latent representations
    fn_latentM = os.path.join(fd_save, 'latentM.csv')
    np.savetxt(fn_latentM, latent_m, delimiter=',')
    fn_latentD = os.path.join(fd_save, 'latentD.csv')
    np.savetxt(fn_latentD, latent_d, delimiter=',')
    print(latent_m.shape)

    ## check recontruction accuracy (optional)
    # plot some random samples
    fig, ax = plt.subplots(2, 10, figsize=[12,4])
    random.seed(1118)
    random_i = random.sample(list(range(recon.shape[0])), 10)
    with h5py.File(fn_spec, 'r') as file:
        for ii in range(10):
            spec = train_data[random_i[ii],:,:].numpy()
            ax[0][ii].imshow(np.flip(spec, 0), aspect='auto', vmin=0, vmax=1, cmap=custom_cmap)
            spec = recon[random_i[ii],:,:]
            ax[1][ii].imshow(np.flip(spec, 0), aspect='auto', vmin=0, vmax=1, cmap=custom_cmap)
            if ii>0:
                ax[0][ii].axis('off')
                ax[1][ii].axis('off')
    plt.tight_layout()
    # save fig
    fn_fig = os.path.join(fd_save, 'reconstructed_spectrogram.pdf')
    fig.savefig(fn_fig)

    # release RAM
    del latent_m, latent_d, recon, spec, info
    gc.collect()
# Out:
# Processing for pair5RigCCU29...
# Spectrogram window size (ms): 12.800
# Spectrogram window hop (ms): 1.000
# Sliding window 24 spec columns, slide by 1 columns, pad by 24 columns
# Sliding window 24.0 ms, slide by 1.0 ms, pad by 24.0 ms
# traj_chop_24_1_24
# /mnt/z4/zz367/EphysMONAO/Analyzed/vaeWav/pair5RigCCU29/Traj/Chop5/pair5RigCCU29.traj_chop_24_1_24.chop.h5
# /mnt/z4/zz367/EphysMONAO/Analyzed/vaeWav/pair5RigCCU29/Traj/Chop5/pair5RigCCU29.traj_chop_24_1_24.chop.info.csv
# (84254, 12)
# Counter({'h': 27190, 'x': 24431, 'v': 23240, 'b': 5461, 'e': 3932})
# v: total 23240 syllables 	 sampled 11620 syllables
# b: total 5461 syllables 	 sampled 2730 syllables
# h: total 27190 syllables 	 sampled 13595 syllables
# e: total 3932 syllables 	 sampled 1966 syllables
# x: total 24431 syllables 	 sampled 12215 syllables
# /mnt/z4/zz367/EphysMONAO/Analyzed/vaeWav/pair5RigCCU29/Traj
# Epoch: 42 Average loss: 251.2311
# Epoch: 43 Average loss: 250.0557
# Epoch: 44 Average loss: 249.0394
# Epoch: 45 Average loss: 247.1394
# Epoch: 46 Average loss: 245.9018
# Epoch: 47 Average loss: 245.2568
# Epoch: 48 Average loss: 244.1243
# Epoch: 49 Average loss: 242.4583
# Epoch: 50 Average loss: 241.1792
# 2139it [02:34, 13.81it/s]
# (136839, 32)
# Processing for pair5RigCCU29...
# Spectrogram window size (ms): 12.800
# Spectrogram window hop (ms): 1.000
# Sliding window 48 spec columns, slide by 1 columns, pad by 48 columns
# Sliding window 48.0 ms, slide by 1.0 ms, pad by 48.0 ms
# traj_chop_48_1_48
# /mnt/z4/zz367/EphysMONAO/Analyzed/vaeWav/pair5RigCCU29/Traj/Chop5/pair5RigCCU29.traj_chop_48_1_48.chop.h5
# /mnt/z4/zz367/EphysMONAO/Analyzed/vaeWav/pair5RigCCU29/Traj/Chop5/pair5RigCCU29.traj_chop_48_1_48.chop.info.csv
# (84254, 12)
# Counter({'h': 27190, 'x': 24431, 'v': 23240, 'b': 5461, 'e': 3932})
# v: total 23240 syllables 	 sampled 11620 syllables
# b: total 5461 syllables 	 sampled 2730 syllables
# h: total 27190 syllables 	 sampled 13595 syllables
# e: total 3932 syllables 	 sampled 1966 syllables
# x: total 24431 syllables 	 sampled 12215 syllables
# /mnt/z4/zz367/EphysMONAO/Analyzed/vaeWav/pair5RigCCU29/Traj/Chop5/pair5RigCCU29.traj_chop_48_1_48.idx_rd.pkl
# Sampling spectrogram windows from v...
# Sampling spectrogram windows from b...
# Sampling spectrogram windows from h...
# Sampling spectrogram windows from e...
# Sampling spectrogram windows from x...
# 114569 (114569, 4)
# (114569, 128, 128)
# Processing for pair5RigCCU29 traj_chop_48_1_48...
# Save results to /mnt/z4/zz367/EphysMONAO/Analyzed/vaeWav/pair5RigCCU29/Traj/VAE5/traj_chop_48_1_48
# (114569, 16)
# ========================================
# Training: epochs 0 to 50
# Training set: 114569
# Test set: 114569
# ========================================
# /home/zz367/miniconda3/envs/wseg_VAE/lib/python3.10/site-packages/torch/nn/modules/conv.py:952: UserWarning: Plan failed with a cudnnException: CUDNN_BACKEND_EXECUTION_PLAN_DESCRIPTOR: cudnnFinalize Descriptor Failed cudnn_status: CUDNN_STATUS_NOT_SUPPORTED (Triggered internally at ../aten/src/ATen/native/cudnn/Conv_v8.cpp:919.)
#   return F.conv_transpose2d(
# /home/zz367/miniconda3/envs/wseg_VAE/lib/python3.10/site-packages/torch/autograd/graph.py:744: UserWarning: Plan failed with a cudnnException: CUDNN_BACKEND_EXECUTION_PLAN_DESCRIPTOR: cudnnFinalize Descriptor Failed cudnn_status: CUDNN_STATUS_NOT_SUPPORTED (Triggered internally at ../aten/src/ATen/native/cudnn/Conv_v8.cpp:919.)
#   return Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
# Epoch: 0 Average loss: 1795.1043
# Epoch: 1 Average loss: 505.9225
# Epoch: 2 Average loss: 431.7673
# Epoch: 3 Average loss: 403.8085
# Epoch: 4 Average loss: 380.8479
# Epoch: 5 Average loss: 361.6938
# Epoch: 6 Average loss: 350.2914
# Epoch: 7 Average loss: 341.5998
# Epoch: 8 Average loss: 332.5585
# Epoch: 9 Average loss: 328.1416
# Epoch: 10 Average loss: 321.5440
# Epoch: 11 Average loss: 316.0519
# Epoch: 12 Average loss: 311.9371
# Epoch: 13 Average loss: 308.2177
# Epoch: 14 Average loss: 303.6143
# Epoch: 15 Average loss: 300.2873
# Epoch: 16 Average loss: 296.0166
# Epoch: 17 Average loss: 294.2453
# Epoch: 18 Average loss: 290.0560
# Epoch: 19 Average loss: 288.1067
# Epoch: 20 Average loss: 284.6728
# Epoch: 21 Average loss: 281.9535
# Epoch: 22 Average loss: 280.0635
# Epoch: 23 Average loss: 277.0815
# Epoch: 24 Average loss: 275.5407
# Epoch: 25 Average loss: 273.1099
# Epoch: 26 Average loss: 271.2318
# Epoch: 27 Average loss: 270.3364
# Epoch: 28 Average loss: 266.8440
# Epoch: 29 Average loss: 263.9941
# Epoch: 30 Average loss: 262.9442
# Epoch: 31 Average loss: 260.7726
# Epoch: 32 Average loss: 259.9011
# Epoch: 33 Average loss: 257.2951
# Epoch: 34 Average loss: 255.8052
# Epoch: 35 Average loss: 255.3567
# Epoch: 36 Average loss: 253.1725
# Epoch: 37 Average loss: 252.3607
# Epoch: 38 Average loss: 250.2249
# Epoch: 39 Average loss: 248.4676
# Epoch: 40 Average loss: 246.8016
# Epoch: 41 Average loss: 245.4746
# Epoch: 42 Average loss: 244.7345
# Epoch: 43 Average loss: 243.3807
# Epoch: 44 Average loss: 242.2215
# Epoch: 45 Average loss: 240.9697
# Epoch: 46 Average loss: 239.1055
# Epoch: 47 Average loss: 238.3447
# Epoch: 48 Average loss: 237.4955
# Epoch: 49 Average loss: 237.7264
# Epoch: 50 Average loss: 234.6783
# 1791it [02:09, 13.80it/s]
# (114569, 32)
# Processing for pair5RigCCU29...
# Spectrogram window size (ms): 12.800
# Spectrogram window hop (ms): 1.000
# Sliding window 64 spec columns, slide by 1 columns, pad by 64 columns
# Sliding window 64.0 ms, slide by 1.0 ms, pad by 64.0 ms
# traj_chop_64_1_64
# /mnt/z4/zz367/EphysMONAO/Analyzed/vaeWav/pair5RigCCU29/Traj/Chop5/pair5RigCCU29.traj_chop_64_1_64.chop.h5
# /mnt/z4/zz367/EphysMONAO/Analyzed/vaeWav/pair5RigCCU29/Traj/Chop5/pair5RigCCU29.traj_chop_64_1_64.chop.info.csv
# (84254, 12)
# Counter({'h': 27190, 'x': 24431, 'v': 23240, 'b': 5461, 'e': 3932})
# v: total 23240 syllables 	 sampled 23240 syllables
# b: total 5461 syllables 	 sampled 5461 syllables
# h: total 27190 syllables 	 sampled 27190 syllables
# e: total 3932 syllables 	 sampled 3932 syllables
# x: total 24431 syllables 	 sampled 24431 syllables
# /mnt/z4/zz367/EphysMONAO/Analyzed/vaeWav/pair5RigCCU29/Traj/Chop5/pair5RigCCU29.traj_chop_64_1_64.idx_rd.pkl
# Sampling spectrogram windows from v...
# Sampling spectrogram windows from b...
# Sampling spectrogram windows from h...
# Sampling spectrogram windows from e...
# Sampling spectrogram windows from x...
# 173669 (173669, 4)
# (173669, 128, 128)
# Processing for pair5RigCCU29 traj_chop_64_1_64...
# Save results to /mnt/z4/zz367/EphysMONAO/Analyzed/vaeWav/pair5RigCCU29/Traj/VAE5/traj_chop_64_1_64
# (173669, 16)
# ========================================
# Training: epochs 0 to 50
# Training set: 173669
# Test set: 173669
# ========================================
# /home/zz367/miniconda3/envs/wseg_VAE/lib/python3.10/site-packages/torch/nn/modules/conv.py:952: UserWarning: Plan failed with a cudnnException: CUDNN_BACKEND_EXECUTION_PLAN_DESCRIPTOR: cudnnFinalize Descriptor Failed cudnn_status: CUDNN_STATUS_NOT_SUPPORTED (Triggered internally at ../aten/src/ATen/native/cudnn/Conv_v8.cpp:919.)
#   return F.conv_transpose2d(
# /home/zz367/miniconda3/envs/wseg_VAE/lib/python3.10/site-packages/torch/autograd/graph.py:744: UserWarning: Plan failed with a cudnnException: CUDNN_BACKEND_EXECUTION_PLAN_DESCRIPTOR: cudnnFinalize Descriptor Failed cudnn_status: CUDNN_STATUS_NOT_SUPPORTED (Triggered internally at ../aten/src/ATen/native/cudnn/Conv_v8.cpp:919.)
#   return Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
# Epoch: 0 Average loss: 1913.0542
# Epoch: 1 Average loss: 465.6547
# Epoch: 2 Average loss: 404.8739
# Epoch: 3 Average loss: 372.0555
# Epoch: 4 Average loss: 353.7310
# Epoch: 5 Average loss: 340.6115
# Epoch: 6 Average loss: 331.4956
# Epoch: 7 Average loss: 323.9822
# Epoch: 8 Average loss: 316.8234
# Epoch: 9 Average loss: 311.6580
# Epoch: 10 Average loss: 306.2040
# Epoch: 11 Average loss: 303.2601
# Epoch: 12 Average loss: 298.6158
# Epoch: 13 Average loss: 295.2896
# Epoch: 14 Average loss: 292.3880
# Epoch: 15 Average loss: 289.3414
# Epoch: 16 Average loss: 286.1567
# Epoch: 17 Average loss: 284.2996
# Epoch: 18 Average loss: 282.6352
# Epoch: 19 Average loss: 279.5908
# Epoch: 20 Average loss: 278.0908
# Epoch: 21 Average loss: 275.7885
# Epoch: 22 Average loss: 274.2798
# Epoch: 23 Average loss: 272.3995
# Epoch: 24 Average loss: 270.9177
# Epoch: 25 Average loss: 268.7725
# Epoch: 26 Average loss: 268.1802
# Epoch: 27 Average loss: 265.1734
# Epoch: 28 Average loss: 264.7733
# Epoch: 29 Average loss: 263.0084
# Epoch: 30 Average loss: 261.8368
# Epoch: 31 Average loss: 260.3942
# Epoch: 32 Average loss: 258.9011
# Epoch: 33 Average loss: 258.1415
# Epoch: 34 Average loss: 257.1418
# Epoch: 35 Average loss: 256.5744
# Epoch: 36 Average loss: 254.5932
# Epoch: 37 Average loss: 253.8015
# Epoch: 38 Average loss: 252.6640
# Epoch: 39 Average loss: 251.3594
# Epoch: 40 Average loss: 251.1080
# Epoch: 41 Average loss: 249.9866
# Epoch: 42 Average loss: 249.3520
# Epoch: 43 Average loss: 248.3974
# Epoch: 44 Average loss: 248.0638
# Epoch: 45 Average loss: 246.8613
# Epoch: 46 Average loss: 246.0676
# Epoch: 47 Average loss: 245.2034
# Epoch: 48 Average loss: 244.7379
# Epoch: 49 Average loss: 243.6778
# Epoch: 50 Average loss: 240.9304
# 2714it [03:16, 13.83it/s]
# (173669, 32)
# Processing for pair5RigCCU29...
# Spectrogram window size (ms): 12.800
# Spectrogram window hop (ms): 1.000
# Sliding window 80 spec columns, slide by 1 columns, pad by 80 columns
# Sliding window 80.0 ms, slide by 1.0 ms, pad by 80.0 ms
# traj_chop_80_1_80
# /mnt/z4/zz367/EphysMONAO/Analyzed/vaeWav/pair5RigCCU29/Traj/Chop5/pair5RigCCU29.traj_chop_80_1_80.chop.h5
# /mnt/z4/zz367/EphysMONAO/Analyzed/vaeWav/pair5RigCCU29/Traj/Chop5/pair5RigCCU29.traj_chop_80_1_80.chop.info.csv
# (84254, 12)
# Counter({'h': 27190, 'x': 24431, 'v': 23240, 'b': 5461, 'e': 3932})
# v: total 23240 syllables 	 sampled 23240 syllables
# b: total 5461 syllables 	 sampled 5461 syllables
# h: total 27190 syllables 	 sampled 27190 syllables
# e: total 3932 syllables 	 sampled 3932 syllables
# x: total 24431 syllables 	 sampled 24431 syllables
# /mnt/z4/zz367/EphysMONAO/Analyzed/vaeWav/pair5RigCCU29/Traj/Chop5/pair5RigCCU29.traj_chop_80_1_80.idx_rd.pkl
# Sampling spectrogram windows from v...
# Sampling spectrogram windows from b...
# Sampling spectrogram windows from h...
# Sampling spectrogram windows from e...
# Sampling spectrogram windows from x...
# 145008 (145008, 4)
# (145008, 128, 128)
# Processing for pair5RigCCU29 traj_chop_80_1_80...
# Save results to /mnt/z4/zz367/EphysMONAO/Analyzed/vaeWav/pair5RigCCU29/Traj/VAE5/traj_chop_80_1_80
# (145008, 16)
# ========================================
# Training: epochs 0 to 50
# Training set: 145008
# Test set: 145008
# ========================================
# /home/zz367/miniconda3/envs/wseg_VAE/lib/python3.10/site-packages/torch/nn/modules/conv.py:952: UserWarning: Plan failed with a cudnnException: CUDNN_BACKEND_EXECUTION_PLAN_DESCRIPTOR: cudnnFinalize Descriptor Failed cudnn_status: CUDNN_STATUS_NOT_SUPPORTED (Triggered internally at ../aten/src/ATen/native/cudnn/Conv_v8.cpp:919.)
#   return F.conv_transpose2d(
# /home/zz367/miniconda3/envs/wseg_VAE/lib/python3.10/site-packages/torch/autograd/graph.py:744: UserWarning: Plan failed with a cudnnException: CUDNN_BACKEND_EXECUTION_PLAN_DESCRIPTOR: cudnnFinalize Descriptor Failed cudnn_status: CUDNN_STATUS_NOT_SUPPORTED (Triggered internally at ../aten/src/ATen/native/cudnn/Conv_v8.cpp:919.)
#   return Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
# Epoch: 0 Average loss: 1896.4764
# Epoch: 1 Average loss: 551.9656
# Epoch: 2 Average loss: 451.9909
# Epoch: 3 Average loss: 414.5516
# Epoch: 4 Average loss: 392.8613
# Epoch: 5 Average loss: 373.7782
# Epoch: 6 Average loss: 362.0107
# Epoch: 7 Average loss: 353.2035
# Epoch: 8 Average loss: 346.5473
# Epoch: 9 Average loss: 338.4465
# Epoch: 10 Average loss: 333.8950
# Epoch: 11 Average loss: 329.6492
# Epoch: 12 Average loss: 325.1451
# Epoch: 13 Average loss: 320.8574
# Epoch: 14 Average loss: 317.2529
# Epoch: 15 Average loss: 313.8601
# Epoch: 16 Average loss: 311.3376
# Epoch: 17 Average loss: 307.2955
# Epoch: 18 Average loss: 305.7921
# Epoch: 19 Average loss: 302.8406
# Epoch: 20 Average loss: 300.4952
# Epoch: 21 Average loss: 297.6135
# Epoch: 22 Average loss: 295.2876
# Epoch: 23 Average loss: 293.4206
# Epoch: 24 Average loss: 291.5241
# Epoch: 25 Average loss: 289.3333
# Epoch: 26 Average loss: 287.1909
# Epoch: 27 Average loss: 285.6455
# Epoch: 28 Average loss: 283.6995
# Epoch: 29 Average loss: 282.5438
# Epoch: 30 Average loss: 279.8740
# Epoch: 31 Average loss: 279.2273
# Epoch: 32 Average loss: 277.3285
# Epoch: 33 Average loss: 276.0581
# Epoch: 34 Average loss: 274.3242
# Epoch: 35 Average loss: 272.9801
# Epoch: 36 Average loss: 271.4412
# Epoch: 37 Average loss: 269.9457
# Epoch: 38 Average loss: 269.5216
# Epoch: 39 Average loss: 267.3969
# Epoch: 40 Average loss: 266.4875
# Epoch: 41 Average loss: 264.6320
# Epoch: 42 Average loss: 263.6173
# Epoch: 43 Average loss: 263.9268
# Epoch: 44 Average loss: 262.3067
# Epoch: 45 Average loss: 261.3853
# Epoch: 46 Average loss: 260.0222
# Epoch: 47 Average loss: 259.0952
# Epoch: 48 Average loss: 257.9468
# Epoch: 49 Average loss: 256.7757
# Epoch: 50 Average loss: 255.3205
# 2266it [02:44, 13.79it/s]
# (145008, 32)

# %% [markdown]
# #### Check RAM usage

# %%
import pandas as pd
from pympler import asizeof

var_info = []
for name, val in list(globals().items()):  # Make list copy
    try:
        size = asizeof.asizeof(val)
        var_info.append((name, size))
    except:
        continue

df = pd.DataFrame(var_info, columns=["Variable", "Size (Bytes)"])
df["Size (MB)"] = df["Size (Bytes)"] / 1024**2
df.sort_values(by="Size (Bytes)", ascending=False, inplace=True)
print(df)
# Out:
# /home/zz367/miniconda3/envs/wseg_VAE/lib/python3.10/site-packages/pympler/asizeof.py:651: UserWarning: Iterating '<class 'traitlets.config.loader.Config'>': TypeError("'LazyConfigValue' object is not iterable")
#   warnings.warn("Iterating '%s': %r" % (_classof(obj), x))
# /home/zz367/miniconda3/envs/wseg_VAE/lib/python3.10/site-packages/pympler/asizeof.py:651: UserWarning: Iterating '<class 'traitlets.config.loader.Config'>': TypeError("'LazyConfigValue' object is not iterable")
#   warnings.warn("Iterating '%s': %r" % (_classof(obj), x))
#            Variable  Size (Bytes)     Size (MB)
# 127            spec   23324918032  22244.375259
# 109            info    1737379848   1656.894539
# 119             rec       2228536      2.125298
# 90          idx_syl        977296      0.932022
# 88           idx_rd        842880      0.803833
# ..              ...           ...           ...
# 13             open             0      0.000000
# 43   ListedColormap             0      0.000000
# 34          delayed             0      0.000000
# 41       DataLoader             0      0.000000
# 38          Counter             0      0.000000
#
# [138 rows x 3 columns]
