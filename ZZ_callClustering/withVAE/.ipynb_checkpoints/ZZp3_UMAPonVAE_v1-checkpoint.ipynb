# %% [markdown]
# ## 0. Goal
# Run VAE first to reduce spectrogram dimensions from 128*128 to 32 latent features. Then run UMAP and HDBSCAN. <br>
# Use Goffinet spectrogramming and VAE network.

# %%
import os, sys, importlib, librosa, glob, h5py, tqdm
from scipy.io import wavfile
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from joblib import Parallel, delayed
import random
import umap, hdbscan
from collections import Counter
import seaborn as sns
from matplotlib.colors import ListedColormap
from sklearn.metrics import silhouette_score
from torch.utils.data import Dataset, DataLoader
import torch
from sklearn.metrics import calinski_harabasz_score

plt.rcParams['pdf.fonttype'] = 42

# %%
# import my utility script
cluster_script_path = '/home/zz367/ProjectsU/EphysMONAO/Jupyter/MatlabCodes/ZZ_callClustering/'
sys.path.insert(1, cluster_script_path)
import hopkins2
import vae_goffinet, hopkins
importlib.reload(vae_goffinet)
importlib.reload(hopkins2)
# Out:
# <module 'hopkins2' from '/home/zz367/ProjectsU/EphysMONAO/Jupyter/MatlabCodes/ZZ_callClustering/hopkins2.py'>

# %%
# create a custom colormap for spectrogram
jet = plt.get_cmap('jet', 255)
# Extract jet colors and prepend black at the beginning
jet_colors = jet(np.linspace(0, 1, 255))
custom_colors = np.vstack([[0, 0, 0, 1], jet_colors])  # Black for 0, then jet
custom_cmap = ListedColormap(custom_colors)

# %% [markdown]
# ## 1. Inputs

# %%
fd_z4 = '/mnt/z4'
fd_data = os.path.join(fd_z4, 'zz367', 'EphysMONAO', 'Analyzed', 'vaeWav')
birdIDs = ['pair5RigCCU29', 'pair4RigACU68', 'pair4RigBCU53', 'pair2RigBCU25']
# color limits when calculating spectrograms, depending on the audio amplitude, may differ between birds
clims = [[1.5,7], [1.5,7], [1.5,8.5], [1.5,8]]
# what syllable to analyze
syl = ['v']
sylStr = ''.join(syl)
# the default color list
col_list = ['#e41a1c','#a65628','#4daf4a','#984ea3','#ff7f00','#f781bf','#377eb8','#737373']
# what input dataset to use: real and matched shuffle
# run_names = ['spec_goffinet_nn_256_176', 'spec_goffinet_rd_256_176']
run_names = ['spec_goffinet_rs_256_176']
# size of the spectrogram windows
X_SHAPE = [128, 128]

# %%
# paramteres for UMAP and HDBSCAN
param_umap = {'n_components':2, 'n_neighbors':25, 'min_dist':0, 'metric':'euclidean'}
param_hdbscan = {'min_cluster_size_frac':0.05, 'min_samples': 20}

# %% [markdown]
# ## 2. Loop through birds: VAE -> UMAP -> HDBSCAN

# %%
# save metrics in a master dataframe
metrics = pd.DataFrame()

# %%
bi = 0
bd = birdIDs[bi]

# loop through real and shuffled datasets
for rn in run_names:
    fd_save = os.path.join(fd_data, bd, 'UMAPonVAE1', sylStr, rn)
    if not os.path.exists(fd_save):
        os.makedirs(fd_save)

    print(f'Processing for {bd} {rn}...')
    print(f'Save results to {fd_save}')
    ## load spectrograms and meta info
    fn_spec = os.path.join(fd_data, bd, 'Spectrogram2', sylStr, f'{bd}.{sylStr}.{rn}.h5')
    fn_info = os.path.join(fd_data, bd, 'Spectrogram2', sylStr, f'{bd}.{sylStr}.{rn}.info.csv')
    with h5py.File(fn_spec, 'r') as f:
        spec_win_all = f['spec_win_all'][:]  #

    info = pd.read_csv(fn_info, index_col=0)

    print(spec_win_all.shape, info.shape)

    ## train VAE network
    # create dataloader from h5 file
    train_data = vae_goffinet.SpecDataset(fn_spec)
    train_dataloader = DataLoader(train_data, batch_size=64, shuffle=True, num_workers=4)  # set shuffle to true
    loaders = {'train':train_dataloader, 'test':train_dataloader}

    # init VAE model then train
    model = vae_goffinet.VAE(save_dir=fd_save)
    model.train_loop(loaders, epochs=51, test_freq=None, vis_freq=None, save_freq=10)

    # save model
    fn_model = os.path.join(fd_save, f'{bd}_checkpoint_final.tar')
    model.save_state(fn_model)

    ## Obtain latent representation
    train_dataloader = DataLoader(train_data, batch_size=64, shuffle=False, num_workers=4)  # set shuffle to false to match the order in id_pd

    # loop through dataloader, obtain model latent space
    latent_m = np.zeros((info.shape[0], 32))
    latent_d = np.zeros((info.shape[0], 32))
    recon = np.zeros((info.shape[0], X_SHAPE[0], X_SHAPE[1]))
    model.eval()
    count = 0
    for i, data in tqdm.tqdm(enumerate(train_dataloader)):
        data = data.to('cuda:0')
        with torch.no_grad():
            _, _, rec, mu, d = model.forwardZZ(data, return_latent_rec=True)
            a = rec.shape[0]
            latent_m[count:(count+a),:] = mu
            latent_d[count:(count+a),:] = d
            recon[count:(count+a),:,:] = rec
            count += a

    # save the latent representations
    fn_latentM = os.path.join(fd_save, 'latentM.csv')
    np.savetxt(fn_latentM, latent_m, delimiter=',')
    fn_latentD = os.path.join(fd_save, 'latentD.csv')
    np.savetxt(fn_latentD, latent_d, delimiter=',')
    print(latent_m.shape)

    ## check recontruction accuracy (optional)
    # plot some random samples
    fig, ax = plt.subplots(2, 10, figsize=[12,4])
    random.seed(1118)
    random_i = random.sample(list(range(recon.shape[0])), 10)
    with h5py.File(fn_spec, 'r') as file:
        for ii in range(10):
            spec = train_data[random_i[ii],:,:].numpy()
            ax[0][ii].imshow(np.flip(spec, 0), aspect='auto', vmin=0, vmax=1, cmap=custom_cmap)
            spec = recon[random_i[ii],:,:]
            ax[1][ii].imshow(np.flip(spec, 0), aspect='auto', vmin=0, vmax=1, cmap=custom_cmap)
            if ii>0:
                ax[0][ii].axis('off')
                ax[1][ii].axis('off')
    plt.tight_layout()
    # save fig
    fn_fig = os.path.join(fd_save, 'reconstructed_spectrogram.pdf')
    fig.savefig(fn_fig)

    # add latent_m to the embedding data frame
    embed = info.copy()
    for ii in range(latent_m.shape[1]):
        embed[f'vae{ii}'] = latent_m[:,ii]

    ## run UMAP 
    print(param_umap)
    umap_model = umap.UMAP(n_neighbors=param_umap['n_neighbors'], n_components=param_umap['n_components'], min_dist=param_umap['min_dist'], 
                                                  metric=param_umap['metric'], random_state=1118, verbose=True)
    res = umap_model.fit_transform(latent_m)

    # add UMAP embedding to the dataframe
    for jj in range(res.shape[1]):
        embed[f'umap{jj+1}'] = res[:,jj]

    ## plot embedding
    fig, ax = plt.subplots(nrows=1, ncols=1, figsize=[5, 5])
    for si, ss in enumerate(syl):
        embed_s = embed[embed['label']==ss]
        ax.scatter(embed_s['umap1'], embed_s['umap2'], s=0.3, alpha=0.25, c='#737373')
        # add syl label
        ax.text(np.mean(embed_s['umap1']), np.mean(embed_s['umap2']), ss, fontsize=14)
    ax.set_title(bd, fontsize=14)
    ax.set_xlabel('UMAP axis 1', fontsize=12)
    ax.set_ylabel('UMAP axis 2', fontsize=12)
    plt.tight_layout()
    # save fig
    fn_fig =os.path.join(fd_save, f'{bd}.UMAPonVAE.embedding.pdf')
    fig.savefig(fn_fig)

    ## HDBSCAN clustering
    clusterer = hdbscan.HDBSCAN(min_cluster_size=int(res.shape[0]* param_hdbscan['min_cluster_size_frac']), min_samples=param_hdbscan['min_samples'])
    # clusterer = hdbscan.HDBSCAN(min_cluster_size=200, min_samples=20)
    clusterer.fit(res)
    embed['hdbscan_cluster'] = clusterer.labels_
    embed['hdbscan_prob'] = clusterer.probabilities_
    print(clusterer.cluster_persistence_)

    # save embedding and clustering 
    fn_embed = os.path.join(fd_save, f'{bd}.UMAPonVAE.embedding.csv')
    embed.to_csv(fn_embed)

    # what's the fraction that's not clustered
    unc_f = embed[embed['hdbscan_cluster']==-1].shape[0] / embed.shape[0]
    print(f'The fraction that are not clustered: {unc_f:.4f}')
    num_c = max(embed['hdbscan_cluster']+1)
    print(f'Total number of clusters: {num_c}')

    # color calls according to hdbscan labels
    col_long = sns.color_palette('hls', n_colors=max(embed['hdbscan_cluster'])+1)
    # plot embedding
    fig, ax = plt.subplots(nrows=1, ncols=1, figsize=[5, 5])
    for hi in range(-1, max(embed['hdbscan_cluster'])+1):
        embed_s = embed[embed['hdbscan_cluster']==hi]
        if hi==-1:
            ax.scatter(embed_s['umap1'], embed_s['umap2'], s=0.3, alpha=0.25, color='#737373')
        else:
            ax.scatter(embed_s['umap1'], embed_s['umap2'], s=0.3, alpha=0.5, color=col_long[hi])
            # add syl label
            ax.text(np.mean(embed_s['umap1']), np.mean(embed_s['umap2']), hi, fontsize=12)
    ax.set_title(f'{bd}: {rn}', fontsize=12)
    ax.set_xlabel('UMAP axis 1', fontsize=12)
    ax.set_ylabel('UMAP axis 2', fontsize=12)
    plt.tight_layout()
    # save fig
    fn_fig = os.path.join(fd_save, f'{bd}.UMAPonVAE.HBBSCAN.pdf')
    fig.savefig(fn_fig)

    ## Quantify clustering tendency
    # in UMAP space
    hpk1 = hopkins2.hopkins_statistic(res, rng=1992)
    print(f'Hopkins metric in UMAP: {hpk1:.4f}')
    # in VAE space
    hpk2 = hopkins2.hopkins_statistic(latent_m, rng=1992)
    print(f'Hopkins metric in VAE: {hpk2:.4f}')

    ## Quantify clustering quality with Silhoutte score
    # in UMAP space
    sil1 = silhouette_score(res, embed['hdbscan_cluster'], random_state=1118, metric='euclidean')
    print(f'HDBSCAN Silhouette score in UMAP: {sil1:.4f}')
    # in VAE space
    sil2 = silhouette_score(latent_m, embed['hdbscan_cluster'], random_state=1118, metric='euclidean')
    print(f'HDBSCAN Silhouette score in VAE: {sil2:.4f}')

    # Calinski–Harabasz (CH) Index
    cah1 = calinski_harabasz_score(res, embed['hdbscan_cluster'])
    print(f'Calinski–Harabasz index in UMAP: {cah1:.4f}')
    cah2 = calinski_harabasz_score(latent_m, embed['hdbscan_cluster'])
    print(f'Calinski–Harabasz index in VAE: {cah2:.4f}')

    # save data to the master data frame
    row = pd.DataFrame([{'birdID':bd, 'run_name':input_rn, 'num_cluster':num_c, 'frac_unclustered':unc_f, 'hopkins_umap':hpk1, 'hopkins_vae':hpk2,
                         'silhouette_umap':sil1, 'silhouette_vae':sil2, 'calinski_umap':cah1, 'calinski_vae':cah2, 'param_umap':param_umap, 'param_hdbscan':param_hdbscan}])
    metrics = pd.concat([metrics, row], ignore_index=True)
# Out:
# Processing for pair5RigCCU29 spec_goffinet_rs_256_176...
# Save results to /mnt/z4/zz367/EphysMONAO/Analyzed/vaeWav/pair5RigCCU29/UMAPonVAE1/v/spec_goffinet_rs_256_176
# (23240, 128, 128) (23240, 7)
# ========================================
# Training: epochs 0 to 50
# Training set: 23240
# Test set: 23240
# ========================================
# Epoch: 0 Average loss: 5156.8533
# Epoch: 1 Average loss: 883.2995
# Epoch: 2 Average loss: 711.7457
# Epoch: 3 Average loss: 641.3229
# Epoch: 4 Average loss: 590.7305
# Epoch: 5 Average loss: 545.1418
# Epoch: 6 Average loss: 512.0354
# Epoch: 7 Average loss: 486.9120
# Epoch: 8 Average loss: 471.2275
# Epoch: 9 Average loss: 456.1024
# Epoch: 10 Average loss: 444.5893
# Epoch: 11 Average loss: 435.1879
# Epoch: 12 Average loss: 428.9571
# Epoch: 13 Average loss: 418.5763
# Epoch: 14 Average loss: 411.8479
# Epoch: 15 Average loss: 405.4079
# Epoch: 16 Average loss: 400.5430
# Epoch: 17 Average loss: 395.3625
# Epoch: 18 Average loss: 387.8497
# Epoch: 19 Average loss: 380.1997
# Epoch: 20 Average loss: 375.1128
# Epoch: 21 Average loss: 368.5718
# Epoch: 22 Average loss: 364.0481
# Epoch: 23 Average loss: 361.2340
# Epoch: 24 Average loss: 353.7709
# Epoch: 25 Average loss: 348.8507
# Epoch: 26 Average loss: 344.0543
# Epoch: 27 Average loss: 340.2052
# Epoch: 28 Average loss: 334.4427
# Epoch: 29 Average loss: 331.4511
# Epoch: 30 Average loss: 325.9271
# Epoch: 31 Average loss: 321.0419
# Epoch: 32 Average loss: 317.0883
# Epoch: 33 Average loss: 310.8550
# Epoch: 34 Average loss: 307.2495
# Epoch: 35 Average loss: 302.4224
# Epoch: 36 Average loss: 299.0592
# Epoch: 37 Average loss: 295.7214
# Epoch: 38 Average loss: 291.5758
# Epoch: 39 Average loss: 287.7309
# Epoch: 40 Average loss: 283.8996
# Epoch: 41 Average loss: 278.9256
# Epoch: 42 Average loss: 276.0390
# Epoch: 43 Average loss: 273.2458
# Epoch: 44 Average loss: 269.9574
# Epoch: 45 Average loss: 267.9776
# Epoch: 46 Average loss: 263.5443
# Epoch: 47 Average loss: 261.6739
# Epoch: 48 Average loss: 257.1289
# Epoch: 49 Average loss: 253.9416
# Epoch: 50 Average loss: 251.2888
# 364it [00:26, 13.66it/s]
# (23240, 32)
# {'n_components': 2, 'n_neighbors': 25, 'min_dist': 0, 'metric': 'euclidean'}
# UMAP(min_dist=0, n_jobs=1, n_neighbors=25, random_state=1118, verbose=True)
# Mon Jun  9 10:43:39 2025 Construct fuzzy simplicial set
# Mon Jun  9 10:43:39 2025 Finding Nearest Neighbors
# Mon Jun  9 10:43:39 2025 Building RP forest with 13 trees
# Mon Jun  9 10:43:40 2025 NN descent for 15 iterations
# /home/zz367/miniconda3/envs/wseg_VAE/lib/python3.10/site-packages/umap/umap_.py:1945: UserWarning: n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(f"n_jobs value {self.n_jobs} overridden to 1 by setting random_state. Use no seed for parallelism.")
# 	 1  /  15
# 	 2  /  15
# 	 3  /  15
# 	Stopping threshold met -- exiting after 3 iterations
# Mon Jun  9 10:43:41 2025 Finished Nearest Neighbor Search
# Mon Jun  9 10:43:41 2025 Construct embedding
# Epochs completed:   0%|            0/200 [00:00]
# 	completed  0  /  200 epochs
# 	completed  20  /  200 epochs
# 	completed  40  /  200 epochs
# 	completed  60  /  200 epochs
# 	completed  80  /  200 epochs
# 	completed  100  /  200 epochs
# 	completed  120  /  200 epochs
# 	completed  140  /  200 epochs
# 	completed  160  /  200 epochs
# 	completed  180  /  200 epochs
# Mon Jun  9 10:43:50 2025 Finished embedding
# [0.50108743 0.19046074 0.1215889  0.02964321 0.15854548]
# The fraction that are not clustered: 0.1205
# Total number of clusters: 5
# Hopkins metric in UMAP: 0.9689
# Hopkins metric in VAE: 0.8328
# HDBSCAN Silhouette score in UMAP: 0.2076
# HDBSCAN Silhouette score in VAE: -0.0111
# Calinski–Harabasz index in UMAP: 6677.8385
# Calinski–Harabasz index in VAE: 597.3942

# %%
metrics
# Out:
#           birdID                                           run_name  \
# 0  pair5RigCCU29  [spec_goffinet_nn_256_176, spec_goffinet_rd_25...
# 1  pair5RigCCU29  [spec_goffinet_nn_256_176, spec_goffinet_rd_25...
# 2  pair5RigCCU29  [spec_goffinet_nn_256_176, spec_goffinet_rd_25...
#
#    num_cluster  frac_unclustered  hopkins_umap  hopkins_vae  silhouette_umap  \
# 0            5          0.054518      0.983279     0.825579         0.272011
# 1            4          0.506627      0.952692     0.918045         0.015829
# 2            5          0.120482      0.968893     0.832754         0.207608
#
#    silhouette_vae  calinski_umap  calinski_vae  \
# 0        0.003252    9507.941362    842.519895
# 1        0.021724    4139.575190   1285.699471
# 2       -0.011122    6677.838481    597.394174
#
#                                           param_umap  \
# 0  {'n_components': 2, 'n_neighbors': 25, 'min_di...
# 1  {'n_components': 2, 'n_neighbors': 25, 'min_di...
# 2  {'n_components': 2, 'n_neighbors': 25, 'min_di...
#
#                                        param_hdbscan
# 0  {'min_cluster_size_frac': 0.05, 'min_samples':...
# 1  {'min_cluster_size_frac': 0.05, 'min_samples':...
# 2  {'min_cluster_size_frac': 0.05, 'min_samples':...

# %% [markdown]
# ## Construct a Gaussian covariance matched dataset
# This is what Goffinet used as the baseline

# %%
# load the real dataset
embed_r = pd.read_csv(os.path.join('/mnt/z4/zz367/EphysMONAO/Analyzed/vaeWav/pair5RigCCU29/UMAPonVAE1/v/spec_goffinet_nn_256_176', 'pair5RigCCU29.UMAPonVAE.embedding.csv'))
latent_m_r = np.loadtxt(os.path.join('/mnt/z4/zz367/EphysMONAO/Analyzed/vaeWav/pair5RigCCU29/UMAPonVAE1/v/spec_goffinet_nn_256_176', 'latentM.csv'), delimiter=',')

# %%
# estimated mean and variance
mu = latent_m_r.mean(axis=0)                        # empirical mean  (shape: 32,)
Sigma  = np.cov(latent_m_r, rowvar=False, ddof=1)

# %%
# draw random samples
rng = np.random.default_rng(seed=42)  
X_syn = rng.multivariate_normal(mean=mu, cov=Sigma, size=latent_m_r.shape[0], method='cholesky')
X_syn.shape
# Out:
# (23240, 32)

# %%
## run UMAP 
umap_model = umap.UMAP(n_neighbors=param_umap['n_neighbors'], n_components=param_umap['n_components'], min_dist=param_umap['min_dist'], 
                                              metric=param_umap['metric'], random_state=1118, verbose=True)
res = umap_model.fit_transform(X_syn)
# Out:
# /home/zz367/miniconda3/envs/wseg_VAE/lib/python3.10/site-packages/umap/umap_.py:1945: UserWarning: n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(f"n_jobs value {self.n_jobs} overridden to 1 by setting random_state. Use no seed for parallelism.")
# UMAP(min_dist=0, n_jobs=1, n_neighbors=25, random_state=1118, verbose=True)
# Sun Jun  8 20:50:51 2025 Construct fuzzy simplicial set
# Sun Jun  8 20:50:51 2025 Finding Nearest Neighbors
# Sun Jun  8 20:50:51 2025 Building RP forest with 13 trees
# Sun Jun  8 20:50:51 2025 NN descent for 15 iterations
# 	 1  /  15
# 	 2  /  15
# 	 3  /  15
# 	Stopping threshold met -- exiting after 3 iterations
# Sun Jun  8 20:50:52 2025 Finished Nearest Neighbor Search
# Sun Jun  8 20:50:52 2025 Construct embedding
# Epochs completed:   0%|            0/200 [00:00]
# 	completed  0  /  200 epochs
# 	completed  20  /  200 epochs
# 	completed  40  /  200 epochs
# 	completed  60  /  200 epochs
# 	completed  80  /  200 epochs
# 	completed  100  /  200 epochs
# 	completed  120  /  200 epochs
# 	completed  140  /  200 epochs
# 	completed  160  /  200 epochs
# 	completed  180  /  200 epochs
# Sun Jun  8 20:51:01 2025 Finished embedding

# %%
## HDBSCAN clustering
clusterer = hdbscan.HDBSCAN(min_cluster_size=10, min_samples=param_hdbscan['min_samples'])
# clusterer = hdbscan.HDBSCAN(min_cluster_size=200, min_samples=20)
clusterer.fit(res)
print(clusterer.cluster_persistence_)


## Quantify clustering tendency
# in UMAP space
hpk1 = hopkins2.hopkins_statistic(res, rng=1992)
print(f'Hopkins metric in UMAP: {hpk1:.4f}')
# in VAE space
hpk2 = hopkins2.hopkins_statistic(X_syn, rng=1992)
print(f'Hopkins metric in VAE: {hpk2:.4f}')

## Quantify clustering quality with Silhoutte score
# in UMAP space
sil1 = silhouette_score(res, clusterer.labels_, random_state=1118, metric='euclidean')
print(f'HDBSCAN Silhouette score in UMAP: {sil1:.4f}')
# in VAE space
sil2 = silhouette_score(latent_m,clusterer.labels_, random_state=1118, metric='euclidean')
print(f'HDBSCAN Silhouette score in VAE: {sil2:.4f}')

# Calinski–Harabasz (CH) Index
cah1 = calinski_harabasz_score(res, clusterer.labels_)
print(f'Calinski–Harabasz index in UMAP: {cah1:.4f}')
cah2 = calinski_harabasz_score(latent_m, clusterer.labels_)
print(f'Calinski–Harabasz index in VAE: {cah2:.4f}')
# Out:
# [0.01033015 0.04547455]
# Hopkins metric in UMAP: 0.8432
# Hopkins metric in VAE: 0.7732
# HDBSCAN Silhouette score in UMAP: 0.0296
# HDBSCAN Silhouette score in VAE: 0.0013
# Calinski–Harabasz index in UMAP: 23.7803
# Calinski–Harabasz index in VAE: 2.6233

# %%
clusterer.labels_
# Out:
# array([-1, -1, -1, ..., -1, -1, -1])
