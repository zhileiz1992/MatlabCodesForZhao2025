# %% [markdown]
# ## 0. Goal
# Run VAE first to reduce spectrogram dimensions from 128*128 to 32 latent features. Then run UMAP and HDBSCAN. <br>
# Use Goffinet spectrogramming and VAE network. Use fixed parameters. <br>
# Run one bird at a time

# %%
import os, sys, importlib, librosa, glob, h5py, tqdm, pickle
from scipy.io import wavfile
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from joblib import Parallel, delayed
import random
import umap, hdbscan
from collections import Counter
import seaborn as sns
from matplotlib.colors import ListedColormap
from sklearn.metrics import silhouette_score
from torch.utils.data import Dataset, DataLoader
import torch
from sklearn.metrics import calinski_harabasz_score

plt.rcParams['pdf.fonttype'] = 42

# %%
# import my utility script
cluster_script_path = '/home/zz367/ProjectsU/EphysMONAO/Jupyter/MatlabCodes/ZZ_callClustering/'
sys.path.insert(1, cluster_script_path)
import hopkins2
import vae_goffinet, hopkins
importlib.reload(vae_goffinet)
importlib.reload(hopkins2)
# Out:
# <module 'hopkins2' from '/home/zz367/ProjectsU/EphysMONAO/Jupyter/MatlabCodes/ZZ_callClustering/hopkins2.py'>

# %%
# create a custom colormap for spectrogram
jet = plt.get_cmap('jet', 255)
# Extract jet colors and prepend black at the beginning
jet_colors = jet(np.linspace(0, 1, 255))
custom_colors = np.vstack([[0, 0, 0, 1], jet_colors])  # Black for 0, then jet
custom_cmap = ListedColormap(custom_colors)

# %% [markdown]
# ## 1. Inputs

# %%
fd_z4 = '/mnt/z4'
fd_data = os.path.join(fd_z4, 'zz367', 'EphysMONAO', 'Analyzed', 'vaeWav')
bd = 'pair2RigBCU25'
# color limits when calculating spectrograms, depending on the audio amplitude, may differ between birds
clim = [1.5,8.5]
# what syllable to analyze
syl = ['v']
sylStr = ''.join(syl)
# the default color list
col_list = ['#e41a1c','#a65628','#4daf4a','#984ea3','#ff7f00','#f781bf','#377eb8','#737373']
# what input dataset to use
rn = 'spec_goffinet_nn_256_176'
# size of the spectrogram windows
X_SHAPE = [128, 128]

# %%
fd_save = os.path.join(fd_data, bd, 'UMAPonVAE7', sylStr, rn)
if not os.path.exists(fd_save):
    os.makedirs(fd_save)
print(fd_save)
# Out:
# /mnt/z4/zz367/EphysMONAO/Analyzed/vaeWav/pair2RigBCU25/UMAPonVAE7/v/spec_goffinet_nn_256_176

# %%
# paramteres for UMAP and HDBSCAN
param_umap = {'n_components':2, 'n_neighbors':25, 'min_dist':0, 'metric':'cosine'}
param_hdbscan = {'min_cluster_size_frac':0.05, 'min_samples': 20, 'select_method':'leaf'}

# %% [markdown]
# ## 2. Train VAE, obtain latent features

# %%
print(f'Processing for {bd} {rn}...')
print(f'Save results to {fd_save}')
## load spectrograms and meta info
fn_spec = os.path.join(fd_data, bd, 'Spectrogram2', sylStr, f'{bd}.{sylStr}.{rn}.h5')
fn_info = os.path.join(fd_data, bd, 'Spectrogram2', sylStr, f'{bd}.{sylStr}.{rn}.info.csv')
with h5py.File(fn_spec, 'r') as f:
    spec_win_all = f['spec_win_all'][:]  #

info = pd.read_csv(fn_info, index_col=0)

print(spec_win_all.shape, info.shape)
# Out:
# Processing for pair2RigBCU25 spec_goffinet_nn_256_176...
# Save results to /mnt/z4/zz367/EphysMONAO/Analyzed/vaeWav/pair2RigBCU25/UMAPonVAE7/v/spec_goffinet_nn_256_176
# (16452, 128, 128) (16452, 7)

# %%
## train VAE network
# create dataloader from h5 file
# train_data = vae_goffinet.SpecDataset(fn_spec)
# # set a random seed
# g = torch.Generator()
# g.manual_seed(42)
# train_dataloader = DataLoader(train_data, batch_size=64, shuffle=True, num_workers=4, generator=g)  # set shuffle to true
# loaders = {'train':train_dataloader, 'test':train_dataloader}

# # init VAE model then train
# model = vae_goffinet.VAE(save_dir=fd_save)
# model.train_loop(loaders, epochs=51, test_freq=None, vis_freq=None, save_freq=10)

# OR load previously trained model
# for training see ZZp3_UMAPonVAE_v1.ipynb
fn_model = os.path.join(fd_save, f'{bd}_checkpoint_final.tar')
model = vae_goffinet.VAE(save_dir=fd_save)
model.load_state(fn_model)

# %%
## Obtain latent representation
train_data = vae_goffinet.SpecDataset(fn_spec)
train_dataloader = DataLoader(train_data, batch_size=64, shuffle=False, num_workers=4)  # set shuffle to false to match the order in id_pd

# loop through dataloader, obtain model latent space
latent_m = np.zeros((info.shape[0], 32))
latent_d = np.zeros((info.shape[0], 32))
recon = np.zeros((info.shape[0], X_SHAPE[0], X_SHAPE[1]))
model.eval()
count = 0
for i, data in tqdm.tqdm(enumerate(train_dataloader)):
    data = data.to('cuda:0')
    with torch.no_grad():
        _, _, rec, mu, d = model.forwardZZ(data, return_latent_rec=True)
        a = rec.shape[0]
        latent_m[count:(count+a),:] = mu
        latent_d[count:(count+a),:] = d
        recon[count:(count+a),:,:] = rec
        count += a

# save the latent representations
fn_latentM = os.path.join(fd_save, 'latentM.csv')
np.savetxt(fn_latentM, latent_m, delimiter=',')
fn_latentD = os.path.join(fd_save, 'latentD.csv')
np.savetxt(fn_latentD, latent_d, delimiter=',')
print(latent_m.shape)
# Out:
# 0it [00:00, ?it/s]/home/zz367/miniconda3/envs/wseg_VAE/lib/python3.10/site-packages/torch/nn/modules/conv.py:952: UserWarning: Plan failed with a cudnnException: CUDNN_BACKEND_EXECUTION_PLAN_DESCRIPTOR: cudnnFinalize Descriptor Failed cudnn_status: CUDNN_STATUS_NOT_SUPPORTED (Triggered internally at ../aten/src/ATen/native/cudnn/Conv_v8.cpp:919.)
#   return F.conv_transpose2d(
# 258it [00:18, 13.97it/s]
# (16452, 32)

# %%
## check recontruction accuracy (optional)
# plot some random samples
fig, ax = plt.subplots(2, 10, figsize=[12,4])
random.seed(1118)
random_i = random.sample(list(range(recon.shape[0])), 10)
with h5py.File(fn_spec, 'r') as file:
    for ii in range(10):
        spec = train_data[random_i[ii],:,:].numpy()
        ax[0][ii].imshow(np.flip(spec, 0), aspect='auto', vmin=0, vmax=1, cmap=custom_cmap)
        spec = recon[random_i[ii],:,:]
        ax[1][ii].imshow(np.flip(spec, 0), aspect='auto', vmin=0, vmax=1, cmap=custom_cmap)
        if ii>0:
            ax[0][ii].axis('off')
            ax[1][ii].axis('off')
plt.tight_layout()
# save fig
fn_fig = os.path.join(fd_save, 'reconstructed_spectrogram.pdf')
fig.savefig(fn_fig)

# %% [markdown]
# ## 3. Run UMAP/HDBSCAN

# %%
fn_info = os.path.join(fd_data, bd, 'Spectrogram2', sylStr, f'{bd}.{sylStr}.{rn}.info.csv')
info = pd.read_csv(fn_info, index_col=0)

# %%
# read latent features
fn_latentM = os.path.join(fd_save, 'latentM.csv')
latent_m = np.loadtxt(fn_latentM, delimiter=',')
latent_m.shape
# Out:
# (16452, 32)

# %%
# add latent_m to the embedding data frame
embed = info.copy()
for ii in range(latent_m.shape[1]):
    embed[f'vae{ii}'] = latent_m[:,ii]

# %% [markdown]
# ### UMAP

# %%
## run UMAP 
print(param_umap)
umap_model = umap.UMAP(n_neighbors=param_umap['n_neighbors'], n_components=param_umap['n_components'], min_dist=param_umap['min_dist'], 
                                              metric=param_umap['metric'], random_state=1118, verbose=True)
res = umap_model.fit_transform(latent_m)

# add UMAP embedding to the dataframe
for jj in range(res.shape[1]):
    embed[f'umap{jj+1}'] = res[:,jj]
# Out:
# {'n_components': 2, 'n_neighbors': 25, 'min_dist': 0, 'metric': 'cosine'}
# UMAP(angular_rp_forest=True, metric='cosine', min_dist=0, n_jobs=1, n_neighbors=25, random_state=1118, verbose=True)
# Thu Jul  3 16:25:29 2025 Construct fuzzy simplicial set
# Thu Jul  3 16:25:29 2025 Finding Nearest Neighbors
# Thu Jul  3 16:25:29 2025 Building RP forest with 11 trees
# /home/zz367/miniconda3/envs/wseg_VAE/lib/python3.10/site-packages/umap/umap_.py:1945: UserWarning: n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(f"n_jobs value {self.n_jobs} overridden to 1 by setting random_state. Use no seed for parallelism.")
# Thu Jul  3 16:25:31 2025 NN descent for 14 iterations
# 	 1  /  14
# 	 2  /  14
# 	 3  /  14
# 	Stopping threshold met -- exiting after 3 iterations
# Thu Jul  3 16:25:39 2025 Finished Nearest Neighbor Search
# Thu Jul  3 16:25:41 2025 Construct embedding
# Epochs completed:   0%|            0/200 [00:00]
# 	completed  0  /  200 epochs
# 	completed  20  /  200 epochs
# 	completed  40  /  200 epochs
# 	completed  60  /  200 epochs
# 	completed  80  /  200 epochs
# 	completed  100  /  200 epochs
# 	completed  120  /  200 epochs
# 	completed  140  /  200 epochs
# 	completed  160  /  200 epochs
# 	completed  180  /  200 epochs
# Thu Jul  3 16:25:48 2025 Finished embedding

# %%
# save the UMAP model for later usage
fn_umap = os.path.join(fd_save, f'UMAPmodel_{bd}.p')
pickle.dump(umap_model, open(fn_umap, 'wb'))
# Out:
# Thu Jul  3 16:25:50 2025 Worst tree score: 0.88512035
# Thu Jul  3 16:25:50 2025 Mean tree score: 0.88839710
# Thu Jul  3 16:25:50 2025 Best tree score: 0.89241430
# Thu Jul  3 16:25:52 2025 Forward diversification reduced edges from 411300 to 133807
# Thu Jul  3 16:25:53 2025 Reverse diversification reduced edges from 133807 to 133807
# Thu Jul  3 16:25:55 2025 Degree pruning reduced edges from 144840 to 144840
# Thu Jul  3 16:25:55 2025 Resorting data and graph based on tree order
# Thu Jul  3 16:25:55 2025 Building and compiling search function

# %%
## plot embedding
fig, ax = plt.subplots(nrows=1, ncols=1, figsize=[5, 5])
for si, ss in enumerate(syl):
    embed_s = embed[embed['label']==ss]
    ax.scatter(embed_s['umap1'], embed_s['umap2'], s=0.3, alpha=0.25, c='#737373')
    # add syl label
    ax.text(np.mean(embed_s['umap1']), np.mean(embed_s['umap2']), ss, fontsize=14)
ax.set_title(f'{bd}:{embed.shape[0]}', fontsize=10)
ax.set_xlabel('UMAP axis 1', fontsize=12)
ax.set_ylabel('UMAP axis 2', fontsize=12)
plt.tight_layout()
# save fig
fn_fig =os.path.join(fd_save, f'{bd}.UMAPonVAE.embedding.pdf')
fig.savefig(fn_fig)

# %% [markdown]
# ### HDBSCAN clustering

# %%
res.shape[0] * 0.05
# Out:
# 822.6

# %%
## HDBSCAN clustering
clusterer = hdbscan.HDBSCAN(min_cluster_size=int(res.shape[0]* param_hdbscan['min_cluster_size_frac']), min_samples=param_hdbscan['min_samples'], 
                            cluster_selection_method=param_hdbscan['select_method'], prediction_data=True)
# clusterer = hdbscan.HDBSCAN(min_cluster_size=1000, min_samples=20, 
#                             cluster_selection_method='leaf')
# clusterer = hdbscan.HDBSCAN(min_cluster_size=200, min_samples=20)
clusterer.fit(res)
embed['hdbscan_cluster'] = clusterer.labels_ + 1    # no clustering is label 0
embed['hdbscan_prob'] = clusterer.probabilities_

# save embedding and clustering 
fn_embed = os.path.join(fd_save, f'{bd}.{rn}.embedding.csv')
embed.to_csv(fn_embed)

# what's the fraction that's not clustered
unc_f = embed[embed['hdbscan_cluster']==0].shape[0] / embed.shape[0]
print(f'The fraction that are not clustered: {unc_f:.4f}')
num_c = max(embed['hdbscan_cluster'])
print(f'Total number of clusters: {num_c}')
# Out:
# The fraction that are not clustered: 0.3066
# Total number of clusters: 7

# %%
# color calls according to hdbscan labels
col_long = sns.color_palette('hls', n_colors=max(embed['hdbscan_cluster']))
# plot embedding
fig, ax = plt.subplots(nrows=1, ncols=1, figsize=[5, 5])
for hi in range(0, max(embed['hdbscan_cluster'])+1):
    embed_s = embed[embed['hdbscan_cluster']==hi]
    if hi==0:
        ax.scatter(embed_s['umap1'], embed_s['umap2'], s=0.3, alpha=0.25, color='#737373')
    else:
        ax.scatter(embed_s['umap1'], embed_s['umap2'], s=0.3, alpha=0.5, color=col_long[hi-1])
        # add syl label
        ax.text(np.mean(embed_s['umap1']), np.mean(embed_s['umap2']), hi, fontsize=12)
ax.set_title(f'{bd}:{embed.shape[0]}', fontsize=10)
ax.set_xlabel('UMAP axis 1', fontsize=12)
ax.set_ylabel('UMAP axis 2', fontsize=12)
plt.tight_layout()
# save fig
fn_fig = os.path.join(fd_save, f'{bd}.UMAPonVAE.HBBSCAN.pdf')
fig.savefig(fn_fig)

# %%
# save HDBSCAN model for future use
fn_cluster = os.path.join(fd_save, f'HDBSCANmodel_{bd}.p')
pickle.dump(clusterer, open(fn_cluster, 'wb'))

# %%
# save the color list as well
col_long_np = np.array(col_long)
fn_col = os.path.join(fd_save, 'color.txt')
np.savetxt(fn_col, col_long_np, delimiter=',')

# %% [markdown]
# ### Quantify clustering quality

# %%
## Quantify clustering tendency
# in UMAP space
hpk1 = hopkins2.hopkins_statistic(res, rng=1992)
print(f'Hopkins metric in UMAP: {hpk1:.4f}')
# in VAE space
hpk2 = hopkins2.hopkins_statistic(latent_m, rng=1992)
print(f'Hopkins metric in VAE: {hpk2:.4f}')

## Quantify clustering quality with Silhoutte score
# in UMAP space
sil1 = silhouette_score(res, embed['hdbscan_cluster'], random_state=1118, metric='euclidean')
print(f'HDBSCAN Silhouette score in UMAP: {sil1:.4f}')
# in VAE space
sil2 = silhouette_score(latent_m, embed['hdbscan_cluster'], random_state=1118, metric='euclidean')
print(f'HDBSCAN Silhouette score in VAE: {sil2:.4f}')

# Calinski–Harabasz (CH) Index
cah1 = calinski_harabasz_score(res, embed['hdbscan_cluster'])
print(f'Calinski–Harabasz index in UMAP: {cah1:.4f}')
cah2 = calinski_harabasz_score(latent_m, embed['hdbscan_cluster'])
print(f'Calinski–Harabasz index in VAE: {cah2:.4f}')

# save data to the master data frame
metrics = pd.DataFrame([{'birdID':bd, 'run_name':rn, 'num_cluster':num_c, 'frac_unclustered':unc_f, 'cluster_persist':clusterer.cluster_persistence_, 'hopkins_umap':hpk1, 
                     'hopkins_vae':hpk2, 'silhouette_umap':sil1, 'silhouette_vae':sil2, 'calinski_umap':cah1, 'calinski_vae':cah2, 'param_umap':param_umap, 'param_hdbscan':param_hdbscan}])
# Out:
# Hopkins metric in UMAP: 0.9834
# Hopkins metric in VAE: 0.8310
# HDBSCAN Silhouette score in UMAP: 0.1967
# HDBSCAN Silhouette score in VAE: 0.0245
# Calinski–Harabasz index in UMAP: 6515.7210
# Calinski–Harabasz index in VAE: 805.7932

# %%
# save the metrics
fn_metric = os.path.join(fd_save, f'{bd}.UMAPonVAE.metrics.csv')
metrics.to_csv(fn_metric)
metrics
# Out:
#           birdID                  run_name  num_cluster  frac_unclustered  \
# 0  pair2RigBCU25  spec_goffinet_nn_256_176            7           0.30665
#
#                                      cluster_persist  hopkins_umap  \
# 0  [0.8763901881326406, 0.19597107242663978, 0.15...      0.983425
#
#    hopkins_vae  silhouette_umap  silhouette_vae  calinski_umap  calinski_vae  \
# 0     0.831036         0.196658        0.024531     6515.72097    805.793237
#
#                                           param_umap  \
# 0  {'n_components': 2, 'n_neighbors': 25, 'min_di...
#
#                                        param_hdbscan
# 0  {'min_cluster_size_frac': 0.05, 'min_samples':...

# %% [markdown]
# ## 4. Simulate the random datasets

# %%
# number of trials to simulate
n = 200

# %%
# load the real dataset
fn_latentM = os.path.join(fd_save, 'latentM.csv')
latent_m = np.loadtxt(fn_latentM, delimiter=',')
latent_m.shape
# Out:
# (16452, 32)

# %%
 # estimated mean and variance
mu = latent_m.mean(axis=0)                        # empirical mean  (shape: 32,)
Sigma  = np.cov(latent_m, rowvar=False, ddof=1)

# %%
# save metrics in a master dataframe
metrics = pd.DataFrame()
np.random.seed(1118)
for i in range(n):
# for i in range(2):
    rng = np.random.default_rng()  
    latent_rd = rng.multivariate_normal(mean=mu, cov=Sigma, size=latent_m.shape[0], method='cholesky')
    
    # then run UMAP and HDBSCAN exactly as for real datasets
    ## run UMAP 
    umap_model = umap.UMAP(n_neighbors=param_umap['n_neighbors'], n_components=param_umap['n_components'], min_dist=param_umap['min_dist'], 
                                                  metric=param_umap['metric'], random_state=1118, verbose=True)
    res = umap_model.fit_transform(latent_rd)

    ## HDBSCAN clustering
    # clusterer = hdbscan.HDBSCAN(min_cluster_size=int(res.shape[0]* param_hdbscan['min_cluster_size_frac']), min_samples=param_hdbscan['min_samples'], 
    #                             cluster_selection_method=param_hdbscan['select_method'])
    clusterer = hdbscan.HDBSCAN(min_cluster_size=1000, min_samples=20, 
                                cluster_selection_method='leaf')
    # clusterer = hdbscan.HDBSCAN(min_cluster_size=200, min_samples=20)
    clusterer.fit(res)
    
    labs = clusterer.labels_; 
    # what's the fraction that's not clustered
    unc_f = labs[labs==-1].shape[0] / labs.shape[0]
    print(f'The fraction that are not clustered: {unc_f:.4f}')
    num_c = max(labs+1)
    print(f'Total number of clusters: {num_c}')
    
    if num_c==0:
        continue

    ## Quantify clustering tendency
    # in UMAP space
    hpk1 = hopkins2.hopkins_statistic(res, rng=1992)
    print(f'Hopkins metric in UMAP: {hpk1:.4f}')
    # in VAE space
    hpk2 = hopkins2.hopkins_statistic(latent_m, rng=1992)
    print(f'Hopkins metric in VAE: {hpk2:.4f}')

    ## Quantify clustering quality with Silhoutte score
    # in UMAP space
    sil1 = silhouette_score(res, labs, random_state=1118, metric='euclidean')
    print(f'HDBSCAN Silhouette score in UMAP: {sil1:.4f}')
    # in VAE space
    sil2 = silhouette_score(latent_m, labs, random_state=1118, metric='euclidean')
    print(f'HDBSCAN Silhouette score in VAE: {sil2:.4f}')

    # Calinski–Harabasz (CH) Index
    cah1 = calinski_harabasz_score(res, labs)
    print(f'Calinski–Harabasz index in UMAP: {cah1:.4f}')
    cah2 = calinski_harabasz_score(latent_m, labs)
    print(f'Calinski–Harabasz index in VAE: {cah2:.4f}')

    # save data to the master data frame
    row = pd.DataFrame([{'birdID':bd, 'run_id':i, 'num_cluster':num_c, 'frac_unclustered':unc_f, 'cluster_persist':clusterer.cluster_persistence_, 'hopkins_umap':hpk1, 
                         'hopkins_vae':hpk2, 'silhouette_umap':sil1, 'silhouette_vae':sil2, 'calinski_umap':cah1, 'calinski_vae':cah2, 'param_umap':param_umap, 'param_hdbscan':param_hdbscan}])
    metrics = pd.concat([metrics, row], ignore_index=True)
# Out:
# /home/zz367/miniconda3/envs/wseg_VAE/lib/python3.10/site-packages/umap/umap_.py:1945: UserWarning: n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(f"n_jobs value {self.n_jobs} overridden to 1 by setting random_state. Use no seed for parallelism.")
# UMAP(angular_rp_forest=True, metric='cosine', min_dist=0, n_jobs=1, n_neighbors=25, random_state=1118, verbose=True)
# Sun Jun 22 21:21:23 2025 Construct fuzzy simplicial set
# Sun Jun 22 21:21:23 2025 Finding Nearest Neighbors
# Sun Jun 22 21:21:23 2025 Building RP forest with 11 trees
# Sun Jun 22 21:21:24 2025 NN descent for 14 iterations
# 	 1  /  14
# 	 2  /  14
# 	 3  /  14
# 	Stopping threshold met -- exiting after 3 iterations
# Sun Jun 22 21:21:24 2025 Finished Nearest Neighbor Search
# Sun Jun 22 21:21:24 2025 Construct embedding
# Epochs completed:   0%|            0/200 [00:00]
# 	completed  0  /  200 epochs
# 	completed  20  /  200 epochs
# 	completed  40  /  200 epochs
# 	completed  60  /  200 epochs
# 	completed  80  /  200 epochs
# 	completed  100  /  200 epochs
# 	completed  120  /  200 epochs
# 	completed  140  /  200 epochs
# 	completed  160  /  200 epochs
# 	completed  180  /  200 epochs
# Sun Jun 22 21:21:31 2025 Finished embedding
# The fraction that are not clustered: 0.5721
# Total number of clusters: 4
# Hopkins metric in UMAP: 0.8572
# Hopkins metric in VAE: 0.8310
# HDBSCAN Silhouette score in UMAP: -0.1068
# HDBSCAN Silhouette score in VAE: -0.0040
# Calinski–Harabasz index in UMAP: 1613.7866
# Calinski–Harabasz index in VAE: 0.9020
# UMAP(angular_rp_forest=True, metric='cosine', min_dist=0, n_jobs=1, n_neighbors=25, random_state=1118, verbose=True)
# Sun Jun 22 21:21:36 2025 Construct fuzzy simplicial set
# Sun Jun 22 21:21:36 2025 Finding Nearest Neighbors
# Sun Jun 22 21:21:36 2025 Building RP forest with 11 trees
# Sun Jun 22 21:21:36 2025 NN descent for 14 iterations
# 	 1  /  14
# /home/zz367/miniconda3/envs/wseg_VAE/lib/python3.10/site-packages/umap/umap_.py:1945: UserWarning: n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(f"n_jobs value {self.n_jobs} overridden to 1 by setting random_state. Use no seed for parallelism.")
# 	 2  /  14
# 	 3  /  14
# 	Stopping threshold met -- exiting after 3 iterations
# Sun Jun 22 21:21:37 2025 Finished Nearest Neighbor Search
# Sun Jun 22 21:21:37 2025 Construct embedding
# Epochs completed:   0%|            0/200 [00:00]
# 	completed  0  /  200 epochs
# 	completed  20  /  200 epochs
# 	completed  40  /  200 epochs
# 	completed  60  /  200 epochs
# 	completed  80  /  200 epochs
# 	completed  100  /  200 epochs
# 	completed  120  /  200 epochs
# 	completed  140  /  200 epochs
# 	completed  160  /  200 epochs
# 	completed  180  /  200 epochs
# Sun Jun 22 21:21:43 2025 Finished embedding
# The fraction that are not clustered: 0.7012
# Total number of clusters: 3
# Hopkins metric in UMAP: 0.8683
# Hopkins metric in VAE: 0.8310
# HDBSCAN Silhouette score in UMAP: -0.1635
# HDBSCAN Silhouette score in VAE: -0.0062
# Calinski–Harabasz index in UMAP: 828.1597
# Calinski–Harabasz index in VAE: 1.2353
# UMAP(angular_rp_forest=True, metric='cosine', min_dist=0, n_jobs=1, n_neighbors=25, random_state=1118, verbose=True)
# Sun Jun 22 21:21:48 2025 Construct fuzzy simplicial set
# Sun Jun 22 21:21:48 2025 Finding Nearest Neighbors
# Sun Jun 22 21:21:48 2025 Building RP forest with 11 trees
# Sun Jun 22 21:21:48 2025 NN descent for 14 iterations
# 	 1  /  14
# /home/zz367/miniconda3/envs/wseg_VAE/lib/python3.10/site-packages/umap/umap_.py:1945: UserWarning: n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(f"n_jobs value {self.n_jobs} overridden to 1 by setting random_state. Use no seed for parallelism.")
# 	 2  /  14
# 	 3  /  14
# 	Stopping threshold met -- exiting after 3 iterations
# Sun Jun 22 21:21:49 2025 Finished Nearest Neighbor Search
# Sun Jun 22 21:21:49 2025 Construct embedding
# Epochs completed:   0%|            0/200 [00:00]
# 	completed  0  /  200 epochs
# 	completed  20  /  200 epochs
# 	completed  40  /  200 epochs
# 	completed  60  /  200 epochs
# 	completed  80  /  200 epochs
# 	completed  100  /  200 epochs
# 	completed  120  /  200 epochs
# 	completed  140  /  200 epochs
# 	completed  160  /  200 epochs
# 	completed  180  /  200 epochs
# Sun Jun 22 21:21:56 2025 Finished embedding
# The fraction that are not clustered: 0.5455
# Total number of clusters: 3
# Hopkins metric in UMAP: 0.8730
# Hopkins metric in VAE: 0.8310
# HDBSCAN Silhouette score in UMAP: -0.0671
# HDBSCAN Silhouette score in VAE: -0.0047
# Calinski–Harabasz index in UMAP: 1637.9924
# Calinski–Harabasz index in VAE: 0.9365
# UMAP(angular_rp_forest=True, metric='cosine', min_dist=0, n_jobs=1, n_neighbors=25, random_state=1118, verbose=True)
# Sun Jun 22 21:22:01 2025 Construct fuzzy simplicial set
# Sun Jun 22 21:22:01 2025 Finding Nearest Neighbors
# Sun Jun 22 21:22:01 2025 Building RP forest with 11 trees
# Sun Jun 22 21:22:01 2025 NN descent for 14 iterations
# 	 1  /  14
# /home/zz367/miniconda3/envs/wseg_VAE/lib/python3.10/site-packages/umap/umap_.py:1945: UserWarning: n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(f"n_jobs value {self.n_jobs} overridden to 1 by setting random_state. Use no seed for parallelism.")
# 	 2  /  14
# 	 3  /  14
# 	Stopping threshold met -- exiting after 3 iterations
# Sun Jun 22 21:22:01 2025 Finished Nearest Neighbor Search
# Sun Jun 22 21:22:01 2025 Construct embedding
# Epochs completed:   0%|            0/200 [00:00]
# 	completed  0  /  200 epochs
# 	completed  20  /  200 epochs
# 	completed  40  /  200 epochs
# 	completed  60  /  200 epochs
# 	completed  80  /  200 epochs
# 	completed  100  /  200 epochs
# 	completed  120  /  200 epochs
# 	completed  140  /  200 epochs
# 	completed  160  /  200 epochs
# 	completed  180  /  200 epochs
# Sun Jun 22 21:22:08 2025 Finished embedding
# The fraction that are not clustered: 0.6902
# Total number of clusters: 2
# Hopkins metric in UMAP: 0.8642
# Hopkins metric in VAE: 0.8310
# HDBSCAN Silhouette score in UMAP: -0.0887
# HDBSCAN Silhouette score in VAE: -0.0006
# Calinski–Harabasz index in UMAP: 907.3095
# Calinski–Harabasz index in VAE: 0.7313
# UMAP(angular_rp_forest=True, metric='cosine', min_dist=0, n_jobs=1, n_neighbors=25, random_state=1118, verbose=True)
# Sun Jun 22 21:22:13 2025 Construct fuzzy simplicial set
# Sun Jun 22 21:22:13 2025 Finding Nearest Neighbors
# Sun Jun 22 21:22:13 2025 Building RP forest with 11 trees
# Sun Jun 22 21:22:13 2025 NN descent for 14 iterations
# 	 1  /  14
# /home/zz367/miniconda3/envs/wseg_VAE/lib/python3.10/site-packages/umap/umap_.py:1945: UserWarning: n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(f"n_jobs value {self.n_jobs} overridden to 1 by setting random_state. Use no seed for parallelism.")
# 	 2  /  14
# 	 3  /  14
# 	Stopping threshold met -- exiting after 3 iterations
# Sun Jun 22 21:22:14 2025 Finished Nearest Neighbor Search
# Sun Jun 22 21:22:14 2025 Construct embedding
# Epochs completed:   0%|            0/200 [00:00]
# 	completed  0  /  200 epochs
# 	completed  20  /  200 epochs
# 	completed  40  /  200 epochs
# 	completed  60  /  200 epochs
# 	completed  80  /  200 epochs
# 	completed  100  /  200 epochs
# 	completed  120  /  200 epochs
# 	completed  140  /  200 epochs
# 	completed  160  /  200 epochs
# 	completed  180  /  200 epochs
# Sun Jun 22 21:22:21 2025 Finished embedding
# The fraction that are not clustered: 0.5344
# Total number of clusters: 4
# Hopkins metric in UMAP: 0.8754
# Hopkins metric in VAE: 0.8310
# HDBSCAN Silhouette score in UMAP: -0.0720
# HDBSCAN Silhouette score in VAE: -0.0055
# Calinski–Harabasz index in UMAP: 1996.4257
# Calinski–Harabasz index in VAE: 0.7389
# UMAP(angular_rp_forest=True, metric='cosine', min_dist=0, n_jobs=1, n_neighbors=25, random_state=1118, verbose=True)
# Sun Jun 22 21:22:25 2025 Construct fuzzy simplicial set
# Sun Jun 22 21:22:25 2025 Finding Nearest Neighbors
# Sun Jun 22 21:22:25 2025 Building RP forest with 11 trees
# Sun Jun 22 21:22:26 2025 NN descent for 14 iterations
# 	 1  /  14
# /home/zz367/miniconda3/envs/wseg_VAE/lib/python3.10/site-packages/umap/umap_.py:1945: UserWarning: n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(f"n_jobs value {self.n_jobs} overridden to 1 by setting random_state. Use no seed for parallelism.")
# 	 2  /  14
# 	 3  /  14
# 	Stopping threshold met -- exiting after 3 iterations
# Sun Jun 22 21:22:26 2025 Finished Nearest Neighbor Search
# Sun Jun 22 21:22:26 2025 Construct embedding
# Epochs completed:   0%|            0/200 [00:00]
# 	completed  0  /  200 epochs
# 	completed  20  /  200 epochs
# 	completed  40  /  200 epochs
# 	completed  60  /  200 epochs
# 	completed  80  /  200 epochs
# 	completed  100  /  200 epochs
# 	completed  120  /  200 epochs
# 	completed  140  /  200 epochs
# 	completed  160  /  200 epochs
# 	completed  180  /  200 epochs
# Sun Jun 22 21:22:33 2025 Finished embedding
# The fraction that are not clustered: 0.7650
# Total number of clusters: 3
# Hopkins metric in UMAP: 0.8624
# Hopkins metric in VAE: 0.8310
# HDBSCAN Silhouette score in UMAP: -0.2346
# HDBSCAN Silhouette score in VAE: -0.0095
# Calinski–Harabasz index in UMAP: 694.8627
# Calinski–Harabasz index in VAE: 1.2715
# UMAP(angular_rp_forest=True, metric='cosine', min_dist=0, n_jobs=1, n_neighbors=25, random_state=1118, verbose=True)
# Sun Jun 22 21:22:38 2025 Construct fuzzy simplicial set
# Sun Jun 22 21:22:38 2025 Finding Nearest Neighbors
# Sun Jun 22 21:22:38 2025 Building RP forest with 11 trees
# Sun Jun 22 21:22:38 2025 NN descent for 14 iterations
# 	 1  /  14
# /home/zz367/miniconda3/envs/wseg_VAE/lib/python3.10/site-packages/umap/umap_.py:1945: UserWarning: n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(f"n_jobs value {self.n_jobs} overridden to 1 by setting random_state. Use no seed for parallelism.")
# 	 2  /  14
# 	 3  /  14
# 	Stopping threshold met -- exiting after 3 iterations
# Sun Jun 22 21:22:39 2025 Finished Nearest Neighbor Search
# Sun Jun 22 21:22:39 2025 Construct embedding
# Epochs completed:   0%|            0/200 [00:00]
# 	completed  0  /  200 epochs
# 	completed  20  /  200 epochs
# 	completed  40  /  200 epochs
# 	completed  60  /  200 epochs
# 	completed  80  /  200 epochs
# 	completed  100  /  200 epochs
# 	completed  120  /  200 epochs
# 	completed  140  /  200 epochs
# 	completed  160  /  200 epochs
# 	completed  180  /  200 epochs
# Sun Jun 22 21:22:45 2025 Finished embedding
# The fraction that are not clustered: 0.8209
# Total number of clusters: 2
# Hopkins metric in UMAP: 0.8832
# Hopkins metric in VAE: 0.8310
# HDBSCAN Silhouette score in UMAP: -0.1838
# HDBSCAN Silhouette score in VAE: -0.0054
# Calinski–Harabasz index in UMAP: 500.8521
# Calinski–Harabasz index in VAE: 0.7135
# UMAP(angular_rp_forest=True, metric='cosine', min_dist=0, n_jobs=1, n_neighbors=25, random_state=1118, verbose=True)
# Sun Jun 22 21:22:51 2025 Construct fuzzy simplicial set
# Sun Jun 22 21:22:51 2025 Finding Nearest Neighbors
# Sun Jun 22 21:22:51 2025 Building RP forest with 11 trees
# Sun Jun 22 21:22:51 2025 NN descent for 14 iterations
# 	 1  /  14
# /home/zz367/miniconda3/envs/wseg_VAE/lib/python3.10/site-packages/umap/umap_.py:1945: UserWarning: n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(f"n_jobs value {self.n_jobs} overridden to 1 by setting random_state. Use no seed for parallelism.")
# 	 2  /  14
# 	 3  /  14
# 	Stopping threshold met -- exiting after 3 iterations
# Sun Jun 22 21:22:51 2025 Finished Nearest Neighbor Search
# Sun Jun 22 21:22:52 2025 Construct embedding
# Epochs completed:   0%|            0/200 [00:00]
# 	completed  0  /  200 epochs
# 	completed  20  /  200 epochs
# 	completed  40  /  200 epochs
# 	completed  60  /  200 epochs
# 	completed  80  /  200 epochs
# 	completed  100  /  200 epochs
# 	completed  120  /  200 epochs
# 	completed  140  /  200 epochs
# 	completed  160  /  200 epochs
# 	completed  180  /  200 epochs
# Sun Jun 22 21:22:58 2025 Finished embedding
# The fraction that are not clustered: 0.5785
# Total number of clusters: 5
# Hopkins metric in UMAP: 0.8534
# Hopkins metric in VAE: 0.8310
# HDBSCAN Silhouette score in UMAP: -0.1490
# HDBSCAN Silhouette score in VAE: -0.0101
# Calinski–Harabasz index in UMAP: 1455.7457
# Calinski–Harabasz index in VAE: 1.2201
# UMAP(angular_rp_forest=True, metric='cosine', min_dist=0, n_jobs=1, n_neighbors=25, random_state=1118, verbose=True)
# Sun Jun 22 21:23:03 2025 Construct fuzzy simplicial set
# Sun Jun 22 21:23:03 2025 Finding Nearest Neighbors
# Sun Jun 22 21:23:03 2025 Building RP forest with 11 trees
# Sun Jun 22 21:23:03 2025 NN descent for 14 iterations
# 	 1  /  14
# /home/zz367/miniconda3/envs/wseg_VAE/lib/python3.10/site-packages/umap/umap_.py:1945: UserWarning: n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(f"n_jobs value {self.n_jobs} overridden to 1 by setting random_state. Use no seed for parallelism.")
# 	 2  /  14
# 	 3  /  14
# 	Stopping threshold met -- exiting after 3 iterations
# Sun Jun 22 21:23:04 2025 Finished Nearest Neighbor Search
# Sun Jun 22 21:23:04 2025 Construct embedding
# Epochs completed:   0%|            0/200 [00:00]
# 	completed  0  /  200 epochs
# 	completed  20  /  200 epochs
# 	completed  40  /  200 epochs
# 	completed  60  /  200 epochs
# 	completed  80  /  200 epochs
# 	completed  100  /  200 epochs
# 	completed  120  /  200 epochs
# 	completed  140  /  200 epochs
# 	completed  160  /  200 epochs
# 	completed  180  /  200 epochs
# Sun Jun 22 21:23:10 2025 Finished embedding
# The fraction that are not clustered: 0.6658
# Total number of clusters: 3
# Hopkins metric in UMAP: 0.8651
# Hopkins metric in VAE: 0.8310
# HDBSCAN Silhouette score in UMAP: -0.1089
# HDBSCAN Silhouette score in VAE: -0.0045
# Calinski–Harabasz index in UMAP: 1427.8634
# Calinski–Harabasz index in VAE: 0.7220
# UMAP(angular_rp_forest=True, metric='cosine', min_dist=0, n_jobs=1, n_neighbors=25, random_state=1118, verbose=True)
# Sun Jun 22 21:23:16 2025 Construct fuzzy simplicial set
# Sun Jun 22 21:23:16 2025 Finding Nearest Neighbors
# Sun Jun 22 21:23:16 2025 Building RP forest with 11 trees
# Sun Jun 22 21:23:16 2025 NN descent for 14 iterations
# 	 1  /  14
# /home/zz367/miniconda3/envs/wseg_VAE/lib/python3.10/site-packages/umap/umap_.py:1945: UserWarning: n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(f"n_jobs value {self.n_jobs} overridden to 1 by setting random_state. Use no seed for parallelism.")
# 	 2  /  14
# 	 3  /  14
# 	Stopping threshold met -- exiting after 3 iterations
# Sun Jun 22 21:23:16 2025 Finished Nearest Neighbor Search
# Sun Jun 22 21:23:16 2025 Construct embedding
# Epochs completed:   0%|            0/200 [00:00]
# 	completed  0  /  200 epochs
# 	completed  20  /  200 epochs
# 	completed  40  /  200 epochs
# 	completed  60  /  200 epochs
# 	completed  80  /  200 epochs
# 	completed  100  /  200 epochs
# 	completed  120  /  200 epochs
# 	completed  140  /  200 epochs
# 	completed  160  /  200 epochs
# 	completed  180  /  200 epochs
# Sun Jun 22 21:23:23 2025 Finished embedding
# The fraction that are not clustered: 0.6225
# Total number of clusters: 4
# Hopkins metric in UMAP: 0.8410
# Hopkins metric in VAE: 0.8310
# HDBSCAN Silhouette score in UMAP: -0.1711
# HDBSCAN Silhouette score in VAE: -0.0072
# Calinski–Harabasz index in UMAP: 1161.5037
# Calinski–Harabasz index in VAE: 1.1516
# UMAP(angular_rp_forest=True, metric='cosine', min_dist=0, n_jobs=1, n_neighbors=25, random_state=1118, verbose=True)
# Sun Jun 22 21:23:28 2025 Construct fuzzy simplicial set
# Sun Jun 22 21:23:28 2025 Finding Nearest Neighbors
# Sun Jun 22 21:23:28 2025 Building RP forest with 11 trees
# Sun Jun 22 21:23:28 2025 NN descent for 14 iterations
# 	 1  /  14
# /home/zz367/miniconda3/envs/wseg_VAE/lib/python3.10/site-packages/umap/umap_.py:1945: UserWarning: n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(f"n_jobs value {self.n_jobs} overridden to 1 by setting random_state. Use no seed for parallelism.")
# 	 2  /  14
# 	 3  /  14
# 	Stopping threshold met -- exiting after 3 iterations
# Sun Jun 22 21:23:29 2025 Finished Nearest Neighbor Search
# Sun Jun 22 21:23:29 2025 Construct embedding
# Epochs completed:   0%|            0/200 [00:00]
# 	completed  0  /  200 epochs
# 	completed  20  /  200 epochs
# 	completed  40  /  200 epochs
# 	completed  60  /  200 epochs
# 	completed  80  /  200 epochs
# 	completed  100  /  200 epochs
# 	completed  120  /  200 epochs
# 	completed  140  /  200 epochs
# 	completed  160  /  200 epochs
# 	completed  180  /  200 epochs
# Sun Jun 22 21:23:35 2025 Finished embedding
# The fraction that are not clustered: 0.6064
# Total number of clusters: 4
# Hopkins metric in UMAP: 0.8787
# Hopkins metric in VAE: 0.8310
# HDBSCAN Silhouette score in UMAP: -0.1564
# HDBSCAN Silhouette score in VAE: -0.0085
# Calinski–Harabasz index in UMAP: 1238.7309
# Calinski–Harabasz index in VAE: 1.3329
# UMAP(angular_rp_forest=True, metric='cosine', min_dist=0, n_jobs=1, n_neighbors=25, random_state=1118, verbose=True)
# Sun Jun 22 21:23:40 2025 Construct fuzzy simplicial set
# Sun Jun 22 21:23:40 2025 Finding Nearest Neighbors
# Sun Jun 22 21:23:40 2025 Building RP forest with 11 trees
# Sun Jun 22 21:23:40 2025 NN descent for 14 iterations
# 	 1  /  14
# /home/zz367/miniconda3/envs/wseg_VAE/lib/python3.10/site-packages/umap/umap_.py:1945: UserWarning: n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(f"n_jobs value {self.n_jobs} overridden to 1 by setting random_state. Use no seed for parallelism.")
# 	 2  /  14
# 	 3  /  14
# 	Stopping threshold met -- exiting after 3 iterations
# Sun Jun 22 21:23:41 2025 Finished Nearest Neighbor Search
# Sun Jun 22 21:23:41 2025 Construct embedding
# Epochs completed:   0%|            0/200 [00:00]
# 	completed  0  /  200 epochs
# 	completed  20  /  200 epochs
# 	completed  40  /  200 epochs
# 	completed  60  /  200 epochs
# 	completed  80  /  200 epochs
# 	completed  100  /  200 epochs
# 	completed  120  /  200 epochs
# 	completed  140  /  200 epochs
# 	completed  160  /  200 epochs
# 	completed  180  /  200 epochs
# Sun Jun 22 21:23:47 2025 Finished embedding
# The fraction that are not clustered: 0.6257
# Total number of clusters: 2
# Hopkins metric in UMAP: 0.8619
# Hopkins metric in VAE: 0.8310
# HDBSCAN Silhouette score in UMAP: -0.0368
# HDBSCAN Silhouette score in VAE: -0.0025
# Calinski–Harabasz index in UMAP: 1266.1085
# Calinski–Harabasz index in VAE: 1.2107
# UMAP(angular_rp_forest=True, metric='cosine', min_dist=0, n_jobs=1, n_neighbors=25, random_state=1118, verbose=True)
# Sun Jun 22 21:23:52 2025 Construct fuzzy simplicial set
# Sun Jun 22 21:23:53 2025 Finding Nearest Neighbors
# Sun Jun 22 21:23:53 2025 Building RP forest with 11 trees
# Sun Jun 22 21:23:53 2025 NN descent for 14 iterations
# 	 1  /  14
# /home/zz367/miniconda3/envs/wseg_VAE/lib/python3.10/site-packages/umap/umap_.py:1945: UserWarning: n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(f"n_jobs value {self.n_jobs} overridden to 1 by setting random_state. Use no seed for parallelism.")
# 	 2  /  14
# 	 3  /  14
# 	Stopping threshold met -- exiting after 3 iterations
# Sun Jun 22 21:23:53 2025 Finished Nearest Neighbor Search
# Sun Jun 22 21:23:53 2025 Construct embedding
# Epochs completed:   0%|            0/200 [00:00]
# 	completed  0  /  200 epochs
# 	completed  20  /  200 epochs
# 	completed  40  /  200 epochs
# 	completed  60  /  200 epochs
# 	completed  80  /  200 epochs
# 	completed  100  /  200 epochs
# 	completed  120  /  200 epochs
# 	completed  140  /  200 epochs
# 	completed  160  /  200 epochs
# 	completed  180  /  200 epochs
# Sun Jun 22 21:24:00 2025 Finished embedding
# The fraction that are not clustered: 0.6372
# Total number of clusters: 4
# Hopkins metric in UMAP: 0.8566
# Hopkins metric in VAE: 0.8310
# HDBSCAN Silhouette score in UMAP: -0.1587
# HDBSCAN Silhouette score in VAE: -0.0072
# Calinski–Harabasz index in UMAP: 1229.6918
# Calinski–Harabasz index in VAE: 0.7779
# UMAP(angular_rp_forest=True, metric='cosine', min_dist=0, n_jobs=1, n_neighbors=25, random_state=1118, verbose=True)
# Sun Jun 22 21:24:05 2025 Construct fuzzy simplicial set
# Sun Jun 22 21:24:05 2025 Finding Nearest Neighbors
# Sun Jun 22 21:24:05 2025 Building RP forest with 11 trees
# Sun Jun 22 21:24:05 2025 NN descent for 14 iterations
# 	 1  /  14
# /home/zz367/miniconda3/envs/wseg_VAE/lib/python3.10/site-packages/umap/umap_.py:1945: UserWarning: n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(f"n_jobs value {self.n_jobs} overridden to 1 by setting random_state. Use no seed for parallelism.")
# 	 2  /  14
# 	 3  /  14
# 	Stopping threshold met -- exiting after 3 iterations
# Sun Jun 22 21:24:06 2025 Finished Nearest Neighbor Search
# Sun Jun 22 21:24:06 2025 Construct embedding
# Epochs completed:   0%|            0/200 [00:00]
# 	completed  0  /  200 epochs
# 	completed  20  /  200 epochs
# 	completed  40  /  200 epochs
# 	completed  60  /  200 epochs
# 	completed  80  /  200 epochs
# 	completed  100  /  200 epochs
# 	completed  120  /  200 epochs
# 	completed  140  /  200 epochs
# 	completed  160  /  200 epochs
# 	completed  180  /  200 epochs
# Sun Jun 22 21:24:12 2025 Finished embedding
# The fraction that are not clustered: 0.6543
# Total number of clusters: 3
# Hopkins metric in UMAP: 0.8295
# Hopkins metric in VAE: 0.8310
# HDBSCAN Silhouette score in UMAP: -0.1470
# HDBSCAN Silhouette score in VAE: -0.0012
# Calinski–Harabasz index in UMAP: 981.8994
# Calinski–Harabasz index in VAE: 0.9097
# UMAP(angular_rp_forest=True, metric='cosine', min_dist=0, n_jobs=1, n_neighbors=25, random_state=1118, verbose=True)
# Sun Jun 22 21:24:18 2025 Construct fuzzy simplicial set
# Sun Jun 22 21:24:18 2025 Finding Nearest Neighbors
# Sun Jun 22 21:24:18 2025 Building RP forest with 11 trees
# Sun Jun 22 21:24:18 2025 NN descent for 14 iterations
# 	 1  /  14
# /home/zz367/miniconda3/envs/wseg_VAE/lib/python3.10/site-packages/umap/umap_.py:1945: UserWarning: n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(f"n_jobs value {self.n_jobs} overridden to 1 by setting random_state. Use no seed for parallelism.")
# 	 2  /  14
# 	 3  /  14
# 	Stopping threshold met -- exiting after 3 iterations
# Sun Jun 22 21:24:18 2025 Finished Nearest Neighbor Search
# Sun Jun 22 21:24:18 2025 Construct embedding
# Epochs completed:   0%|            0/200 [00:00]
# 	completed  0  /  200 epochs
# 	completed  20  /  200 epochs
# 	completed  40  /  200 epochs
# 	completed  60  /  200 epochs
# 	completed  80  /  200 epochs
# 	completed  100  /  200 epochs
# 	completed  120  /  200 epochs
# 	completed  140  /  200 epochs
# 	completed  160  /  200 epochs
# 	completed  180  /  200 epochs
# Sun Jun 22 21:24:25 2025 Finished embedding
# The fraction that are not clustered: 1.0000
# Total number of clusters: 0
# UMAP(angular_rp_forest=True, metric='cosine', min_dist=0, n_jobs=1, n_neighbors=25, random_state=1118, verbose=True)
# Sun Jun 22 21:24:25 2025 Construct fuzzy simplicial set
# Sun Jun 22 21:24:25 2025 Finding Nearest Neighbors
# Sun Jun 22 21:24:25 2025 Building RP forest with 11 trees
# Sun Jun 22 21:24:25 2025 NN descent for 14 iterations
# 	 1  /  14
# /home/zz367/miniconda3/envs/wseg_VAE/lib/python3.10/site-packages/umap/umap_.py:1945: UserWarning: n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(f"n_jobs value {self.n_jobs} overridden to 1 by setting random_state. Use no seed for parallelism.")
# 	 2  /  14
# 	 3  /  14
# 	Stopping threshold met -- exiting after 3 iterations
# Sun Jun 22 21:24:26 2025 Finished Nearest Neighbor Search
# Sun Jun 22 21:24:26 2025 Construct embedding
# Epochs completed:   0%|            0/200 [00:00]
# 	completed  0  /  200 epochs
# 	completed  20  /  200 epochs
# 	completed  40  /  200 epochs
# 	completed  60  /  200 epochs
# 	completed  80  /  200 epochs
# 	completed  100  /  200 epochs
# 	completed  120  /  200 epochs
# 	completed  140  /  200 epochs
# 	completed  160  /  200 epochs
# 	completed  180  /  200 epochs
# Sun Jun 22 21:24:32 2025 Finished embedding
# The fraction that are not clustered: 0.4984
# Total number of clusters: 2
# Hopkins metric in UMAP: 0.8716
# Hopkins metric in VAE: 0.8310
# HDBSCAN Silhouette score in UMAP: -0.0601
# HDBSCAN Silhouette score in VAE: -0.0026
# Calinski–Harabasz index in UMAP: 637.4507
# Calinski–Harabasz index in VAE: 1.4625
# UMAP(angular_rp_forest=True, metric='cosine', min_dist=0, n_jobs=1, n_neighbors=25, random_state=1118, verbose=True)
# Sun Jun 22 21:24:37 2025 Construct fuzzy simplicial set
# Sun Jun 22 21:24:37 2025 Finding Nearest Neighbors
# Sun Jun 22 21:24:37 2025 Building RP forest with 11 trees
# Sun Jun 22 21:24:37 2025 NN descent for 14 iterations
# 	 1  /  14
# /home/zz367/miniconda3/envs/wseg_VAE/lib/python3.10/site-packages/umap/umap_.py:1945: UserWarning: n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(f"n_jobs value {self.n_jobs} overridden to 1 by setting random_state. Use no seed for parallelism.")
# 	 2  /  14
# 	 3  /  14
# 	Stopping threshold met -- exiting after 3 iterations
# Sun Jun 22 21:24:38 2025 Finished Nearest Neighbor Search
# Sun Jun 22 21:24:38 2025 Construct embedding
# Epochs completed:   0%|            0/200 [00:00]
# 	completed  0  /  200 epochs
# 	completed  20  /  200 epochs
# 	completed  40  /  200 epochs
# 	completed  60  /  200 epochs
# 	completed  80  /  200 epochs
# 	completed  100  /  200 epochs
# 	completed  120  /  200 epochs
# 	completed  140  /  200 epochs
# 	completed  160  /  200 epochs
# 	completed  180  /  200 epochs
# Sun Jun 22 21:24:44 2025 Finished embedding
# The fraction that are not clustered: 0.7127
# Total number of clusters: 2
# Hopkins metric in UMAP: 0.8497
# Hopkins metric in VAE: 0.8310
# HDBSCAN Silhouette score in UMAP: -0.0891
# HDBSCAN Silhouette score in VAE: -0.0015
# Calinski–Harabasz index in UMAP: 1034.6701
# Calinski–Harabasz index in VAE: 0.7338
# UMAP(angular_rp_forest=True, metric='cosine', min_dist=0, n_jobs=1, n_neighbors=25, random_state=1118, verbose=True)
# Sun Jun 22 21:24:49 2025 Construct fuzzy simplicial set
# Sun Jun 22 21:24:49 2025 Finding Nearest Neighbors
# Sun Jun 22 21:24:49 2025 Building RP forest with 11 trees
# Sun Jun 22 21:24:49 2025 NN descent for 14 iterations
# 	 1  /  14
# /home/zz367/miniconda3/envs/wseg_VAE/lib/python3.10/site-packages/umap/umap_.py:1945: UserWarning: n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(f"n_jobs value {self.n_jobs} overridden to 1 by setting random_state. Use no seed for parallelism.")
# 	 2  /  14
# 	 3  /  14
# 	Stopping threshold met -- exiting after 3 iterations
# Sun Jun 22 21:24:50 2025 Finished Nearest Neighbor Search
# Sun Jun 22 21:24:50 2025 Construct embedding
# Epochs completed:   0%|            0/200 [00:00]
# 	completed  0  /  200 epochs
# 	completed  20  /  200 epochs
# 	completed  40  /  200 epochs
# 	completed  60  /  200 epochs
# 	completed  80  /  200 epochs
# 	completed  100  /  200 epochs
# 	completed  120  /  200 epochs
# 	completed  140  /  200 epochs
# 	completed  160  /  200 epochs
# 	completed  180  /  200 epochs
# Sun Jun 22 21:24:57 2025 Finished embedding
# The fraction that are not clustered: 0.5513
# Total number of clusters: 5
# Hopkins metric in UMAP: 0.8612
# Hopkins metric in VAE: 0.8310
# HDBSCAN Silhouette score in UMAP: -0.1415
# HDBSCAN Silhouette score in VAE: -0.0086
# Calinski–Harabasz index in UMAP: 1290.6385
# Calinski–Harabasz index in VAE: 0.9301
# UMAP(angular_rp_forest=True, metric='cosine', min_dist=0, n_jobs=1, n_neighbors=25, random_state=1118, verbose=True)
# Sun Jun 22 21:25:01 2025 Construct fuzzy simplicial set
# Sun Jun 22 21:25:01 2025 Finding Nearest Neighbors
# Sun Jun 22 21:25:01 2025 Building RP forest with 11 trees
# Sun Jun 22 21:25:02 2025 NN descent for 14 iterations
# 	 1  /  14
# /home/zz367/miniconda3/envs/wseg_VAE/lib/python3.10/site-packages/umap/umap_.py:1945: UserWarning: n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(f"n_jobs value {self.n_jobs} overridden to 1 by setting random_state. Use no seed for parallelism.")
# 	 2  /  14
# 	 3  /  14
# 	Stopping threshold met -- exiting after 3 iterations
# Sun Jun 22 21:25:02 2025 Finished Nearest Neighbor Search
# Sun Jun 22 21:25:02 2025 Construct embedding
# Epochs completed:   0%|            0/200 [00:00]
# 	completed  0  /  200 epochs
# 	completed  20  /  200 epochs
# 	completed  40  /  200 epochs
# 	completed  60  /  200 epochs
# 	completed  80  /  200 epochs
# 	completed  100  /  200 epochs
# 	completed  120  /  200 epochs
# 	completed  140  /  200 epochs
# 	completed  160  /  200 epochs
# 	completed  180  /  200 epochs
# Sun Jun 22 21:25:09 2025 Finished embedding
# The fraction that are not clustered: 0.4629
# Total number of clusters: 3
# Hopkins metric in UMAP: 0.8469
# Hopkins metric in VAE: 0.8310
# HDBSCAN Silhouette score in UMAP: -0.0085
# HDBSCAN Silhouette score in VAE: -0.0035
# Calinski–Harabasz index in UMAP: 2092.2446
# Calinski–Harabasz index in VAE: 0.9453
# UMAP(angular_rp_forest=True, metric='cosine', min_dist=0, n_jobs=1, n_neighbors=25, random_state=1118, verbose=True)
# Sun Jun 22 21:25:14 2025 Construct fuzzy simplicial set
# Sun Jun 22 21:25:14 2025 Finding Nearest Neighbors
# Sun Jun 22 21:25:14 2025 Building RP forest with 11 trees
# Sun Jun 22 21:25:14 2025 NN descent for 14 iterations
# 	 1  /  14
# /home/zz367/miniconda3/envs/wseg_VAE/lib/python3.10/site-packages/umap/umap_.py:1945: UserWarning: n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(f"n_jobs value {self.n_jobs} overridden to 1 by setting random_state. Use no seed for parallelism.")
# 	 2  /  14
# 	 3  /  14
# 	Stopping threshold met -- exiting after 3 iterations
# Sun Jun 22 21:25:15 2025 Finished Nearest Neighbor Search
# Sun Jun 22 21:25:15 2025 Construct embedding
# Epochs completed:   0%|            0/200 [00:00]
# 	completed  0  /  200 epochs
# 	completed  20  /  200 epochs
# 	completed  40  /  200 epochs
# 	completed  60  /  200 epochs
# 	completed  80  /  200 epochs
# 	completed  100  /  200 epochs
# 	completed  120  /  200 epochs
# 	completed  140  /  200 epochs
# 	completed  160  /  200 epochs
# 	completed  180  /  200 epochs
# Sun Jun 22 21:25:21 2025 Finished embedding
# The fraction that are not clustered: 0.5955
# Total number of clusters: 3
# Hopkins metric in UMAP: 0.8494
# Hopkins metric in VAE: 0.8310
# HDBSCAN Silhouette score in UMAP: -0.0932
# HDBSCAN Silhouette score in VAE: -0.0055
# Calinski–Harabasz index in UMAP: 1337.3229
# Calinski–Harabasz index in VAE: 1.4186
# UMAP(angular_rp_forest=True, metric='cosine', min_dist=0, n_jobs=1, n_neighbors=25, random_state=1118, verbose=True)
# Sun Jun 22 21:25:26 2025 Construct fuzzy simplicial set
# Sun Jun 22 21:25:26 2025 Finding Nearest Neighbors
# Sun Jun 22 21:25:26 2025 Building RP forest with 11 trees
# Sun Jun 22 21:25:26 2025 NN descent for 14 iterations
# 	 1  /  14
# /home/zz367/miniconda3/envs/wseg_VAE/lib/python3.10/site-packages/umap/umap_.py:1945: UserWarning: n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(f"n_jobs value {self.n_jobs} overridden to 1 by setting random_state. Use no seed for parallelism.")
# 	 2  /  14
# 	 3  /  14
# 	Stopping threshold met -- exiting after 3 iterations
# Sun Jun 22 21:25:27 2025 Finished Nearest Neighbor Search
# Sun Jun 22 21:25:27 2025 Construct embedding
# Epochs completed:   0%|            0/200 [00:00]
# 	completed  0  /  200 epochs
# 	completed  20  /  200 epochs
# 	completed  40  /  200 epochs
# 	completed  60  /  200 epochs
# 	completed  80  /  200 epochs
# 	completed  100  /  200 epochs
# 	completed  120  /  200 epochs
# 	completed  140  /  200 epochs
# 	completed  160  /  200 epochs
# 	completed  180  /  200 epochs
# Sun Jun 22 21:25:33 2025 Finished embedding
# The fraction that are not clustered: 0.4747
# Total number of clusters: 3
# Hopkins metric in UMAP: 0.8741
# Hopkins metric in VAE: 0.8310
# HDBSCAN Silhouette score in UMAP: -0.0143
# HDBSCAN Silhouette score in VAE: -0.0035
# Calinski–Harabasz index in UMAP: 2005.7931
# Calinski–Harabasz index in VAE: 0.9683
# UMAP(angular_rp_forest=True, metric='cosine', min_dist=0, n_jobs=1, n_neighbors=25, random_state=1118, verbose=True)
# Sun Jun 22 21:25:38 2025 Construct fuzzy simplicial set
# Sun Jun 22 21:25:38 2025 Finding Nearest Neighbors
# Sun Jun 22 21:25:38 2025 Building RP forest with 11 trees
# Sun Jun 22 21:25:38 2025 NN descent for 14 iterations
# 	 1  /  14
# /home/zz367/miniconda3/envs/wseg_VAE/lib/python3.10/site-packages/umap/umap_.py:1945: UserWarning: n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(f"n_jobs value {self.n_jobs} overridden to 1 by setting random_state. Use no seed for parallelism.")
# 	 2  /  14
# 	 3  /  14
# 	Stopping threshold met -- exiting after 3 iterations
# Sun Jun 22 21:25:39 2025 Finished Nearest Neighbor Search
# Sun Jun 22 21:25:39 2025 Construct embedding
# Epochs completed:   0%|            0/200 [00:00]
# 	completed  0  /  200 epochs
# 	completed  20  /  200 epochs
# 	completed  40  /  200 epochs
# 	completed  60  /  200 epochs
# 	completed  80  /  200 epochs
# 	completed  100  /  200 epochs
# 	completed  120  /  200 epochs
# 	completed  140  /  200 epochs
# 	completed  160  /  200 epochs
# 	completed  180  /  200 epochs
# Sun Jun 22 21:25:45 2025 Finished embedding
# The fraction that are not clustered: 0.5648
# Total number of clusters: 3
# Hopkins metric in UMAP: 0.8568
# Hopkins metric in VAE: 0.8310
# HDBSCAN Silhouette score in UMAP: -0.1029
# HDBSCAN Silhouette score in VAE: -0.0051
# Calinski–Harabasz index in UMAP: 1279.9789
# Calinski–Harabasz index in VAE: 0.8615
# UMAP(angular_rp_forest=True, metric='cosine', min_dist=0, n_jobs=1, n_neighbors=25, random_state=1118, verbose=True)
# Sun Jun 22 21:25:50 2025 Construct fuzzy simplicial set
# Sun Jun 22 21:25:50 2025 Finding Nearest Neighbors
# Sun Jun 22 21:25:50 2025 Building RP forest with 11 trees
# Sun Jun 22 21:25:50 2025 NN descent for 14 iterations
# 	 1  /  14
# /home/zz367/miniconda3/envs/wseg_VAE/lib/python3.10/site-packages/umap/umap_.py:1945: UserWarning: n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(f"n_jobs value {self.n_jobs} overridden to 1 by setting random_state. Use no seed for parallelism.")
# 	 2  /  14
# 	 3  /  14
# 	Stopping threshold met -- exiting after 3 iterations
# Sun Jun 22 21:25:51 2025 Finished Nearest Neighbor Search
# Sun Jun 22 21:25:51 2025 Construct embedding
# Epochs completed:   0%|            0/200 [00:00]
# 	completed  0  /  200 epochs
# 	completed  20  /  200 epochs
# 	completed  40  /  200 epochs
# 	completed  60  /  200 epochs
# 	completed  80  /  200 epochs
# 	completed  100  /  200 epochs
# 	completed  120  /  200 epochs
# 	completed  140  /  200 epochs
# 	completed  160  /  200 epochs
# 	completed  180  /  200 epochs
# Sun Jun 22 21:25:57 2025 Finished embedding
# The fraction that are not clustered: 0.4914
# Total number of clusters: 2
# Hopkins metric in UMAP: 0.8337
# Hopkins metric in VAE: 0.8310
# HDBSCAN Silhouette score in UMAP: 0.0248
# HDBSCAN Silhouette score in VAE: -0.0026
# Calinski–Harabasz index in UMAP: 1846.8928
# Calinski–Harabasz index in VAE: 1.6515
# UMAP(angular_rp_forest=True, metric='cosine', min_dist=0, n_jobs=1, n_neighbors=25, random_state=1118, verbose=True)
# Sun Jun 22 21:26:02 2025 Construct fuzzy simplicial set
# Sun Jun 22 21:26:02 2025 Finding Nearest Neighbors
# Sun Jun 22 21:26:02 2025 Building RP forest with 11 trees
# Sun Jun 22 21:26:02 2025 NN descent for 14 iterations
# 	 1  /  14
# /home/zz367/miniconda3/envs/wseg_VAE/lib/python3.10/site-packages/umap/umap_.py:1945: UserWarning: n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(f"n_jobs value {self.n_jobs} overridden to 1 by setting random_state. Use no seed for parallelism.")
# 	 2  /  14
# 	 3  /  14
# 	Stopping threshold met -- exiting after 3 iterations
# Sun Jun 22 21:26:03 2025 Finished Nearest Neighbor Search
# Sun Jun 22 21:26:03 2025 Construct embedding
# Epochs completed:   0%|            0/200 [00:00]
# 	completed  0  /  200 epochs
# 	completed  20  /  200 epochs
# 	completed  40  /  200 epochs
# 	completed  60  /  200 epochs
# 	completed  80  /  200 epochs
# 	completed  100  /  200 epochs
# 	completed  120  /  200 epochs
# 	completed  140  /  200 epochs
# 	completed  160  /  200 epochs
# 	completed  180  /  200 epochs
# Sun Jun 22 21:26:09 2025 Finished embedding
# The fraction that are not clustered: 0.6512
# Total number of clusters: 4
# Hopkins metric in UMAP: 0.8659
# Hopkins metric in VAE: 0.8310
# HDBSCAN Silhouette score in UMAP: -0.1804
# HDBSCAN Silhouette score in VAE: -0.0083
# Calinski–Harabasz index in UMAP: 1021.6221
# Calinski–Harabasz index in VAE: 0.8797
# UMAP(angular_rp_forest=True, metric='cosine', min_dist=0, n_jobs=1, n_neighbors=25, random_state=1118, verbose=True)
# Sun Jun 22 21:26:14 2025 Construct fuzzy simplicial set
# Sun Jun 22 21:26:14 2025 Finding Nearest Neighbors
# Sun Jun 22 21:26:14 2025 Building RP forest with 11 trees
# Sun Jun 22 21:26:15 2025 NN descent for 14 iterations
# 	 1  /  14
# /home/zz367/miniconda3/envs/wseg_VAE/lib/python3.10/site-packages/umap/umap_.py:1945: UserWarning: n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(f"n_jobs value {self.n_jobs} overridden to 1 by setting random_state. Use no seed for parallelism.")
# 	 2  /  14
# 	 3  /  14
# 	Stopping threshold met -- exiting after 3 iterations
# Sun Jun 22 21:26:15 2025 Finished Nearest Neighbor Search
# Sun Jun 22 21:26:15 2025 Construct embedding
# Epochs completed:   0%|            0/200 [00:00]
# 	completed  0  /  200 epochs
# 	completed  20  /  200 epochs
# 	completed  40  /  200 epochs
# 	completed  60  /  200 epochs
# 	completed  80  /  200 epochs
# 	completed  100  /  200 epochs
# 	completed  120  /  200 epochs
# 	completed  140  /  200 epochs
# 	completed  160  /  200 epochs
# 	completed  180  /  200 epochs
# Sun Jun 22 21:26:22 2025 Finished embedding
# The fraction that are not clustered: 0.7808
# Total number of clusters: 2
# Hopkins metric in UMAP: 0.8365
# Hopkins metric in VAE: 0.8310
# HDBSCAN Silhouette score in UMAP: -0.0574
# HDBSCAN Silhouette score in VAE: -0.0047
# Calinski–Harabasz index in UMAP: 1507.4448
# Calinski–Harabasz index in VAE: 0.6888
# UMAP(angular_rp_forest=True, metric='cosine', min_dist=0, n_jobs=1, n_neighbors=25, random_state=1118, verbose=True)
# Sun Jun 22 21:26:27 2025 Construct fuzzy simplicial set
# Sun Jun 22 21:26:27 2025 Finding Nearest Neighbors
# Sun Jun 22 21:26:27 2025 Building RP forest with 11 trees
# Sun Jun 22 21:26:27 2025 NN descent for 14 iterations
# 	 1  /  14
# /home/zz367/miniconda3/envs/wseg_VAE/lib/python3.10/site-packages/umap/umap_.py:1945: UserWarning: n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(f"n_jobs value {self.n_jobs} overridden to 1 by setting random_state. Use no seed for parallelism.")
# 	 2  /  14
# 	 3  /  14
# 	Stopping threshold met -- exiting after 3 iterations
# Sun Jun 22 21:26:28 2025 Finished Nearest Neighbor Search
# Sun Jun 22 21:26:28 2025 Construct embedding
# Epochs completed:   0%|            0/200 [00:00]
# 	completed  0  /  200 epochs
# 	completed  20  /  200 epochs
# 	completed  40  /  200 epochs
# 	completed  60  /  200 epochs
# 	completed  80  /  200 epochs
# 	completed  100  /  200 epochs
# 	completed  120  /  200 epochs
# 	completed  140  /  200 epochs
# 	completed  160  /  200 epochs
# 	completed  180  /  200 epochs
# Sun Jun 22 21:26:34 2025 Finished embedding
# The fraction that are not clustered: 0.7048
# Total number of clusters: 3
# Hopkins metric in UMAP: 0.8724
# Hopkins metric in VAE: 0.8310
# HDBSCAN Silhouette score in UMAP: -0.1490
# HDBSCAN Silhouette score in VAE: -0.0054
# Calinski–Harabasz index in UMAP: 762.3039
# Calinski–Harabasz index in VAE: 1.0339
# UMAP(angular_rp_forest=True, metric='cosine', min_dist=0, n_jobs=1, n_neighbors=25, random_state=1118, verbose=True)
# Sun Jun 22 21:26:39 2025 Construct fuzzy simplicial set
# Sun Jun 22 21:26:39 2025 Finding Nearest Neighbors
# Sun Jun 22 21:26:39 2025 Building RP forest with 11 trees
# Sun Jun 22 21:26:40 2025 NN descent for 14 iterations
# 	 1  /  14
# /home/zz367/miniconda3/envs/wseg_VAE/lib/python3.10/site-packages/umap/umap_.py:1945: UserWarning: n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(f"n_jobs value {self.n_jobs} overridden to 1 by setting random_state. Use no seed for parallelism.")
# 	 2  /  14
# 	 3  /  14
# 	Stopping threshold met -- exiting after 3 iterations
# Sun Jun 22 21:26:40 2025 Finished Nearest Neighbor Search
# Sun Jun 22 21:26:40 2025 Construct embedding
# Epochs completed:   0%|            0/200 [00:00]
# 	completed  0  /  200 epochs
# 	completed  20  /  200 epochs
# 	completed  40  /  200 epochs
# 	completed  60  /  200 epochs
# 	completed  80  /  200 epochs
# 	completed  100  /  200 epochs
# 	completed  120  /  200 epochs
# 	completed  140  /  200 epochs
# 	completed  160  /  200 epochs
# 	completed  180  /  200 epochs
# Sun Jun 22 21:26:47 2025 Finished embedding
# The fraction that are not clustered: 0.3662
# Total number of clusters: 2
# Hopkins metric in UMAP: 0.8512
# Hopkins metric in VAE: 0.8310
# HDBSCAN Silhouette score in UMAP: -0.0753
# HDBSCAN Silhouette score in VAE: -0.0007
# Calinski–Harabasz index in UMAP: 525.1898
# Calinski–Harabasz index in VAE: 0.9105
# UMAP(angular_rp_forest=True, metric='cosine', min_dist=0, n_jobs=1, n_neighbors=25, random_state=1118, verbose=True)
# Sun Jun 22 21:26:52 2025 Construct fuzzy simplicial set
# Sun Jun 22 21:26:52 2025 Finding Nearest Neighbors
# Sun Jun 22 21:26:52 2025 Building RP forest with 11 trees
# Sun Jun 22 21:26:52 2025 NN descent for 14 iterations
# 	 1  /  14
# /home/zz367/miniconda3/envs/wseg_VAE/lib/python3.10/site-packages/umap/umap_.py:1945: UserWarning: n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(f"n_jobs value {self.n_jobs} overridden to 1 by setting random_state. Use no seed for parallelism.")
# 	 2  /  14
# 	 3  /  14
# 	Stopping threshold met -- exiting after 3 iterations
# Sun Jun 22 21:26:53 2025 Finished Nearest Neighbor Search
# Sun Jun 22 21:26:53 2025 Construct embedding
# Epochs completed:   0%|            0/200 [00:00]
# 	completed  0  /  200 epochs
# 	completed  20  /  200 epochs
# 	completed  40  /  200 epochs
# 	completed  60  /  200 epochs
# 	completed  80  /  200 epochs
# 	completed  100  /  200 epochs
# 	completed  120  /  200 epochs
# 	completed  140  /  200 epochs
# 	completed  160  /  200 epochs
# 	completed  180  /  200 epochs
# Sun Jun 22 21:26:59 2025 Finished embedding
# The fraction that are not clustered: 0.5974
# Total number of clusters: 3
# Hopkins metric in UMAP: 0.8945
# Hopkins metric in VAE: 0.8310
# HDBSCAN Silhouette score in UMAP: -0.0844
# HDBSCAN Silhouette score in VAE: -0.0052
# Calinski–Harabasz index in UMAP: 1487.1608
# Calinski–Harabasz index in VAE: 0.9161
# UMAP(angular_rp_forest=True, metric='cosine', min_dist=0, n_jobs=1, n_neighbors=25, random_state=1118, verbose=True)
# Sun Jun 22 21:27:04 2025 Construct fuzzy simplicial set
# Sun Jun 22 21:27:04 2025 Finding Nearest Neighbors
# Sun Jun 22 21:27:04 2025 Building RP forest with 11 trees
# Sun Jun 22 21:27:04 2025 NN descent for 14 iterations
# 	 1  /  14
# /home/zz367/miniconda3/envs/wseg_VAE/lib/python3.10/site-packages/umap/umap_.py:1945: UserWarning: n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(f"n_jobs value {self.n_jobs} overridden to 1 by setting random_state. Use no seed for parallelism.")
# 	 2  /  14
# 	 3  /  14
# 	Stopping threshold met -- exiting after 3 iterations
# Sun Jun 22 21:27:05 2025 Finished Nearest Neighbor Search
# Sun Jun 22 21:27:05 2025 Construct embedding
# Epochs completed:   0%|            0/200 [00:00]
# 	completed  0  /  200 epochs
# 	completed  20  /  200 epochs
# 	completed  40  /  200 epochs
# 	completed  60  /  200 epochs
# 	completed  80  /  200 epochs
# 	completed  100  /  200 epochs
# 	completed  120  /  200 epochs
# 	completed  140  /  200 epochs
# 	completed  160  /  200 epochs
# 	completed  180  /  200 epochs
# Sun Jun 22 21:27:12 2025 Finished embedding
# The fraction that are not clustered: 0.6406
# Total number of clusters: 4
# Hopkins metric in UMAP: 0.8774
# Hopkins metric in VAE: 0.8310
# HDBSCAN Silhouette score in UMAP: -0.1365
# HDBSCAN Silhouette score in VAE: -0.0094
# Calinski–Harabasz index in UMAP: 1328.5755
# Calinski–Harabasz index in VAE: 1.0045
# UMAP(angular_rp_forest=True, metric='cosine', min_dist=0, n_jobs=1, n_neighbors=25, random_state=1118, verbose=True)
# Sun Jun 22 21:27:17 2025 Construct fuzzy simplicial set
# Sun Jun 22 21:27:17 2025 Finding Nearest Neighbors
# Sun Jun 22 21:27:17 2025 Building RP forest with 11 trees
# Sun Jun 22 21:27:17 2025 NN descent for 14 iterations
# 	 1  /  14
# /home/zz367/miniconda3/envs/wseg_VAE/lib/python3.10/site-packages/umap/umap_.py:1945: UserWarning: n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(f"n_jobs value {self.n_jobs} overridden to 1 by setting random_state. Use no seed for parallelism.")
# 	 2  /  14
# 	 3  /  14
# 	Stopping threshold met -- exiting after 3 iterations
# Sun Jun 22 21:27:17 2025 Finished Nearest Neighbor Search
# Sun Jun 22 21:27:18 2025 Construct embedding
# Epochs completed:   0%|            0/200 [00:00]
# 	completed  0  /  200 epochs
# 	completed  20  /  200 epochs
# 	completed  40  /  200 epochs
# 	completed  60  /  200 epochs
# 	completed  80  /  200 epochs
# 	completed  100  /  200 epochs
# 	completed  120  /  200 epochs
# 	completed  140  /  200 epochs
# 	completed  160  /  200 epochs
# 	completed  180  /  200 epochs
# Sun Jun 22 21:27:24 2025 Finished embedding
# The fraction that are not clustered: 0.5911
# Total number of clusters: 4
# Hopkins metric in UMAP: 0.8130
# Hopkins metric in VAE: 0.8310
# HDBSCAN Silhouette score in UMAP: -0.0994
# HDBSCAN Silhouette score in VAE: -0.0031
# Calinski–Harabasz index in UMAP: 1560.4039
# Calinski–Harabasz index in VAE: 1.1009
# UMAP(angular_rp_forest=True, metric='cosine', min_dist=0, n_jobs=1, n_neighbors=25, random_state=1118, verbose=True)
# Sun Jun 22 21:27:29 2025 Construct fuzzy simplicial set
# Sun Jun 22 21:27:29 2025 Finding Nearest Neighbors
# Sun Jun 22 21:27:29 2025 Building RP forest with 11 trees
# Sun Jun 22 21:27:29 2025 NN descent for 14 iterations
# 	 1  /  14
# /home/zz367/miniconda3/envs/wseg_VAE/lib/python3.10/site-packages/umap/umap_.py:1945: UserWarning: n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(f"n_jobs value {self.n_jobs} overridden to 1 by setting random_state. Use no seed for parallelism.")
# 	 2  /  14
# 	 3  /  14
# 	Stopping threshold met -- exiting after 3 iterations
# Sun Jun 22 21:27:30 2025 Finished Nearest Neighbor Search
# Sun Jun 22 21:27:30 2025 Construct embedding
# Epochs completed:   0%|            0/200 [00:00]
# 	completed  0  /  200 epochs
# 	completed  20  /  200 epochs
# 	completed  40  /  200 epochs
# 	completed  60  /  200 epochs
# 	completed  80  /  200 epochs
# 	completed  100  /  200 epochs
# 	completed  120  /  200 epochs
# 	completed  140  /  200 epochs
# 	completed  160  /  200 epochs
# 	completed  180  /  200 epochs
# Sun Jun 22 21:27:36 2025 Finished embedding
# The fraction that are not clustered: 0.5937
# Total number of clusters: 4
# Hopkins metric in UMAP: 0.8744
# Hopkins metric in VAE: 0.8310
# HDBSCAN Silhouette score in UMAP: -0.1178
# HDBSCAN Silhouette score in VAE: -0.0112
# Calinski–Harabasz index in UMAP: 1629.7695
# Calinski–Harabasz index in VAE: 0.8149
# UMAP(angular_rp_forest=True, metric='cosine', min_dist=0, n_jobs=1, n_neighbors=25, random_state=1118, verbose=True)
# Sun Jun 22 21:27:41 2025 Construct fuzzy simplicial set
# Sun Jun 22 21:27:41 2025 Finding Nearest Neighbors
# Sun Jun 22 21:27:41 2025 Building RP forest with 11 trees
# Sun Jun 22 21:27:41 2025 NN descent for 14 iterations
# 	 1  /  14
# /home/zz367/miniconda3/envs/wseg_VAE/lib/python3.10/site-packages/umap/umap_.py:1945: UserWarning: n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(f"n_jobs value {self.n_jobs} overridden to 1 by setting random_state. Use no seed for parallelism.")
# 	 2  /  14
# 	 3  /  14
# 	Stopping threshold met -- exiting after 3 iterations
# Sun Jun 22 21:27:42 2025 Finished Nearest Neighbor Search
# Sun Jun 22 21:27:42 2025 Construct embedding
# Epochs completed:   0%|            0/200 [00:00]
# 	completed  0  /  200 epochs
# 	completed  20  /  200 epochs
# 	completed  40  /  200 epochs
# 	completed  60  /  200 epochs
# 	completed  80  /  200 epochs
# 	completed  100  /  200 epochs
# 	completed  120  /  200 epochs
# 	completed  140  /  200 epochs
# 	completed  160  /  200 epochs
# 	completed  180  /  200 epochs
# Sun Jun 22 21:27:48 2025 Finished embedding
# The fraction that are not clustered: 0.7464
# Total number of clusters: 3
# Hopkins metric in UMAP: 0.8522
# ...
#   warn(f"n_jobs value {self.n_jobs} overridden to 1 by setting random_state. Use no seed for parallelism.")
# 	 2  /  14
# 	 3  /  14
# 	Stopping threshold met -- exiting after 3 iterations
# Sun Jun 22 21:59:54 2025 Finished Nearest Neighbor Search
# Sun Jun 22 21:59:54 2025 Construct embedding
# Epochs completed:   0%|            0/200 [00:00]
# 	completed  0  /  200 epochs
# 	completed  20  /  200 epochs
# 	completed  40  /  200 epochs
# 	completed  60  /  200 epochs
# 	completed  80  /  200 epochs
# 	completed  100  /  200 epochs
# 	completed  120  /  200 epochs
# 	completed  140  /  200 epochs
# 	completed  160  /  200 epochs
# 	completed  180  /  200 epochs
# Sun Jun 22 22:00:01 2025 Finished embedding
# The fraction that are not clustered: 0.4823
# Total number of clusters: 4
# Hopkins metric in UMAP: 0.8610
# Hopkins metric in VAE: 0.8310
# HDBSCAN Silhouette score in UMAP: -0.0397
# HDBSCAN Silhouette score in VAE: -0.0077
# Calinski–Harabasz index in UMAP: 2270.1068
# Calinski–Harabasz index in VAE: 1.5519
# UMAP(angular_rp_forest=True, metric='cosine', min_dist=0, n_jobs=1, n_neighbors=25, random_state=1118, verbose=True)
# Sun Jun 22 22:00:06 2025 Construct fuzzy simplicial set
# Sun Jun 22 22:00:06 2025 Finding Nearest Neighbors
# Sun Jun 22 22:00:06 2025 Building RP forest with 11 trees
# Sun Jun 22 22:00:06 2025 NN descent for 14 iterations
# 	 1  /  14
# /home/zz367/miniconda3/envs/wseg_VAE/lib/python3.10/site-packages/umap/umap_.py:1945: UserWarning: n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(f"n_jobs value {self.n_jobs} overridden to 1 by setting random_state. Use no seed for parallelism.")
# 	 2  /  14
# 	 3  /  14
# 	Stopping threshold met -- exiting after 3 iterations
# Sun Jun 22 22:00:07 2025 Finished Nearest Neighbor Search
# Sun Jun 22 22:00:07 2025 Construct embedding
# Epochs completed:   0%|            0/200 [00:00]
# 	completed  0  /  200 epochs
# 	completed  20  /  200 epochs
# 	completed  40  /  200 epochs
# 	completed  60  /  200 epochs
# 	completed  80  /  200 epochs
# 	completed  100  /  200 epochs
# 	completed  120  /  200 epochs
# 	completed  140  /  200 epochs
# 	completed  160  /  200 epochs
# 	completed  180  /  200 epochs
# Sun Jun 22 22:00:13 2025 Finished embedding
# The fraction that are not clustered: 0.6089
# Total number of clusters: 2
# Hopkins metric in UMAP: 0.8188
# Hopkins metric in VAE: 0.8310
# HDBSCAN Silhouette score in UMAP: -0.0682
# HDBSCAN Silhouette score in VAE: -0.0055
# Calinski–Harabasz index in UMAP: 1065.9602
# Calinski–Harabasz index in VAE: 1.5692
# UMAP(angular_rp_forest=True, metric='cosine', min_dist=0, n_jobs=1, n_neighbors=25, random_state=1118, verbose=True)
# Sun Jun 22 22:00:18 2025 Construct fuzzy simplicial set
# Sun Jun 22 22:00:18 2025 Finding Nearest Neighbors
# Sun Jun 22 22:00:18 2025 Building RP forest with 11 trees
# Sun Jun 22 22:00:18 2025 NN descent for 14 iterations
# 	 1  /  14
# /home/zz367/miniconda3/envs/wseg_VAE/lib/python3.10/site-packages/umap/umap_.py:1945: UserWarning: n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(f"n_jobs value {self.n_jobs} overridden to 1 by setting random_state. Use no seed for parallelism.")
# 	 2  /  14
# 	 3  /  14
# 	Stopping threshold met -- exiting after 3 iterations
# Sun Jun 22 22:00:19 2025 Finished Nearest Neighbor Search
# Sun Jun 22 22:00:19 2025 Construct embedding
# Epochs completed:   0%|            0/200 [00:00]
# 	completed  0  /  200 epochs
# 	completed  20  /  200 epochs
# 	completed  40  /  200 epochs
# 	completed  60  /  200 epochs
# 	completed  80  /  200 epochs
# 	completed  100  /  200 epochs
# 	completed  120  /  200 epochs
# 	completed  140  /  200 epochs
# 	completed  160  /  200 epochs
# 	completed  180  /  200 epochs
# Sun Jun 22 22:00:25 2025 Finished embedding
# The fraction that are not clustered: 0.6932
# Total number of clusters: 4
# Hopkins metric in UMAP: 0.8407
# Hopkins metric in VAE: 0.8310
# HDBSCAN Silhouette score in UMAP: -0.1881
# HDBSCAN Silhouette score in VAE: -0.0044
# Calinski–Harabasz index in UMAP: 1269.5961
# Calinski–Harabasz index in VAE: 0.7777
# UMAP(angular_rp_forest=True, metric='cosine', min_dist=0, n_jobs=1, n_neighbors=25, random_state=1118, verbose=True)
# Sun Jun 22 22:00:31 2025 Construct fuzzy simplicial set
# Sun Jun 22 22:00:31 2025 Finding Nearest Neighbors
# Sun Jun 22 22:00:31 2025 Building RP forest with 11 trees
# Sun Jun 22 22:00:31 2025 NN descent for 14 iterations
# 	 1  /  14
# /home/zz367/miniconda3/envs/wseg_VAE/lib/python3.10/site-packages/umap/umap_.py:1945: UserWarning: n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(f"n_jobs value {self.n_jobs} overridden to 1 by setting random_state. Use no seed for parallelism.")
# 	 2  /  14
# 	 3  /  14
# 	Stopping threshold met -- exiting after 3 iterations
# Sun Jun 22 22:00:31 2025 Finished Nearest Neighbor Search
# Sun Jun 22 22:00:31 2025 Construct embedding
# Epochs completed:   0%|            0/200 [00:00]
# 	completed  0  /  200 epochs
# 	completed  20  /  200 epochs
# 	completed  40  /  200 epochs
# 	completed  60  /  200 epochs
# 	completed  80  /  200 epochs
# 	completed  100  /  200 epochs
# 	completed  120  /  200 epochs
# 	completed  140  /  200 epochs
# 	completed  160  /  200 epochs
# 	completed  180  /  200 epochs
# Sun Jun 22 22:00:38 2025 Finished embedding
# The fraction that are not clustered: 0.5175
# Total number of clusters: 4
# Hopkins metric in UMAP: 0.8038
# Hopkins metric in VAE: 0.8310
# HDBSCAN Silhouette score in UMAP: -0.0795
# HDBSCAN Silhouette score in VAE: -0.0046
# Calinski–Harabasz index in UMAP: 1805.2146
# Calinski–Harabasz index in VAE: 0.8732
# UMAP(angular_rp_forest=True, metric='cosine', min_dist=0, n_jobs=1, n_neighbors=25, random_state=1118, verbose=True)
# Sun Jun 22 22:00:43 2025 Construct fuzzy simplicial set
# Sun Jun 22 22:00:43 2025 Finding Nearest Neighbors
# Sun Jun 22 22:00:43 2025 Building RP forest with 11 trees
# Sun Jun 22 22:00:43 2025 NN descent for 14 iterations
# 	 1  /  14
# /home/zz367/miniconda3/envs/wseg_VAE/lib/python3.10/site-packages/umap/umap_.py:1945: UserWarning: n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(f"n_jobs value {self.n_jobs} overridden to 1 by setting random_state. Use no seed for parallelism.")
# 	 2  /  14
# 	 3  /  14
# 	Stopping threshold met -- exiting after 3 iterations
# Sun Jun 22 22:00:44 2025 Finished Nearest Neighbor Search
# Sun Jun 22 22:00:44 2025 Construct embedding
# Epochs completed:   0%|            0/200 [00:00]
# 	completed  0  /  200 epochs
# 	completed  20  /  200 epochs
# 	completed  40  /  200 epochs
# 	completed  60  /  200 epochs
# 	completed  80  /  200 epochs
# 	completed  100  /  200 epochs
# 	completed  120  /  200 epochs
# 	completed  140  /  200 epochs
# 	completed  160  /  200 epochs
# 	completed  180  /  200 epochs
# Sun Jun 22 22:00:50 2025 Finished embedding
# The fraction that are not clustered: 0.4846
# Total number of clusters: 4
# Hopkins metric in UMAP: 0.8383
# Hopkins metric in VAE: 0.8310
# HDBSCAN Silhouette score in UMAP: -0.0152
# HDBSCAN Silhouette score in VAE: -0.0086
# Calinski–Harabasz index in UMAP: 2286.4736
# Calinski–Harabasz index in VAE: 1.1934
# UMAP(angular_rp_forest=True, metric='cosine', min_dist=0, n_jobs=1, n_neighbors=25, random_state=1118, verbose=True)
# Sun Jun 22 22:00:55 2025 Construct fuzzy simplicial set
# Sun Jun 22 22:00:55 2025 Finding Nearest Neighbors
# Sun Jun 22 22:00:55 2025 Building RP forest with 11 trees
# Sun Jun 22 22:00:56 2025 NN descent for 14 iterations
# 	 1  /  14
# /home/zz367/miniconda3/envs/wseg_VAE/lib/python3.10/site-packages/umap/umap_.py:1945: UserWarning: n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(f"n_jobs value {self.n_jobs} overridden to 1 by setting random_state. Use no seed for parallelism.")
# 	 2  /  14
# 	 3  /  14
# 	Stopping threshold met -- exiting after 3 iterations
# Sun Jun 22 22:00:56 2025 Finished Nearest Neighbor Search
# Sun Jun 22 22:00:56 2025 Construct embedding
# Epochs completed:   0%|            0/200 [00:00]
# 	completed  0  /  200 epochs
# 	completed  20  /  200 epochs
# 	completed  40  /  200 epochs
# 	completed  60  /  200 epochs
# 	completed  80  /  200 epochs
# 	completed  100  /  200 epochs
# 	completed  120  /  200 epochs
# 	completed  140  /  200 epochs
# 	completed  160  /  200 epochs
# 	completed  180  /  200 epochs
# Sun Jun 22 22:01:03 2025 Finished embedding
# The fraction that are not clustered: 0.4948
# Total number of clusters: 4
# Hopkins metric in UMAP: 0.8125
# Hopkins metric in VAE: 0.8310
# HDBSCAN Silhouette score in UMAP: -0.0693
# HDBSCAN Silhouette score in VAE: -0.0062
# Calinski–Harabasz index in UMAP: 1812.7989
# Calinski–Harabasz index in VAE: 1.1978
# UMAP(angular_rp_forest=True, metric='cosine', min_dist=0, n_jobs=1, n_neighbors=25, random_state=1118, verbose=True)
# Sun Jun 22 22:01:08 2025 Construct fuzzy simplicial set
# Sun Jun 22 22:01:08 2025 Finding Nearest Neighbors
# Sun Jun 22 22:01:08 2025 Building RP forest with 11 trees
# Sun Jun 22 22:01:08 2025 NN descent for 14 iterations
# 	 1  /  14
# /home/zz367/miniconda3/envs/wseg_VAE/lib/python3.10/site-packages/umap/umap_.py:1945: UserWarning: n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(f"n_jobs value {self.n_jobs} overridden to 1 by setting random_state. Use no seed for parallelism.")
# 	 2  /  14
# 	 3  /  14
# 	Stopping threshold met -- exiting after 3 iterations
# Sun Jun 22 22:01:08 2025 Finished Nearest Neighbor Search
# Sun Jun 22 22:01:08 2025 Construct embedding
# Epochs completed:   0%|            0/200 [00:00]
# 	completed  0  /  200 epochs
# 	completed  20  /  200 epochs
# 	completed  40  /  200 epochs
# 	completed  60  /  200 epochs
# 	completed  80  /  200 epochs
# 	completed  100  /  200 epochs
# 	completed  120  /  200 epochs
# 	completed  140  /  200 epochs
# 	completed  160  /  200 epochs
# 	completed  180  /  200 epochs
# Sun Jun 22 22:01:15 2025 Finished embedding
# The fraction that are not clustered: 0.8014
# Total number of clusters: 2
# Hopkins metric in UMAP: 0.8338
# Hopkins metric in VAE: 0.8310
# HDBSCAN Silhouette score in UMAP: -0.1209
# HDBSCAN Silhouette score in VAE: -0.0040
# Calinski–Harabasz index in UMAP: 774.3431
# Calinski–Harabasz index in VAE: 1.0080
# UMAP(angular_rp_forest=True, metric='cosine', min_dist=0, n_jobs=1, n_neighbors=25, random_state=1118, verbose=True)
# Sun Jun 22 22:01:20 2025 Construct fuzzy simplicial set
# Sun Jun 22 22:01:20 2025 Finding Nearest Neighbors
# Sun Jun 22 22:01:20 2025 Building RP forest with 11 trees
# Sun Jun 22 22:01:20 2025 NN descent for 14 iterations
# 	 1  /  14
# /home/zz367/miniconda3/envs/wseg_VAE/lib/python3.10/site-packages/umap/umap_.py:1945: UserWarning: n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(f"n_jobs value {self.n_jobs} overridden to 1 by setting random_state. Use no seed for parallelism.")
# 	 2  /  14
# 	 3  /  14
# 	Stopping threshold met -- exiting after 3 iterations
# Sun Jun 22 22:01:21 2025 Finished Nearest Neighbor Search
# Sun Jun 22 22:01:21 2025 Construct embedding
# Epochs completed:   0%|            0/200 [00:00]
# 	completed  0  /  200 epochs
# 	completed  20  /  200 epochs
# 	completed  40  /  200 epochs
# 	completed  60  /  200 epochs
# 	completed  80  /  200 epochs
# 	completed  100  /  200 epochs
# 	completed  120  /  200 epochs
# 	completed  140  /  200 epochs
# 	completed  160  /  200 epochs
# 	completed  180  /  200 epochs
# Sun Jun 22 22:01:27 2025 Finished embedding
# The fraction that are not clustered: 0.5348
# Total number of clusters: 5
# Hopkins metric in UMAP: 0.8462
# Hopkins metric in VAE: 0.8310
# HDBSCAN Silhouette score in UMAP: -0.1223
# HDBSCAN Silhouette score in VAE: -0.0056
# Calinski–Harabasz index in UMAP: 1644.8318
# Calinski–Harabasz index in VAE: 1.1038
# UMAP(angular_rp_forest=True, metric='cosine', min_dist=0, n_jobs=1, n_neighbors=25, random_state=1118, verbose=True)
# Sun Jun 22 22:01:32 2025 Construct fuzzy simplicial set
# Sun Jun 22 22:01:32 2025 Finding Nearest Neighbors
# Sun Jun 22 22:01:32 2025 Building RP forest with 11 trees
# Sun Jun 22 22:01:32 2025 NN descent for 14 iterations
# 	 1  /  14
# /home/zz367/miniconda3/envs/wseg_VAE/lib/python3.10/site-packages/umap/umap_.py:1945: UserWarning: n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(f"n_jobs value {self.n_jobs} overridden to 1 by setting random_state. Use no seed for parallelism.")
# 	 2  /  14
# 	 3  /  14
# 	Stopping threshold met -- exiting after 3 iterations
# Sun Jun 22 22:01:33 2025 Finished Nearest Neighbor Search
# Sun Jun 22 22:01:33 2025 Construct embedding
# Epochs completed:   0%|            0/200 [00:00]
# 	completed  0  /  200 epochs
# 	completed  20  /  200 epochs
# 	completed  40  /  200 epochs
# 	completed  60  /  200 epochs
# 	completed  80  /  200 epochs
# 	completed  100  /  200 epochs
# 	completed  120  /  200 epochs
# 	completed  140  /  200 epochs
# 	completed  160  /  200 epochs
# 	completed  180  /  200 epochs
# Sun Jun 22 22:01:39 2025 Finished embedding
# The fraction that are not clustered: 0.4533
# Total number of clusters: 4
# Hopkins metric in UMAP: 0.8366
# Hopkins metric in VAE: 0.8310
# HDBSCAN Silhouette score in UMAP: -0.0122
# HDBSCAN Silhouette score in VAE: -0.0054
# Calinski–Harabasz index in UMAP: 2454.2850
# Calinski–Harabasz index in VAE: 0.9599
# UMAP(angular_rp_forest=True, metric='cosine', min_dist=0, n_jobs=1, n_neighbors=25, random_state=1118, verbose=True)
# Sun Jun 22 22:01:44 2025 Construct fuzzy simplicial set
# Sun Jun 22 22:01:44 2025 Finding Nearest Neighbors
# Sun Jun 22 22:01:44 2025 Building RP forest with 11 trees
# Sun Jun 22 22:01:44 2025 NN descent for 14 iterations
# 	 1  /  14
# /home/zz367/miniconda3/envs/wseg_VAE/lib/python3.10/site-packages/umap/umap_.py:1945: UserWarning: n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(f"n_jobs value {self.n_jobs} overridden to 1 by setting random_state. Use no seed for parallelism.")
# 	 2  /  14
# 	 3  /  14
# 	Stopping threshold met -- exiting after 3 iterations
# Sun Jun 22 22:01:45 2025 Finished Nearest Neighbor Search
# Sun Jun 22 22:01:45 2025 Construct embedding
# Epochs completed:   0%|            0/200 [00:00]
# 	completed  0  /  200 epochs
# 	completed  20  /  200 epochs
# 	completed  40  /  200 epochs
# 	completed  60  /  200 epochs
# 	completed  80  /  200 epochs
# 	completed  100  /  200 epochs
# 	completed  120  /  200 epochs
# 	completed  140  /  200 epochs
# 	completed  160  /  200 epochs
# 	completed  180  /  200 epochs
# Sun Jun 22 22:01:52 2025 Finished embedding
# The fraction that are not clustered: 0.6335
# Total number of clusters: 4
# Hopkins metric in UMAP: 0.8604
# Hopkins metric in VAE: 0.8310
# HDBSCAN Silhouette score in UMAP: -0.1752
# HDBSCAN Silhouette score in VAE: -0.0041
# Calinski–Harabasz index in UMAP: 1109.2956
# Calinski–Harabasz index in VAE: 1.2082
# UMAP(angular_rp_forest=True, metric='cosine', min_dist=0, n_jobs=1, n_neighbors=25, random_state=1118, verbose=True)
# Sun Jun 22 22:01:57 2025 Construct fuzzy simplicial set
# Sun Jun 22 22:01:57 2025 Finding Nearest Neighbors
# Sun Jun 22 22:01:57 2025 Building RP forest with 11 trees
# Sun Jun 22 22:01:57 2025 NN descent for 14 iterations
# 	 1  /  14
# /home/zz367/miniconda3/envs/wseg_VAE/lib/python3.10/site-packages/umap/umap_.py:1945: UserWarning: n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(f"n_jobs value {self.n_jobs} overridden to 1 by setting random_state. Use no seed for parallelism.")
# 	 2  /  14
# 	 3  /  14
# 	Stopping threshold met -- exiting after 3 iterations
# Sun Jun 22 22:01:58 2025 Finished Nearest Neighbor Search
# Sun Jun 22 22:01:58 2025 Construct embedding
# Epochs completed:   0%|            0/200 [00:00]
# 	completed  0  /  200 epochs
# 	completed  20  /  200 epochs
# 	completed  40  /  200 epochs
# 	completed  60  /  200 epochs
# 	completed  80  /  200 epochs
# 	completed  100  /  200 epochs
# 	completed  120  /  200 epochs
# 	completed  140  /  200 epochs
# 	completed  160  /  200 epochs
# 	completed  180  /  200 epochs
# Sun Jun 22 22:02:04 2025 Finished embedding
# The fraction that are not clustered: 1.0000
# Total number of clusters: 0

# %%
# save the metrics
fn_metric = os.path.join(fd_save, f'{bd}.random.UMAPonVAE.metrics.csv')
metrics.to_csv(fn_metric)
metrics.head()
# Out:
#           birdID  run_id  num_cluster  frac_unclustered  \
# 0  pair2RigBCU25       0            4          0.572088
# 1  pair2RigBCU25       1            3          0.701191
# 2  pair2RigBCU25       2            3          0.545466
# 3  pair2RigBCU25       3            2          0.690190
# 4  pair2RigBCU25       4            4          0.534403
#
#                                      cluster_persist  hopkins_umap  \
# 0  [0.06596454132800426, 0.02436817217522686, 0.0...      0.857192
# 1  [0.0034696004735435574, 0.0161366602276825, 0....      0.868297
# 2  [0.03459173269785813, 0.007943790154283852, 0....      0.872970
# 3        [0.004858564426636343, 0.03389984723116974]      0.864210
# 4  [0.018978873387167843, 0.04849365806688092, 0....      0.875427
#
#    hopkins_vae  silhouette_umap  silhouette_vae  calinski_umap  calinski_vae  \
# 0     0.831036        -0.106822       -0.003999    1613.786569      0.902025
# 1     0.831036        -0.163451       -0.006226     828.159660      1.235348
# 2     0.831036        -0.067124       -0.004681    1637.992382      0.936488
# 3     0.831036        -0.088728       -0.000575     907.309502      0.731322
# 4     0.831036        -0.071960       -0.005497    1996.425728      0.738866
#
#                                           param_umap  \
# 0  {'n_components': 2, 'n_neighbors': 25, 'min_di...
# 1  {'n_components': 2, 'n_neighbors': 25, 'min_di...
# 2  {'n_components': 2, 'n_neighbors': 25, 'min_di...
# 3  {'n_components': 2, 'n_neighbors': 25, 'min_di...
# 4  {'n_components': 2, 'n_neighbors': 25, 'min_di...
#
#                                        param_hdbscan
# 0  {'min_cluster_size_frac': 0.05, 'min_samples':...
# 1  {'min_cluster_size_frac': 0.05, 'min_samples':...
# 2  {'min_cluster_size_frac': 0.05, 'min_samples':...
# 3  {'min_cluster_size_frac': 0.05, 'min_samples':...
# 4  {'min_cluster_size_frac': 0.05, 'min_samples':...

# %% [markdown]
# ### Plot the random distribution of clustering metrics

# %%
# read the metric on real dataset
fn_metric = os.path.join(fd_save, f'{bd}.UMAPonVAE.metrics.csv')
metric_r = pd.read_csv(fn_metric, index_col=0)
metric_r
# Out:
#           birdID                  run_name  num_cluster  frac_unclustered  \
# 0  pair2RigBCU25  spec_goffinet_nn_256_176            7           0.30665
#
#                                      cluster_persist  hopkins_umap  \
# 0  [0.87639019 0.19597107 0.15786957 0.11760882 0...      0.983425
#
#    hopkins_vae  silhouette_umap  silhouette_vae  calinski_umap  calinski_vae  \
# 0     0.831036         0.196658        0.024531     6515.72097    805.793237
#
#                                           param_umap  \
# 0  {'n_components': 2, 'n_neighbors': 25, 'min_di...
#
#                                        param_hdbscan
# 0  {'min_cluster_size_frac': 0.05, 'min_samples':...

# %%
field = 'silhouette_umap'
fig, ax = plt.subplots(nrows=1, ncols=1, figsize=[4, 4])
d = metrics[field]
bin_width = 0.02
bins = np.arange(min(d), max(d) + bin_width, bin_width)
ax.hist(d, bins=bins, color='#737373', edgecolor='none')
# add a line for the real data
ax.axvline(x=metric_r[field][0], color='red', linestyle='--', linewidth=2)
ax.set_xlabel(field, fontsize=12)
ax.set_ylabel('No. of simulation', fontsize=12)
ax.set_title(f'{bd}: {field}', fontsize=12)
# save as pdf
fn_pdf = os.path.join(fd_save, f'random.hist.{field}.pdf')
fig.savefig(fn_pdf)

# %% [markdown]
# ### Plot an example random embedding

# %%
# color calls according to hdbscan labels
col_long = sns.color_palette('hls', n_colors=max(clusterer.labels_)+1)
# plot embedding
fig, ax = plt.subplots(nrows=1, ncols=1, figsize=[5, 5])
for hi in range(-1, max(clusterer.labels_)+1):
    idx = np.where(clusterer.labels_ == hi)[0]
    embed_s = res[idx,:]
    if hi==-1:
        ax.scatter(embed_s[:,0], embed_s[:,1], s=0.3, alpha=0.25, color='#737373')
    else:
        ax.scatter(embed_s[:,0], embed_s[:,1], s=0.3, alpha=0.5, color=col_long[hi])
        # add syl label
        ax.text(np.mean(embed_s[:,0]), np.mean(embed_s[:,1]), hi, fontsize=12)
ax.set_title(f'{bd}:{info.shape[0]}', fontsize=10)
ax.set_xlabel('UMAP axis 1', fontsize=12)
ax.set_ylabel('UMAP axis 2', fontsize=12)
plt.tight_layout()
# save fig
fn_fig = os.path.join(fd_save, f'{bd}.random.UMAPonVAE.HBBSCAN.pdf')
fig.savefig(fn_fig)

# %%
# save the embedding data to plot in Matlab 
embed_r = info.copy()
# save the latent features
for ii in range(latent_rd.shape[1]):
    embed_r[f'vae{ii}'] = latent_rd[:,ii]
# save the UMAP and HDBSCAN results
for ii in range(res.shape[1]):
    embed_r[f'umap{ii+1}'] = res[:,ii]
embed_r['hdbscan_cluster'] = clusterer.labels_+1
embed_r['hdbscan_prob'] = clusterer.probabilities_
fn_csv = os.path.join(fd_save, f'{bd}.random.embedding.csv')
embed_r.to_csv(fn_csv)

# %%
print(fn_csv)

# %%
embed_r.shape

# %%
metrics.shape
# Out:
# (195, 13)
