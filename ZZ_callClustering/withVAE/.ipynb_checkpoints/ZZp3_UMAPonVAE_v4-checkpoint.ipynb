# %% [markdown]
# ## 0. Goal
# Run VAE first to reduce spectrogram dimensions from 128*128 to 32 latent features. Then run UMAP and HDBSCAN. <br>
# Use Goffinet spectrogramming and VAE network. <br>
# Differ from v3: try higher UMAP dimensions for clustering, then visualize in 2D

# %%
import os, sys, importlib, librosa, glob, h5py, tqdm
from scipy.io import wavfile
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from joblib import Parallel, delayed
import random
import umap, hdbscan
from collections import Counter
import seaborn as sns
from matplotlib.colors import ListedColormap
from sklearn.metrics import silhouette_score
from torch.utils.data import Dataset, DataLoader
import torch
from sklearn.metrics import calinski_harabasz_score

plt.rcParams['pdf.fonttype'] = 42

# %%
# import my utility script
cluster_script_path = '/home/zz367/ProjectsU/EphysMONAO/Jupyter/MatlabCodes/ZZ_callClustering/'
sys.path.insert(1, cluster_script_path)
import hopkins2
import vae_goffinet, hopkins
importlib.reload(vae_goffinet)
importlib.reload(hopkins2)
# Out:
# <module 'hopkins2' from '/home/zz367/ProjectsU/EphysMONAO/Jupyter/MatlabCodes/ZZ_callClustering/hopkins2.py'>

# %%
# create a custom colormap for spectrogram
jet = plt.get_cmap('jet', 255)
# Extract jet colors and prepend black at the beginning
jet_colors = jet(np.linspace(0, 1, 255))
custom_colors = np.vstack([[0, 0, 0, 1], jet_colors])  # Black for 0, then jet
custom_cmap = ListedColormap(custom_colors)

# %% [markdown]
# ## 1. Inputs

# %%
fd_z4 = '/mnt/z4'
fd_data = os.path.join(fd_z4, 'zz367', 'EphysMONAO', 'Analyzed', 'vaeWav')
birdIDs = ['pair5RigCCU29', 'pair4RigACU68', 'pair4RigBCU53', 'pair2RigBCU25']
# color limits when calculating spectrograms, depending on the audio amplitude, may differ between birds
clims = [[1.5,7], [1.5,7], [1.5,8.5], [1.5,8]]
# what syllable to analyze
syl = ['v']
sylStr = ''.join(syl)
# the default color list
col_list = ['#e41a1c','#a65628','#4daf4a','#984ea3','#ff7f00','#f781bf','#377eb8','#737373']
# what input dataset to use: real and matched shuffle
input_rn = 'spec_goffinet_nn_256_176'
# size of the spectrogram windows
X_SHAPE = [128, 128]

# %%
# parameters to vary
umap_comp = [2, 3, 5, 8, 10]

# %%
# fixed paramteres for UMAP and HDBSCAN
param_umap = {'n_neighbors':25, 'min_dist':0, 'metric':'euclidean'}
param_hdbscan = {'min_cluster_size_frac':0.05, 'min_samples': 20}

# %% [markdown]
# ## 2. Loop through birds: VAE -> UMAP -> HDBSCAN

# %%
# save metrics in a master dataframe
metrics = pd.DataFrame()

# %%
# loop through birds
for bi in range(0, len(birdIDs)):
# for bi in range(1):
    bd = birdIDs[bi]
    # save to a separate folder
    fd_save = os.path.join(fd_data, bd, 'UMAPonVAE4', sylStr)
    if not os.path.exists(fd_save):
        os.makedirs(fd_save)
    print(f'Save results to {fd_save}')
    # load VAE latent features and meta info
    fn_latent = os.path.join(fd_data, bd, 'UMAPonVAE1', sylStr, input_rn, 'latentM.csv')
    latent_m = np.loadtxt(fn_latent, delimiter=',')
    fn_info = os.path.join(fd_data, bd, 'Spectrogram2', sylStr, f'{bd}.{sylStr}.{input_rn}.info.csv')
    info = pd.read_csv(fn_info, index_col=0)
    print(latent_m.shape, info.shape)
    # add UMAP embedding to the dataframe
    embed_ori = info.copy()
    for ii in range(latent_m.shape[1]):
        embed_ori[f'vae{ii}'] = latent_m[:,ii]
    # loop through different parameters
    run_names = []

    for uc in umap_comp:
        ## run UMAP 
        print(param_umap)
        rn = f'uc{uc}'
        print(rn)
        run_names.append(rn)
        umap_model = umap.UMAP(n_neighbors=param_umap['n_neighbors'], n_components=uc, min_dist=param_umap['min_dist'], 
                                                      metric=param_umap['metric'], random_state=1118, verbose=True)
        res = umap_model.fit_transform(latent_m)

        # add umap results to the dataframe
        embed = embed_ori.copy()
        for jj in range(res.shape[1]):
            embed[f'umap{jj+1}'] = res[:,jj]

        ## HDBSCAN clustering
        clusterer = hdbscan.HDBSCAN(min_cluster_size=int(res.shape[0]* param_hdbscan['min_cluster_size_frac']), min_samples=param_hdbscan['min_samples'])
        # clusterer = hdbscan.HDBSCAN(min_cluster_size=200, min_samples=20)
        clusterer.fit(res)
        embed['hdbscan_cluster'] = clusterer.labels_
        embed['hdbscan_prob'] = clusterer.probabilities_

        # what's the fraction that's not clustered
        unc_f = embed[embed['hdbscan_cluster']==-1].shape[0] / embed.shape[0]
        print(f'The fraction that are not clustered: {unc_f:.4f}')
        num_c = max(embed['hdbscan_cluster']+1)
        print(f'Total number of clusters: {num_c}')

        # run UMAP on 2D to visualize
        umap_model2 = umap.UMAP(n_neighbors=param_umap['n_neighbors'], n_components=2, min_dist=param_umap['min_dist'], 
                                                      metric=param_umap['metric'], random_state=1118, verbose=True)
        res2 = umap_model2.fit_transform(latent_m)

        # add umap results to the dataframe
        for jj in range(res2.shape[1]):
            embed[f'2umap{jj+1}'] = res2[:,jj]
        
        # save embedding and clustering 
        fn_embed = os.path.join(fd_save, f'{bd}.{rn}.UMAPonVAE.embedding.csv')
        embed.to_csv(fn_embed)

        # color calls according to hdbscan labels
        col_long = sns.color_palette('hls', n_colors=max(embed['hdbscan_cluster'])+1)
        # plot embedding
        fig, ax = plt.subplots(nrows=1, ncols=1, figsize=[5, 5])
        for hi in range(-1, max(embed['hdbscan_cluster'])+1):
            embed_s = embed[embed['hdbscan_cluster']==hi]
            if hi==-1:
                ax.scatter(embed_s['2umap1'], embed_s['2umap2'], s=0.3, alpha=0.25, color='#737373')
            else:
                ax.scatter(embed_s['2umap1'], embed_s['2umap2'], s=0.3, alpha=0.5, color=col_long[hi])
                # add syl label
                ax.text(np.mean(embed_s['2umap1']), np.mean(embed_s['2umap2']), hi, fontsize=12)
        ax.set_title(f'{bd}:{rn}:{embed.shape[0]}', fontsize=10)
        ax.set_xlabel('UMAP axis 1', fontsize=12)
        ax.set_ylabel('UMAP axis 2', fontsize=12)
        plt.tight_layout()
        # save fig
        fn_fig = os.path.join(fd_save, f'{bd}.{rn}.UMAPonVAE.HBBSCAN.pdf')
        fig.savefig(fn_fig)

        ## Quantify clustering tendency
        # in UMAP space
        hpk1 = hopkins2.hopkins_statistic(res, rng=1992)
        print(f'Hopkins metric in UMAP: {hpk1:.4f}')
        # in VAE space
        hpk2 = hopkins2.hopkins_statistic(latent_m, rng=1992)
        print(f'Hopkins metric in VAE: {hpk2:.4f}')

        ## Quantify clustering quality with Silhoutte score
        # in UMAP space
        sil1 = silhouette_score(res, embed['hdbscan_cluster'], random_state=1118, metric='euclidean')
        print(f'HDBSCAN Silhouette score in UMAP: {sil1:.4f}')
        # in VAE space
        sil2 = silhouette_score(latent_m, embed['hdbscan_cluster'], random_state=1118, metric='euclidean')
        print(f'HDBSCAN Silhouette score in VAE: {sil2:.4f}')

        # Calinski–Harabasz (CH) Index
        cah1 = calinski_harabasz_score(res, embed['hdbscan_cluster'])
        print(f'Calinski–Harabasz index in UMAP: {cah1:.4f}')
        cah2 = calinski_harabasz_score(latent_m, embed['hdbscan_cluster'])
        print(f'Calinski–Harabasz index in VAE: {cah2:.4f}')

        # save data to the master data frame
        row = pd.DataFrame([{'birdID':bd, 'run_name':rn, 'num_cluster':num_c, 'frac_unclustered':unc_f, 'cluster_persist':clusterer.cluster_persistence_, 'hopkins_umap':hpk1, 
                             'hopkins_vae':hpk2, 'silhouette_umap':sil1, 'silhouette_vae':sil2, 'calinski_umap':cah1, 'calinski_vae':cah2, 'param_umap':param_umap, 'param_hdbscan':param_hdbscan}])
        metrics = pd.concat([metrics, row], ignore_index=True)
# Out:
# Save results to /mnt/z4/zz367/EphysMONAO/Analyzed/vaeWav/pair5RigCCU29/UMAPonVAE4/v
# (23240, 32) (23240, 7)
# {'n_neighbors': 25, 'min_dist': 0, 'metric': 'euclidean'}
# uc2
# UMAP(min_dist=0, n_jobs=1, n_neighbors=25, random_state=1118, verbose=True)
# Mon Jun  9 22:37:46 2025 Construct fuzzy simplicial set
# Mon Jun  9 22:37:46 2025 Finding Nearest Neighbors
# Mon Jun  9 22:37:46 2025 Building RP forest with 13 trees
# Mon Jun  9 22:37:46 2025 NN descent for 15 iterations
# /home/zz367/miniconda3/envs/wseg_VAE/lib/python3.10/site-packages/umap/umap_.py:1945: UserWarning: n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(f"n_jobs value {self.n_jobs} overridden to 1 by setting random_state. Use no seed for parallelism.")
# 	 1  /  15
# 	 2  /  15
# 	 3  /  15
# 	Stopping threshold met -- exiting after 3 iterations
# Mon Jun  9 22:37:47 2025 Finished Nearest Neighbor Search
# Mon Jun  9 22:37:47 2025 Construct embedding
# Epochs completed:   0%|            0/200 [00:00]
# 	completed  0  /  200 epochs
# 	completed  20  /  200 epochs
# 	completed  40  /  200 epochs
# 	completed  60  /  200 epochs
# 	completed  80  /  200 epochs
# 	completed  100  /  200 epochs
# 	completed  120  /  200 epochs
# 	completed  140  /  200 epochs
# 	completed  160  /  200 epochs
# 	completed  180  /  200 epochs
# Mon Jun  9 22:37:57 2025 Finished embedding
# The fraction that are not clustered: 0.1131
# Total number of clusters: 6
# UMAP(min_dist=0, n_jobs=1, n_neighbors=25, random_state=1118, verbose=True)
# Mon Jun  9 22:37:57 2025 Construct fuzzy simplicial set
# Mon Jun  9 22:37:57 2025 Finding Nearest Neighbors
# Mon Jun  9 22:37:57 2025 Building RP forest with 13 trees
# Mon Jun  9 22:37:58 2025 NN descent for 15 iterations
# /home/zz367/miniconda3/envs/wseg_VAE/lib/python3.10/site-packages/umap/umap_.py:1945: UserWarning: n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(f"n_jobs value {self.n_jobs} overridden to 1 by setting random_state. Use no seed for parallelism.")
# 	 1  /  15
# 	 2  /  15
# 	 3  /  15
# 	Stopping threshold met -- exiting after 3 iterations
# Mon Jun  9 22:37:59 2025 Finished Nearest Neighbor Search
# Mon Jun  9 22:37:59 2025 Construct embedding
# Epochs completed:   0%|            0/200 [00:00]
# 	completed  0  /  200 epochs
# 	completed  20  /  200 epochs
# 	completed  40  /  200 epochs
# 	completed  60  /  200 epochs
# 	completed  80  /  200 epochs
# 	completed  100  /  200 epochs
# 	completed  120  /  200 epochs
# 	completed  140  /  200 epochs
# 	completed  160  /  200 epochs
# 	completed  180  /  200 epochs
# Mon Jun  9 22:38:09 2025 Finished embedding
# Hopkins metric in UMAP: 0.9859
# Hopkins metric in VAE: 0.8607
# HDBSCAN Silhouette score in UMAP: 0.3688
# HDBSCAN Silhouette score in VAE: 0.0074
# Calinski–Harabasz index in UMAP: 13935.0223
# Calinski–Harabasz index in VAE: 894.4828
# {'n_neighbors': 25, 'min_dist': 0, 'metric': 'euclidean'}
# uc3
# UMAP(min_dist=0, n_components=3, n_jobs=1, n_neighbors=25, random_state=1118, verbose=True)
# Mon Jun  9 22:38:23 2025 Construct fuzzy simplicial set
# Mon Jun  9 22:38:23 2025 Finding Nearest Neighbors
# Mon Jun  9 22:38:23 2025 Building RP forest with 13 trees
# Mon Jun  9 22:38:23 2025 NN descent for 15 iterations
# /home/zz367/miniconda3/envs/wseg_VAE/lib/python3.10/site-packages/umap/umap_.py:1945: UserWarning: n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(f"n_jobs value {self.n_jobs} overridden to 1 by setting random_state. Use no seed for parallelism.")
# 	 1  /  15
# 	 2  /  15
# 	 3  /  15
# 	Stopping threshold met -- exiting after 3 iterations
# Mon Jun  9 22:38:24 2025 Finished Nearest Neighbor Search
# Mon Jun  9 22:38:24 2025 Construct embedding
# Epochs completed:   0%|            0/200 [00:00]
# 	completed  0  /  200 epochs
# 	completed  20  /  200 epochs
# 	completed  40  /  200 epochs
# 	completed  60  /  200 epochs
# 	completed  80  /  200 epochs
# 	completed  100  /  200 epochs
# 	completed  120  /  200 epochs
# 	completed  140  /  200 epochs
# 	completed  160  /  200 epochs
# 	completed  180  /  200 epochs
# Mon Jun  9 22:38:34 2025 Finished embedding
# The fraction that are not clustered: 0.0568
# Total number of clusters: 4
# UMAP(min_dist=0, n_jobs=1, n_neighbors=25, random_state=1118, verbose=True)
# Mon Jun  9 22:38:35 2025 Construct fuzzy simplicial set
# Mon Jun  9 22:38:35 2025 Finding Nearest Neighbors
# Mon Jun  9 22:38:35 2025 Building RP forest with 13 trees
# Mon Jun  9 22:38:35 2025 NN descent for 15 iterations
# /home/zz367/miniconda3/envs/wseg_VAE/lib/python3.10/site-packages/umap/umap_.py:1945: UserWarning: n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(f"n_jobs value {self.n_jobs} overridden to 1 by setting random_state. Use no seed for parallelism.")
# 	 1  /  15
# 	 2  /  15
# 	 3  /  15
# 	Stopping threshold met -- exiting after 3 iterations
# Mon Jun  9 22:38:36 2025 Finished Nearest Neighbor Search
# Mon Jun  9 22:38:36 2025 Construct embedding
# Epochs completed:   0%|            0/200 [00:00]
# 	completed  0  /  200 epochs
# 	completed  20  /  200 epochs
# 	completed  40  /  200 epochs
# 	completed  60  /  200 epochs
# 	completed  80  /  200 epochs
# 	completed  100  /  200 epochs
# 	completed  120  /  200 epochs
# 	completed  140  /  200 epochs
# 	completed  160  /  200 epochs
# 	completed  180  /  200 epochs
# Mon Jun  9 22:38:45 2025 Finished embedding
# Hopkins metric in UMAP: 0.9806
# Hopkins metric in VAE: 0.8607
# HDBSCAN Silhouette score in UMAP: 0.4038
# HDBSCAN Silhouette score in VAE: 0.0172
# Calinski–Harabasz index in UMAP: 12981.6260
# Calinski–Harabasz index in VAE: 993.2659
# {'n_neighbors': 25, 'min_dist': 0, 'metric': 'euclidean'}
# uc5
# UMAP(min_dist=0, n_components=5, n_jobs=1, n_neighbors=25, random_state=1118, verbose=True)
# Mon Jun  9 22:38:57 2025 Construct fuzzy simplicial set
# Mon Jun  9 22:38:57 2025 Finding Nearest Neighbors
# Mon Jun  9 22:38:57 2025 Building RP forest with 13 trees
# Mon Jun  9 22:38:57 2025 NN descent for 15 iterations
# /home/zz367/miniconda3/envs/wseg_VAE/lib/python3.10/site-packages/umap/umap_.py:1945: UserWarning: n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(f"n_jobs value {self.n_jobs} overridden to 1 by setting random_state. Use no seed for parallelism.")
# 	 1  /  15
# 	 2  /  15
# 	 3  /  15
# 	Stopping threshold met -- exiting after 3 iterations
# Mon Jun  9 22:38:58 2025 Finished Nearest Neighbor Search
# Mon Jun  9 22:38:58 2025 Construct embedding
# Epochs completed:   0%|            0/200 [00:00]
# 	completed  0  /  200 epochs
# 	completed  20  /  200 epochs
# 	completed  40  /  200 epochs
# 	completed  60  /  200 epochs
# 	completed  80  /  200 epochs
# 	completed  100  /  200 epochs
# 	completed  120  /  200 epochs
# 	completed  140  /  200 epochs
# 	completed  160  /  200 epochs
# 	completed  180  /  200 epochs
# Mon Jun  9 22:39:09 2025 Finished embedding
# The fraction that are not clustered: 0.1066
# Total number of clusters: 6
# UMAP(min_dist=0, n_jobs=1, n_neighbors=25, random_state=1118, verbose=True)
# Mon Jun  9 22:39:10 2025 Construct fuzzy simplicial set
# Mon Jun  9 22:39:10 2025 Finding Nearest Neighbors
# Mon Jun  9 22:39:10 2025 Building RP forest with 13 trees
# Mon Jun  9 22:39:10 2025 NN descent for 15 iterations
# /home/zz367/miniconda3/envs/wseg_VAE/lib/python3.10/site-packages/umap/umap_.py:1945: UserWarning: n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(f"n_jobs value {self.n_jobs} overridden to 1 by setting random_state. Use no seed for parallelism.")
# 	 1  /  15
# 	 2  /  15
# 	 3  /  15
# 	Stopping threshold met -- exiting after 3 iterations
# Mon Jun  9 22:39:11 2025 Finished Nearest Neighbor Search
# Mon Jun  9 22:39:11 2025 Construct embedding
# Epochs completed:   0%|            0/200 [00:00]
# 	completed  0  /  200 epochs
# 	completed  20  /  200 epochs
# 	completed  40  /  200 epochs
# 	completed  60  /  200 epochs
# 	completed  80  /  200 epochs
# 	completed  100  /  200 epochs
# 	completed  120  /  200 epochs
# 	completed  140  /  200 epochs
# 	completed  160  /  200 epochs
# 	completed  180  /  200 epochs
# Mon Jun  9 22:39:20 2025 Finished embedding
# Hopkins metric in UMAP: 0.9807
# Hopkins metric in VAE: 0.8607
# HDBSCAN Silhouette score in UMAP: 0.3623
# HDBSCAN Silhouette score in VAE: 0.0085
# Calinski–Harabasz index in UMAP: 10452.6779
# Calinski–Harabasz index in VAE: 862.1637
# {'n_neighbors': 25, 'min_dist': 0, 'metric': 'euclidean'}
# uc8
# UMAP(min_dist=0, n_components=8, n_jobs=1, n_neighbors=25, random_state=1118, verbose=True)
# Mon Jun  9 22:39:32 2025 Construct fuzzy simplicial set
# Mon Jun  9 22:39:32 2025 Finding Nearest Neighbors
# Mon Jun  9 22:39:32 2025 Building RP forest with 13 trees
# Mon Jun  9 22:39:32 2025 NN descent for 15 iterations
# /home/zz367/miniconda3/envs/wseg_VAE/lib/python3.10/site-packages/umap/umap_.py:1945: UserWarning: n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(f"n_jobs value {self.n_jobs} overridden to 1 by setting random_state. Use no seed for parallelism.")
# 	 1  /  15
# 	 2  /  15
# 	 3  /  15
# 	Stopping threshold met -- exiting after 3 iterations
# Mon Jun  9 22:39:33 2025 Finished Nearest Neighbor Search
# Mon Jun  9 22:39:33 2025 Construct embedding
# Epochs completed:   0%|            0/200 [00:00]
# 	completed  0  /  200 epochs
# 	completed  20  /  200 epochs
# 	completed  40  /  200 epochs
# 	completed  60  /  200 epochs
# 	completed  80  /  200 epochs
# 	completed  100  /  200 epochs
# 	completed  120  /  200 epochs
# 	completed  140  /  200 epochs
# 	completed  160  /  200 epochs
# 	completed  180  /  200 epochs
# Mon Jun  9 22:39:45 2025 Finished embedding
# The fraction that are not clustered: 0.0414
# Total number of clusters: 4
# UMAP(min_dist=0, n_jobs=1, n_neighbors=25, random_state=1118, verbose=True)
# Mon Jun  9 22:39:46 2025 Construct fuzzy simplicial set
# Mon Jun  9 22:39:46 2025 Finding Nearest Neighbors
# Mon Jun  9 22:39:46 2025 Building RP forest with 13 trees
# Mon Jun  9 22:39:46 2025 NN descent for 15 iterations
# /home/zz367/miniconda3/envs/wseg_VAE/lib/python3.10/site-packages/umap/umap_.py:1945: UserWarning: n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(f"n_jobs value {self.n_jobs} overridden to 1 by setting random_state. Use no seed for parallelism.")
# 	 1  /  15
# 	 2  /  15
# 	 3  /  15
# 	Stopping threshold met -- exiting after 3 iterations
# Mon Jun  9 22:39:47 2025 Finished Nearest Neighbor Search
# Mon Jun  9 22:39:47 2025 Construct embedding
# Epochs completed:   0%|            0/200 [00:00]
# 	completed  0  /  200 epochs
# 	completed  20  /  200 epochs
# 	completed  40  /  200 epochs
# 	completed  60  /  200 epochs
# 	completed  80  /  200 epochs
# 	completed  100  /  200 epochs
# 	completed  120  /  200 epochs
# 	completed  140  /  200 epochs
# 	completed  160  /  200 epochs
# 	completed  180  /  200 epochs
# Mon Jun  9 22:39:57 2025 Finished embedding
# Hopkins metric in UMAP: 0.9818
# Hopkins metric in VAE: 0.8607
# HDBSCAN Silhouette score in UMAP: 0.4024
# HDBSCAN Silhouette score in VAE: 0.0235
# Calinski–Harabasz index in UMAP: 12056.1914
# Calinski–Harabasz index in VAE: 1013.0243
# {'n_neighbors': 25, 'min_dist': 0, 'metric': 'euclidean'}
# uc10
# UMAP(min_dist=0, n_components=10, n_jobs=1, n_neighbors=25, random_state=1118, verbose=True)
# Mon Jun  9 22:40:08 2025 Construct fuzzy simplicial set
# Mon Jun  9 22:40:08 2025 Finding Nearest Neighbors
# Mon Jun  9 22:40:08 2025 Building RP forest with 13 trees
# Mon Jun  9 22:40:08 2025 NN descent for 15 iterations
# /home/zz367/miniconda3/envs/wseg_VAE/lib/python3.10/site-packages/umap/umap_.py:1945: UserWarning: n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(f"n_jobs value {self.n_jobs} overridden to 1 by setting random_state. Use no seed for parallelism.")
# 	 1  /  15
# 	 2  /  15
# 	 3  /  15
# 	Stopping threshold met -- exiting after 3 iterations
# Mon Jun  9 22:40:10 2025 Finished Nearest Neighbor Search
# Mon Jun  9 22:40:10 2025 Construct embedding
# Epochs completed:   0%|            0/200 [00:00]
# 	completed  0  /  200 epochs
# 	completed  20  /  200 epochs
# 	completed  40  /  200 epochs
# 	completed  60  /  200 epochs
# 	completed  80  /  200 epochs
# 	completed  100  /  200 epochs
# 	completed  120  /  200 epochs
# 	completed  140  /  200 epochs
# 	completed  160  /  200 epochs
# 	completed  180  /  200 epochs
# Mon Jun  9 22:40:23 2025 Finished embedding
# The fraction that are not clustered: 0.0506
# Total number of clusters: 4
# UMAP(min_dist=0, n_jobs=1, n_neighbors=25, random_state=1118, verbose=True)
# Mon Jun  9 22:40:23 2025 Construct fuzzy simplicial set
# Mon Jun  9 22:40:23 2025 Finding Nearest Neighbors
# Mon Jun  9 22:40:23 2025 Building RP forest with 13 trees
# Mon Jun  9 22:40:23 2025 NN descent for 15 iterations
# /home/zz367/miniconda3/envs/wseg_VAE/lib/python3.10/site-packages/umap/umap_.py:1945: UserWarning: n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(f"n_jobs value {self.n_jobs} overridden to 1 by setting random_state. Use no seed for parallelism.")
# 	 1  /  15
# 	 2  /  15
# 	 3  /  15
# 	Stopping threshold met -- exiting after 3 iterations
# Mon Jun  9 22:40:24 2025 Finished Nearest Neighbor Search
# Mon Jun  9 22:40:24 2025 Construct embedding
# Epochs completed:   0%|            0/200 [00:00]
# 	completed  0  /  200 epochs
# 	completed  20  /  200 epochs
# 	completed  40  /  200 epochs
# 	completed  60  /  200 epochs
# 	completed  80  /  200 epochs
# 	completed  100  /  200 epochs
# 	completed  120  /  200 epochs
# 	completed  140  /  200 epochs
# 	completed  160  /  200 epochs
# 	completed  180  /  200 epochs
# Mon Jun  9 22:40:34 2025 Finished embedding
# Hopkins metric in UMAP: 0.9821
# Hopkins metric in VAE: 0.8607
# HDBSCAN Silhouette score in UMAP: 0.3951
# HDBSCAN Silhouette score in VAE: 0.0173
# Calinski–Harabasz index in UMAP: 12104.4452
# Calinski–Harabasz index in VAE: 1001.2675
# Save results to /mnt/z4/zz367/EphysMONAO/Analyzed/vaeWav/pair4RigACU68/UMAPonVAE4/v
# (36359, 32) (36359, 7)
# {'n_neighbors': 25, 'min_dist': 0, 'metric': 'euclidean'}
# uc2
# UMAP(min_dist=0, n_jobs=1, n_neighbors=25, random_state=1118, verbose=True)
# Mon Jun  9 22:40:48 2025 Construct fuzzy simplicial set
# Mon Jun  9 22:40:48 2025 Finding Nearest Neighbors
# Mon Jun  9 22:40:48 2025 Building RP forest with 15 trees
# Mon Jun  9 22:40:48 2025 NN descent for 15 iterations
# /home/zz367/miniconda3/envs/wseg_VAE/lib/python3.10/site-packages/umap/umap_.py:1945: UserWarning: n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(f"n_jobs value {self.n_jobs} overridden to 1 by setting random_state. Use no seed for parallelism.")
# 	 1  /  15
# 	 2  /  15
# 	 3  /  15
# 	Stopping threshold met -- exiting after 3 iterations
# Mon Jun  9 22:40:50 2025 Finished Nearest Neighbor Search
# Mon Jun  9 22:40:50 2025 Construct embedding
# Epochs completed:   0%|            0/200 [00:00]
# 	completed  0  /  200 epochs
# 	completed  20  /  200 epochs
# 	completed  40  /  200 epochs
# 	completed  60  /  200 epochs
# 	completed  80  /  200 epochs
# 	completed  100  /  200 epochs
# 	completed  120  /  200 epochs
# 	completed  140  /  200 epochs
# 	completed  160  /  200 epochs
# 	completed  180  /  200 epochs
# Mon Jun  9 22:41:05 2025 Finished embedding
# The fraction that are not clustered: 0.1887
# Total number of clusters: 6
# UMAP(min_dist=0, n_jobs=1, n_neighbors=25, random_state=1118, verbose=True)
# Mon Jun  9 22:41:06 2025 Construct fuzzy simplicial set
# Mon Jun  9 22:41:06 2025 Finding Nearest Neighbors
# Mon Jun  9 22:41:06 2025 Building RP forest with 15 trees
# Mon Jun  9 22:41:06 2025 NN descent for 15 iterations
# /home/zz367/miniconda3/envs/wseg_VAE/lib/python3.10/site-packages/umap/umap_.py:1945: UserWarning: n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(f"n_jobs value {self.n_jobs} overridden to 1 by setting random_state. Use no seed for parallelism.")
# 	 1  /  15
# 	 2  /  15
# 	 3  /  15
# 	Stopping threshold met -- exiting after 3 iterations
# Mon Jun  9 22:41:07 2025 Finished Nearest Neighbor Search
# Mon Jun  9 22:41:08 2025 Construct embedding
# Epochs completed:   0%|            0/200 [00:00]
# 	completed  0  /  200 epochs
# 	completed  20  /  200 epochs
# 	completed  40  /  200 epochs
# 	completed  60  /  200 epochs
# 	completed  80  /  200 epochs
# 	completed  100  /  200 epochs
# 	completed  120  /  200 epochs
# 	completed  140  /  200 epochs
# 	completed  160  /  200 epochs
# 	completed  180  /  200 epochs
# Mon Jun  9 22:41:23 2025 Finished embedding
# Hopkins metric in UMAP: 0.9838
# Hopkins metric in VAE: 0.8502
# HDBSCAN Silhouette score in UMAP: 0.3620
# HDBSCAN Silhouette score in VAE: 0.0134
# Calinski–Harabasz index in UMAP: 18939.5378
# Calinski–Harabasz index in VAE: 1498.1977
# {'n_neighbors': 25, 'min_dist': 0, 'metric': 'euclidean'}
# uc3
# UMAP(min_dist=0, n_components=3, n_jobs=1, n_neighbors=25, random_state=1118, verbose=True)
# Mon Jun  9 22:41:48 2025 Construct fuzzy simplicial set
# Mon Jun  9 22:41:48 2025 Finding Nearest Neighbors
# Mon Jun  9 22:41:48 2025 Building RP forest with 15 trees
# Mon Jun  9 22:41:48 2025 NN descent for 15 iterations
# /home/zz367/miniconda3/envs/wseg_VAE/lib/python3.10/site-packages/umap/umap_.py:1945: UserWarning: n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(f"n_jobs value {self.n_jobs} overridden to 1 by setting random_state. Use no seed for parallelism.")
# 	 1  /  15
# 	 2  /  15
# 	 3  /  15
# 	Stopping threshold met -- exiting after 3 iterations
# Mon Jun  9 22:41:50 2025 Finished Nearest Neighbor Search
# Mon Jun  9 22:41:50 2025 Construct embedding
# Epochs completed:   0%|            0/200 [00:00]
# 	completed  0  /  200 epochs
# 	completed  20  /  200 epochs
# 	completed  40  /  200 epochs
# 	completed  60  /  200 epochs
# 	completed  80  /  200 epochs
# 	completed  100  /  200 epochs
# 	completed  120  /  200 epochs
# 	completed  140  /  200 epochs
# 	completed  160  /  200 epochs
# 	completed  180  /  200 epochs
# Mon Jun  9 22:42:06 2025 Finished embedding
# The fraction that are not clustered: 0.1809
# Total number of clusters: 7
# UMAP(min_dist=0, n_jobs=1, n_neighbors=25, random_state=1118, verbose=True)
# Mon Jun  9 22:42:06 2025 Construct fuzzy simplicial set
# Mon Jun  9 22:42:06 2025 Finding Nearest Neighbors
# Mon Jun  9 22:42:06 2025 Building RP forest with 15 trees
# Mon Jun  9 22:42:06 2025 NN descent for 15 iterations
# /home/zz367/miniconda3/envs/wseg_VAE/lib/python3.10/site-packages/umap/umap_.py:1945: UserWarning: n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(f"n_jobs value {self.n_jobs} overridden to 1 by setting random_state. Use no seed for parallelism.")
# 	 1  /  15
# 	 2  /  15
# 	 3  /  15
# 	Stopping threshold met -- exiting after 3 iterations
# Mon Jun  9 22:42:08 2025 Finished Nearest Neighbor Search
# Mon Jun  9 22:42:08 2025 Construct embedding
# Epochs completed:   0%|            0/200 [00:00]
# 	completed  0  /  200 epochs
# 	completed  20  /  200 epochs
# 	completed  40  /  200 epochs
# 	completed  60  /  200 epochs
# 	completed  80  /  200 epochs
# 	completed  100  /  200 epochs
# 	completed  120  /  200 epochs
# 	completed  140  /  200 epochs
# 	completed  160  /  200 epochs
# 	completed  180  /  200 epochs
# Mon Jun  9 22:42:23 2025 Finished embedding
# Hopkins metric in UMAP: 0.9811
# Hopkins metric in VAE: 0.8502
# HDBSCAN Silhouette score in UMAP: 0.3398
# HDBSCAN Silhouette score in VAE: 0.0119
# Calinski–Harabasz index in UMAP: 14154.9326
# Calinski–Harabasz index in VAE: 1321.6060
# {'n_neighbors': 25, 'min_dist': 0, 'metric': 'euclidean'}
# uc5
# UMAP(min_dist=0, n_components=5, n_jobs=1, n_neighbors=25, random_state=1118, verbose=True)
# Mon Jun  9 22:42:49 2025 Construct fuzzy simplicial set
# Mon Jun  9 22:42:49 2025 Finding Nearest Neighbors
# Mon Jun  9 22:42:49 2025 Building RP forest with 15 trees
# Mon Jun  9 22:42:49 2025 NN descent for 15 iterations
# /home/zz367/miniconda3/envs/wseg_VAE/lib/python3.10/site-packages/umap/umap_.py:1945: UserWarning: n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(f"n_jobs value {self.n_jobs} overridden to 1 by setting random_state. Use no seed for parallelism.")
# 	 1  /  15
# 	 2  /  15
# 	 3  /  15
# 	Stopping threshold met -- exiting after 3 iterations
# Mon Jun  9 22:42:51 2025 Finished Nearest Neighbor Search
# Mon Jun  9 22:42:51 2025 Construct embedding
# Epochs completed:   0%|            0/200 [00:00]
# 	completed  0  /  200 epochs
# 	completed  20  /  200 epochs
# 	completed  40  /  200 epochs
# 	completed  60  /  200 epochs
# 	completed  80  /  200 epochs
# 	completed  100  /  200 epochs
# 	completed  120  /  200 epochs
# 	completed  140  /  200 epochs
# 	completed  160  /  200 epochs
# 	completed  180  /  200 epochs
# Mon Jun  9 22:43:08 2025 Finished embedding
# The fraction that are not clustered: 0.0662
# Total number of clusters: 2
# UMAP(min_dist=0, n_jobs=1, n_neighbors=25, random_state=1118, verbose=True)
# Mon Jun  9 22:43:09 2025 Construct fuzzy simplicial set
# Mon Jun  9 22:43:09 2025 Finding Nearest Neighbors
# Mon Jun  9 22:43:09 2025 Building RP forest with 15 trees
# Mon Jun  9 22:43:09 2025 NN descent for 15 iterations
# /home/zz367/miniconda3/envs/wseg_VAE/lib/python3.10/site-packages/umap/umap_.py:1945: UserWarning: n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(f"n_jobs value {self.n_jobs} overridden to 1 by setting random_state. Use no seed for parallelism.")
# 	 1  /  15
# 	 2  /  15
# 	 3  /  15
# 	Stopping threshold met -- exiting after 3 iterations
# Mon Jun  9 22:43:11 2025 Finished Nearest Neighbor Search
# Mon Jun  9 22:43:11 2025 Construct embedding
# Epochs completed:   0%|            0/200 [00:00]
# 	completed  0  /  200 epochs
# 	completed  20  /  200 epochs
# 	completed  40  /  200 epochs
# 	completed  60  /  200 epochs
# 	completed  80  /  200 epochs
# 	completed  100  /  200 epochs
# 	completed  120  /  200 epochs
# 	completed  140  /  200 epochs
# 	completed  160  /  200 epochs
# 	completed  180  /  200 epochs
# Mon Jun  9 22:43:26 2025 Finished embedding
# Hopkins metric in UMAP: 0.9831
# Hopkins metric in VAE: 0.8502
# HDBSCAN Silhouette score in UMAP: 0.1089
# HDBSCAN Silhouette score in VAE: -0.0334
# Calinski–Harabasz index in UMAP: 2922.4826
# Calinski–Harabasz index in VAE: 811.2549
# {'n_neighbors': 25, 'min_dist': 0, 'metric': 'euclidean'}
# uc8
# UMAP(min_dist=0, n_components=8, n_jobs=1, n_neighbors=25, random_state=1118, verbose=True)
# Mon Jun  9 22:43:55 2025 Construct fuzzy simplicial set
# Mon Jun  9 22:43:55 2025 Finding Nearest Neighbors
# Mon Jun  9 22:43:55 2025 Building RP forest with 15 trees
# Mon Jun  9 22:43:55 2025 NN descent for 15 iterations
# /home/zz367/miniconda3/envs/wseg_VAE/lib/python3.10/site-packages/umap/umap_.py:1945: UserWarning: n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(f"n_jobs value {self.n_jobs} overridden to 1 by setting random_state. Use no seed for parallelism.")
# 	 1  /  15
# 	 2  /  15
# 	 3  /  15
# 	Stopping threshold met -- exiting after 3 iterations
# Mon Jun  9 22:43:57 2025 Finished Nearest Neighbor Search
# Mon Jun  9 22:43:57 2025 Construct embedding
# Epochs completed:   0%|            0/200 [00:00]
# 	completed  0  /  200 epochs
# 	completed  20  /  200 epochs
# 	completed  40  /  200 epochs
# 	completed  60  /  200 epochs
# 	completed  80  /  200 epochs
# 	completed  100  /  200 epochs
# 	completed  120  /  200 epochs
# 	completed  140  /  200 epochs
# 	completed  160  /  200 epochs
# 	completed  180  /  200 epochs
# Mon Jun  9 22:44:15 2025 Finished embedding
# The fraction that are not clustered: 0.0602
# Total number of clusters: 2
# UMAP(min_dist=0, n_jobs=1, n_neighbors=25, random_state=1118, verbose=True)
# Mon Jun  9 22:44:16 2025 Construct fuzzy simplicial set
# Mon Jun  9 22:44:16 2025 Finding Nearest Neighbors
# Mon Jun  9 22:44:16 2025 Building RP forest with 15 trees
# Mon Jun  9 22:44:16 2025 NN descent for 15 iterations
# /home/zz367/miniconda3/envs/wseg_VAE/lib/python3.10/site-packages/umap/umap_.py:1945: UserWarning: n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(f"n_jobs value {self.n_jobs} overridden to 1 by setting random_state. Use no seed for parallelism.")
# 	 1  /  15
# 	 2  /  15
# 	 3  /  15
# 	Stopping threshold met -- exiting after 3 iterations
# Mon Jun  9 22:44:18 2025 Finished Nearest Neighbor Search
# Mon Jun  9 22:44:18 2025 Construct embedding
# Epochs completed:   0%|            0/200 [00:00]
# 	completed  0  /  200 epochs
# 	completed  20  /  200 epochs
# 	completed  40  /  200 epochs
# 	completed  60  /  200 epochs
# 	completed  80  /  200 epochs
# 	completed  100  /  200 epochs
# 	completed  120  /  200 epochs
# 	completed  140  /  200 epochs
# 	completed  160  /  200 epochs
# 	completed  180  /  200 epochs
# Mon Jun  9 22:44:33 2025 Finished embedding
# Hopkins metric in UMAP: 0.9844
# Hopkins metric in VAE: 0.8502
# HDBSCAN Silhouette score in UMAP: 0.1280
# HDBSCAN Silhouette score in VAE: -0.0343
# Calinski–Harabasz index in UMAP: 2894.7798
# Calinski–Harabasz index in VAE: 824.9728
# {'n_neighbors': 25, 'min_dist': 0, 'metric': 'euclidean'}
# uc10
# UMAP(min_dist=0, n_components=10, n_jobs=1, n_neighbors=25, random_state=1118, verbose=True)
# Mon Jun  9 22:45:02 2025 Construct fuzzy simplicial set
# Mon Jun  9 22:45:02 2025 Finding Nearest Neighbors
# Mon Jun  9 22:45:02 2025 Building RP forest with 15 trees
# Mon Jun  9 22:45:02 2025 NN descent for 15 iterations
# /home/zz367/miniconda3/envs/wseg_VAE/lib/python3.10/site-packages/umap/umap_.py:1945: UserWarning: n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(f"n_jobs value {self.n_jobs} overridden to 1 by setting random_state. Use no seed for parallelism.")
# 	 1  /  15
# 	 2  /  15
# 	 3  /  15
# 	Stopping threshold met -- exiting after 3 iterations
# Mon Jun  9 22:45:04 2025 Finished Nearest Neighbor Search
# Mon Jun  9 22:45:04 2025 Construct embedding
# Epochs completed:   0%|            0/200 [00:00]
# 	completed  0  /  200 epochs
# 	completed  20  /  200 epochs
# 	completed  40  /  200 epochs
# 	completed  60  /  200 epochs
# 	completed  80  /  200 epochs
# 	completed  100  /  200 epochs
# 	completed  120  /  200 epochs
# 	completed  140  /  200 epochs
# 	completed  160  /  200 epochs
# 	completed  180  /  200 epochs
# Mon Jun  9 22:45:24 2025 Finished embedding
# The fraction that are not clustered: 0.0639
# Total number of clusters: 2
# UMAP(min_dist=0, n_jobs=1, n_neighbors=25, random_state=1118, verbose=True)
# Mon Jun  9 22:45:25 2025 Construct fuzzy simplicial set
# Mon Jun  9 22:45:25 2025 Finding Nearest Neighbors
# Mon Jun  9 22:45:25 2025 Building RP forest with 15 trees
# Mon Jun  9 22:45:25 2025 NN descent for 15 iterations
# /home/zz367/miniconda3/envs/wseg_VAE/lib/python3.10/site-packages/umap/umap_.py:1945: UserWarning: n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(f"n_jobs value {self.n_jobs} overridden to 1 by setting random_state. Use no seed for parallelism.")
# 	 1  /  15
# 	 2  /  15
# 	 3  /  15
# 	Stopping threshold met -- exiting after 3 iterations
# Mon Jun  9 22:45:27 2025 Finished Nearest Neighbor Search
# Mon Jun  9 22:45:27 2025 Construct embedding
# Epochs completed:   0%|            0/200 [00:00]
# 	completed  0  /  200 epochs
# 	completed  20  /  200 epochs
# 	completed  40  /  200 epochs
# 	completed  60  /  200 epochs
# 	completed  80  /  200 epochs
# 	completed  100  /  200 epochs
# 	completed  120  /  200 epochs
# 	completed  140  /  200 epochs
# 	completed  160  /  200 epochs
# 	completed  180  /  200 epochs
# Mon Jun  9 22:45:42 2025 Finished embedding
# Hopkins metric in UMAP: 0.9844
# Hopkins metric in VAE: 0.8502
# HDBSCAN Silhouette score in UMAP: 0.1190
# HDBSCAN Silhouette score in VAE: -0.0333
# Calinski–Harabasz index in UMAP: 2873.8605
# Calinski–Harabasz index in VAE: 811.1256
# Save results to /mnt/z4/zz367/EphysMONAO/Analyzed/vaeWav/pair4RigBCU53/UMAPonVAE4/v
# (16194, 32) (16194, 7)
# {'n_neighbors': 25, 'min_dist': 0, 'metric': 'euclidean'}
# uc2
# UMAP(min_dist=0, n_jobs=1, n_neighbors=25, random_state=1118, verbose=True)
# Mon Jun  9 22:46:12 2025 Construct fuzzy simplicial set
# Mon Jun  9 22:46:12 2025 Finding Nearest Neighbors
# Mon Jun  9 22:46:12 2025 Building RP forest with 11 trees
# Mon Jun  9 22:46:12 2025 NN descent for 14 iterations
# 	 1  /  14
# /home/zz367/miniconda3/envs/wseg_VAE/lib/python3.10/site-packages/umap/umap_.py:1945: UserWarning: n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(f"n_jobs value {self.n_jobs} overridden to 1 by setting random_state. Use no seed for parallelism.")
# 	 2  /  14
# 	 3  /  14
# 	Stopping threshold met -- exiting after 3 iterations
# Mon Jun  9 22:46:13 2025 Finished Nearest Neighbor Search
# Mon Jun  9 22:46:13 2025 Construct embedding
# Epochs completed:   0%|            0/200 [00:00]
# 	completed  0  /  200 epochs
# 	completed  20  /  200 epochs
# 	completed  40  /  200 epochs
# 	completed  60  /  200 epochs
# 	completed  80  /  200 epochs
# 	completed  100  /  200 epochs
# 	completed  120  /  200 epochs
# 	completed  140  /  200 epochs
# 	completed  160  /  200 epochs
# 	completed  180  /  200 epochs
# Mon Jun  9 22:46:20 2025 Finished embedding
# The fraction that are not clustered: 0.2039
# Total number of clusters: 5
# UMAP(min_dist=0, n_jobs=1, n_neighbors=25, random_state=1118, verbose=True)
# Mon Jun  9 22:46:20 2025 Construct fuzzy simplicial set
# Mon Jun  9 22:46:20 2025 Finding Nearest Neighbors
# Mon Jun  9 22:46:20 2025 Building RP forest with 11 trees
# Mon Jun  9 22:46:20 2025 NN descent for 14 iterations
# 	 1  /  14
# /home/zz367/miniconda3/envs/wseg_VAE/lib/python3.10/site-packages/umap/umap_.py:1945: UserWarning: n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(f"n_jobs value {self.n_jobs} overridden to 1 by setting random_state. Use no seed for parallelism.")
# 	 2  /  14
# 	 3  /  14
# 	Stopping threshold met -- exiting after 3 iterations
# Mon Jun  9 22:46:21 2025 Finished Nearest Neighbor Search
# Mon Jun  9 22:46:21 2025 Construct embedding
# Epochs completed:   0%|            0/200 [00:00]
# 	completed  0  /  200 epochs
# 	completed  20  /  200 epochs
# 	completed  40  /  200 epochs
# 	completed  60  /  200 epochs
# 	completed  80  /  200 epochs
# 	completed  100  /  200 epochs
# 	completed  120  /  200 epochs
# 	completed  140  /  200 epochs
# 	completed  160  /  200 epochs
# 	completed  180  /  200 epochs
# Mon Jun  9 22:46:28 2025 Finished embedding
# Hopkins metric in UMAP: 0.9697
# Hopkins metric in VAE: 0.8248
# HDBSCAN Silhouette score in UMAP: 0.3090
# HDBSCAN Silhouette score in VAE: -0.0018
# Calinski–Harabasz index in UMAP: 7289.8932
# Calinski–Harabasz index in VAE: 601.1207
# {'n_neighbors': 25, 'min_dist': 0, 'metric': 'euclidean'}
# uc3
# UMAP(min_dist=0, n_components=3, n_jobs=1, n_neighbors=25, random_state=1118, verbose=True)
# Mon Jun  9 22:46:34 2025 Construct fuzzy simplicial set
# Mon Jun  9 22:46:34 2025 Finding Nearest Neighbors
# Mon Jun  9 22:46:34 2025 Building RP forest with 11 trees
# Mon Jun  9 22:46:34 2025 NN descent for 14 iterations
# 	 1  /  14
# /home/zz367/miniconda3/envs/wseg_VAE/lib/python3.10/site-packages/umap/umap_.py:1945: UserWarning: n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(f"n_jobs value {self.n_jobs} overridden to 1 by setting random_state. Use no seed for parallelism.")
# 	 2  /  14
# 	 3  /  14
# 	Stopping threshold met -- exiting after 3 iterations
# Mon Jun  9 22:46:35 2025 Finished Nearest Neighbor Search
# Mon Jun  9 22:46:35 2025 Construct embedding
# Epochs completed:   0%|            0/200 [00:00]
# 	completed  0  /  200 epochs
# 	completed  20  /  200 epochs
# 	completed  40  /  200 epochs
# 	completed  60  /  200 epochs
# 	completed  80  /  200 epochs
# 	completed  100  /  200 epochs
# 	completed  120  /  200 epochs
# 	completed  140  /  200 epochs
# 	completed  160  /  200 epochs
# 	completed  180  /  200 epochs
# Mon Jun  9 22:46:42 2025 Finished embedding
# The fraction that are not clustered: 0.1309
# Total number of clusters: 4
# UMAP(min_dist=0, n_jobs=1, n_neighbors=25, random_state=1118, verbose=True)
# Mon Jun  9 22:46:43 2025 Construct fuzzy simplicial set
# Mon Jun  9 22:46:43 2025 Finding Nearest Neighbors
# Mon Jun  9 22:46:43 2025 Building RP forest with 11 trees
# Mon Jun  9 22:46:43 2025 NN descent for 14 iterations
# 	 1  /  14
# /home/zz367/miniconda3/envs/wseg_VAE/lib/python3.10/site-packages/umap/umap_.py:1945: UserWarning: n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(f"n_jobs value {self.n_jobs} overridden to 1 by setting random_state. Use no seed for parallelism.")
# 	 2  /  14
# 	 3  /  14
# 	Stopping threshold met -- exiting after 3 iterations
# Mon Jun  9 22:46:43 2025 Finished Nearest Neighbor Search
# Mon Jun  9 22:46:44 2025 Construct embedding
# Epochs completed:   0%|            0/200 [00:00]
# 	completed  0  /  200 epochs
# 	completed  20  /  200 epochs
# 	completed  40  /  200 epochs
# 	completed  60  /  200 epochs
# 	completed  80  /  200 epochs
# 	completed  100  /  200 epochs
# 	completed  120  /  200 epochs
# 	completed  140  /  200 epochs
# 	completed  160  /  200 epochs
# 	completed  180  /  200 epochs
# Mon Jun  9 22:46:50 2025 Finished embedding
# Hopkins metric in UMAP: 0.9708
# Hopkins metric in VAE: 0.8248
# HDBSCAN Silhouette score in UMAP: 0.4034
# HDBSCAN Silhouette score in VAE: 0.0005
# Calinski–Harabasz index in UMAP: 7811.2557
# Calinski–Harabasz index in VAE: 628.8608
# {'n_neighbors': 25, 'min_dist': 0, 'metric': 'euclidean'}
# uc5
# UMAP(min_dist=0, n_components=5, n_jobs=1, n_neighbors=25, random_state=1118, verbose=True)
# Mon Jun  9 22:46:57 2025 Construct fuzzy simplicial set
# Mon Jun  9 22:46:57 2025 Finding Nearest Neighbors
# Mon Jun  9 22:46:57 2025 Building RP forest with 11 trees
# Mon Jun  9 22:46:57 2025 NN descent for 14 iterations
# 	 1  /  14
# /home/zz367/miniconda3/envs/wseg_VAE/lib/python3.10/site-packages/umap/umap_.py:1945: UserWarning: n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(f"n_jobs value {self.n_jobs} overridden to 1 by setting random_state. Use no seed for parallelism.")
# 	 2  /  14
# 	 3  /  14
# 	Stopping threshold met -- exiting after 3 iterations
# Mon Jun  9 22:46:58 2025 Finished Nearest Neighbor Search
# Mon Jun  9 22:46:58 2025 Construct embedding
# Epochs completed:   0%|            0/200 [00:00]
# 	completed  0  /  200 epochs
# 	completed  20  /  200 epochs
# 	completed  40  /  200 epochs
# 	completed  60  /  200 epochs
# 	completed  80  /  200 epochs
# 	completed  100  /  200 epochs
# 	completed  120  /  200 epochs
# 	completed  140  /  200 epochs
# 	completed  160  /  200 epochs
# 	completed  180  /  200 epochs
# Mon Jun  9 22:47:06 2025 Finished embedding
# The fraction that are not clustered: 0.0068
# Total number of clusters: 2
# UMAP(min_dist=0, n_jobs=1, n_neighbors=25, random_state=1118, verbose=True)
# Mon Jun  9 22:47:06 2025 Construct fuzzy simplicial set
# Mon Jun  9 22:47:06 2025 Finding Nearest Neighbors
# Mon Jun  9 22:47:06 2025 Building RP forest with 11 trees
# Mon Jun  9 22:47:06 2025 NN descent for 14 iterations
# 	 1  /  14
# /home/zz367/miniconda3/envs/wseg_VAE/lib/python3.10/site-packages/umap/umap_.py:1945: UserWarning: n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(f"n_jobs value {self.n_jobs} overridden to 1 by setting random_state. Use no seed for parallelism.")
# 	 2  /  14
# 	 3  /  14
# 	Stopping threshold met -- exiting after 3 iterations
# Mon Jun  9 22:47:07 2025 Finished Nearest Neighbor Search
# Mon Jun  9 22:47:07 2025 Construct embedding
# Epochs completed:   0%|            0/200 [00:00]
# 	completed  0  /  200 epochs
# 	completed  20  /  200 epochs
# 	completed  40  /  200 epochs
# 	completed  60  /  200 epochs
# 	completed  80  /  200 epochs
# 	completed  100  /  200 epochs
# 	completed  120  /  200 epochs
# 	completed  140  /  200 epochs
# 	completed  160  /  200 epochs
# 	completed  180  /  200 epochs
# Mon Jun  9 22:47:14 2025 Finished embedding
# Hopkins metric in UMAP: 0.9739
# Hopkins metric in VAE: 0.8248
# HDBSCAN Silhouette score in UMAP: 0.2712
# HDBSCAN Silhouette score in VAE: 0.0148
# Calinski–Harabasz index in UMAP: 2766.3872
# Calinski–Harabasz index in VAE: 456.0374
# {'n_neighbors': 25, 'min_dist': 0, 'metric': 'euclidean'}
# uc8
# UMAP(min_dist=0, n_components=8, n_jobs=1, n_neighbors=25, random_state=1118, verbose=True)
# Mon Jun  9 22:47:21 2025 Construct fuzzy simplicial set
# Mon Jun  9 22:47:21 2025 Finding Nearest Neighbors
# Mon Jun  9 22:47:21 2025 Building RP forest with 11 trees
# Mon Jun  9 22:47:21 2025 NN descent for 14 iterations
# 	 1  /  14
# /home/zz367/miniconda3/envs/wseg_VAE/lib/python3.10/site-packages/umap/umap_.py:1945: UserWarning: n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(f"n_jobs value {self.n_jobs} overridden to 1 by setting random_state. Use no seed for parallelism.")
# 	 2  /  14
# 	 3  /  14
# 	Stopping threshold met -- exiting after 3 iterations
# Mon Jun  9 22:47:22 2025 Finished Nearest Neighbor Search
# Mon Jun  9 22:47:22 2025 Construct embedding
# Epochs completed:   0%|            0/200 [00:00]
# 	completed  0  /  200 epochs
# 	completed  20  /  200 epochs
# 	completed  40  /  200 epochs
# 	completed  60  /  200 epochs
# 	completed  80  /  200 epochs
# 	completed  100  /  200 epochs
# 	completed  120  /  200 epochs
# 	completed  140  /  200 epochs
# 	completed  160  /  200 epochs
# 	completed  180  /  200 epochs
# Mon Jun  9 22:47:30 2025 Finished embedding
# The fraction that are not clustered: 0.0287
# Total number of clusters: 3
# UMAP(min_dist=0, n_jobs=1, n_neighbors=25, random_state=1118, verbose=True)
# Mon Jun  9 22:47:31 2025 Construct fuzzy simplicial set
# Mon Jun  9 22:47:31 2025 Finding Nearest Neighbors
# Mon Jun  9 22:47:31 2025 Building RP forest with 11 trees
# Mon Jun  9 22:47:31 2025 NN descent for 14 iterations
# 	 1  /  14
# /home/zz367/miniconda3/envs/wseg_VAE/lib/python3.10/site-packages/umap/umap_.py:1945: UserWarning: n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(f"n_jobs value {self.n_jobs} overridden to 1 by setting random_state. Use no seed for parallelism.")
# 	 2  /  14
# 	 3  /  14
# 	Stopping threshold met -- exiting after 3 iterations
# Mon Jun  9 22:47:32 2025 Finished Nearest Neighbor Search
# Mon Jun  9 22:47:32 2025 Construct embedding
# Epochs completed:   0%|            0/200 [00:00]
# 	completed  0  /  200 epochs
# 	completed  20  /  200 epochs
# 	completed  40  /  200 epochs
# 	completed  60  /  200 epochs
# 	completed  80  /  200 epochs
# 	completed  100  /  200 epochs
# 	completed  120  /  200 epochs
# 	completed  140  /  200 epochs
# 	completed  160  /  200 epochs
# 	completed  180  /  200 epochs
# Mon Jun  9 22:47:39 2025 Finished embedding
# Hopkins metric in UMAP: 0.9764
# Hopkins metric in VAE: 0.8248
# HDBSCAN Silhouette score in UMAP: 0.3300
# HDBSCAN Silhouette score in VAE: -0.0097
# Calinski–Harabasz index in UMAP: 5011.9042
# Calinski–Harabasz index in VAE: 562.9475
# {'n_neighbors': 25, 'min_dist': 0, 'metric': 'euclidean'}
# uc10
# UMAP(min_dist=0, n_components=10, n_jobs=1, n_neighbors=25, random_state=1118, verbose=True)
# Mon Jun  9 22:47:45 2025 Construct fuzzy simplicial set
# Mon Jun  9 22:47:45 2025 Finding Nearest Neighbors
# Mon Jun  9 22:47:45 2025 Building RP forest with 11 trees
# Mon Jun  9 22:47:45 2025 NN descent for 14 iterations
# 	 1  /  14
# /home/zz367/miniconda3/envs/wseg_VAE/lib/python3.10/site-packages/umap/umap_.py:1945: UserWarning: n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(f"n_jobs value {self.n_jobs} overridden to 1 by setting random_state. Use no seed for parallelism.")
# 	 2  /  14
# 	 3  /  14
# 	Stopping threshold met -- exiting after 3 iterations
# Mon Jun  9 22:47:46 2025 Finished Nearest Neighbor Search
# Mon Jun  9 22:47:46 2025 Construct embedding
# Epochs completed:   0%|            0/200 [00:00]
# 	completed  0  /  200 epochs
# 	completed  20  /  200 epochs
# 	completed  40  /  200 epochs
# 	completed  60  /  200 epochs
# 	completed  80  /  200 epochs
# 	completed  100  /  200 epochs
# 	completed  120  /  200 epochs
# 	completed  140  /  200 epochs
# 	completed  160  /  200 epochs
# 	completed  180  /  200 epochs
# Mon Jun  9 22:47:55 2025 Finished embedding
# The fraction that are not clustered: 0.0125
# Total number of clusters: 2
# UMAP(min_dist=0, n_jobs=1, n_neighbors=25, random_state=1118, verbose=True)
# Mon Jun  9 22:47:56 2025 Construct fuzzy simplicial set
# Mon Jun  9 22:47:56 2025 Finding Nearest Neighbors
# Mon Jun  9 22:47:56 2025 Building RP forest with 11 trees
# Mon Jun  9 22:47:56 2025 NN descent for 14 iterations
# 	 1  /  14
# /home/zz367/miniconda3/envs/wseg_VAE/lib/python3.10/site-packages/umap/umap_.py:1945: UserWarning: n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(f"n_jobs value {self.n_jobs} overridden to 1 by setting random_state. Use no seed for parallelism.")
# 	 2  /  14
# 	 3  /  14
# 	Stopping threshold met -- exiting after 3 iterations
# Mon Jun  9 22:47:56 2025 Finished Nearest Neighbor Search
# Mon Jun  9 22:47:57 2025 Construct embedding
# Epochs completed:   0%|            0/200 [00:00]
# 	completed  0  /  200 epochs
# 	completed  20  /  200 epochs
# 	completed  40  /  200 epochs
# 	completed  60  /  200 epochs
# 	completed  80  /  200 epochs
# 	completed  100  /  200 epochs
# 	completed  120  /  200 epochs
# 	completed  140  /  200 epochs
# 	completed  160  /  200 epochs
# 	completed  180  /  200 epochs
# Mon Jun  9 22:48:04 2025 Finished embedding
# Hopkins metric in UMAP: 0.9774
# Hopkins metric in VAE: 0.8248
# HDBSCAN Silhouette score in UMAP: 0.2403
# HDBSCAN Silhouette score in VAE: -0.0023
# Calinski–Harabasz index in UMAP: 3029.4686
# Calinski–Harabasz index in VAE: 455.5771
# Save results to /mnt/z4/zz367/EphysMONAO/Analyzed/vaeWav/pair2RigBCU25/UMAPonVAE4/v
# (16452, 32) (16452, 7)
# {'n_neighbors': 25, 'min_dist': 0, 'metric': 'euclidean'}
# uc2
# UMAP(min_dist=0, n_jobs=1, n_neighbors=25, random_state=1118, verbose=True)
# Mon Jun  9 22:48:12 2025 Construct fuzzy simplicial set
# Mon Jun  9 22:48:12 2025 Finding Nearest Neighbors
# Mon Jun  9 22:48:12 2025 Building RP forest with 11 trees
# Mon Jun  9 22:48:12 2025 NN descent for 14 iterations
# 	 1  /  14
# /home/zz367/miniconda3/envs/wseg_VAE/lib/python3.10/site-packages/umap/umap_.py:1945: UserWarning: n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(f"n_jobs value {self.n_jobs} overridden to 1 by setting random_state. Use no seed for parallelism.")
# 	 2  /  14
# 	 3  /  14
# 	Stopping threshold met -- exiting after 3 iterations
# Mon Jun  9 22:48:12 2025 Finished Nearest Neighbor Search
# Mon Jun  9 22:48:13 2025 Construct embedding
# Epochs completed:   0%|            0/200 [00:00]
# 	completed  0  /  200 epochs
# 	completed  20  /  200 epochs
# 	completed  40  /  200 epochs
# 	completed  60  /  200 epochs
# 	completed  80  /  200 epochs
# 	completed  100  /  200 epochs
# 	completed  120  /  200 epochs
# 	completed  140  /  200 epochs
# 	completed  160  /  200 epochs
# 	completed  180  /  200 epochs
# Mon Jun  9 22:48:19 2025 Finished embedding
# The fraction that are not clustered: 0.0058
# Total number of clusters: 3
# UMAP(min_dist=0, n_jobs=1, n_neighbors=25, random_state=1118, verbose=True)
# Mon Jun  9 22:48:20 2025 Construct fuzzy simplicial set
# Mon Jun  9 22:48:20 2025 Finding Nearest Neighbors
# Mon Jun  9 22:48:20 2025 Building RP forest with 11 trees
# Mon Jun  9 22:48:20 2025 NN descent for 14 iterations
# 	 1  /  14
# /home/zz367/miniconda3/envs/wseg_VAE/lib/python3.10/site-packages/umap/umap_.py:1945: UserWarning: n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(f"n_jobs value {self.n_jobs} overridden to 1 by setting random_state. Use no seed for parallelism.")
# 	 2  /  14
# 	 3  /  14
# 	Stopping threshold met -- exiting after 3 iterations
# Mon Jun  9 22:48:20 2025 Finished Nearest Neighbor Search
# Mon Jun  9 22:48:20 2025 Construct embedding
# Epochs completed:   0%|            0/200 [00:00]
# 	completed  0  /  200 epochs
# 	completed  20  /  200 epochs
# 	completed  40  /  200 epochs
# 	completed  60  /  200 epochs
# 	completed  80  /  200 epochs
# 	completed  100  /  200 epochs
# 	completed  120  /  200 epochs
# 	completed  140  /  200 epochs
# 	completed  160  /  200 epochs
# 	completed  180  /  200 epochs
# Mon Jun  9 22:48:27 2025 Finished embedding
# Hopkins metric in UMAP: 0.9849
# Hopkins metric in VAE: 0.8310
# HDBSCAN Silhouette score in UMAP: 0.4503
# HDBSCAN Silhouette score in VAE: 0.0325
# Calinski–Harabasz index in UMAP: 14335.3560
# Calinski–Harabasz index in VAE: 864.1092
# {'n_neighbors': 25, 'min_dist': 0, 'metric': 'euclidean'}
# uc3
# UMAP(min_dist=0, n_components=3, n_jobs=1, n_neighbors=25, random_state=1118, verbose=True)
# Mon Jun  9 22:48:34 2025 Construct fuzzy simplicial set
# Mon Jun  9 22:48:34 2025 Finding Nearest Neighbors
# Mon Jun  9 22:48:34 2025 Building RP forest with 11 trees
# Mon Jun  9 22:48:34 2025 NN descent for 14 iterations
# 	 1  /  14
# /home/zz367/miniconda3/envs/wseg_VAE/lib/python3.10/site-packages/umap/umap_.py:1945: UserWarning: n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(f"n_jobs value {self.n_jobs} overridden to 1 by setting random_state. Use no seed for parallelism.")
# 	 2  /  14
# 	 3  /  14
# 	Stopping threshold met -- exiting after 3 iterations
# Mon Jun  9 22:48:35 2025 Finished Nearest Neighbor Search
# Mon Jun  9 22:48:35 2025 Construct embedding
# Epochs completed:   0%|            0/200 [00:00]
# 	completed  0  /  200 epochs
# 	completed  20  /  200 epochs
# 	completed  40  /  200 epochs
# 	completed  60  /  200 epochs
# 	completed  80  /  200 epochs
# 	completed  100  /  200 epochs
# 	completed  120  /  200 epochs
# 	completed  140  /  200 epochs
# 	completed  160  /  200 epochs
# 	completed  180  /  200 epochs
# Mon Jun  9 22:48:42 2025 Finished embedding
# The fraction that are not clustered: 0.0000
# Total number of clusters: 3
# UMAP(min_dist=0, n_jobs=1, n_neighbors=25, random_state=1118, verbose=True)
# Mon Jun  9 22:48:42 2025 Construct fuzzy simplicial set
# Mon Jun  9 22:48:42 2025 Finding Nearest Neighbors
# Mon Jun  9 22:48:42 2025 Building RP forest with 11 trees
# Mon Jun  9 22:48:43 2025 NN descent for 14 iterations
# 	 1  /  14
# /home/zz367/miniconda3/envs/wseg_VAE/lib/python3.10/site-packages/umap/umap_.py:1945: UserWarning: n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(f"n_jobs value {self.n_jobs} overridden to 1 by setting random_state. Use no seed for parallelism.")
# 	 2  /  14
# 	 3  /  14
# 	Stopping threshold met -- exiting after 3 iterations
# Mon Jun  9 22:48:43 2025 Finished Nearest Neighbor Search
# Mon Jun  9 22:48:43 2025 Construct embedding
# Epochs completed:   0%|            0/200 [00:00]
# 	completed  0  /  200 epochs
# 	completed  20  /  200 epochs
# 	completed  40  /  200 epochs
# 	completed  60  /  200 epochs
# 	completed  80  /  200 epochs
# 	completed  100  /  200 epochs
# 	completed  120  /  200 epochs
# 	completed  140  /  200 epochs
# 	completed  160  /  200 epochs
# 	completed  180  /  200 epochs
# Mon Jun  9 22:48:50 2025 Finished embedding
# Hopkins metric in UMAP: 0.9792
# Hopkins metric in VAE: 0.8310
# HDBSCAN Silhouette score in UMAP: 0.5952
# HDBSCAN Silhouette score in VAE: 0.0550
# Calinski–Harabasz index in UMAP: 22912.9836
# Calinski–Harabasz index in VAE: 1222.7251
# {'n_neighbors': 25, 'min_dist': 0, 'metric': 'euclidean'}
# uc5
# UMAP(min_dist=0, n_components=5, n_jobs=1, n_neighbors=25, random_state=1118, verbose=True)
# Mon Jun  9 22:48:57 2025 Construct fuzzy simplicial set
# Mon Jun  9 22:48:57 2025 Finding Nearest Neighbors
# Mon Jun  9 22:48:57 2025 Building RP forest with 11 trees
# Mon Jun  9 22:48:57 2025 NN descent for 14 iterations
# 	 1  /  14
# /home/zz367/miniconda3/envs/wseg_VAE/lib/python3.10/site-packages/umap/umap_.py:1945: UserWarning: n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(f"n_jobs value {self.n_jobs} overridden to 1 by setting random_state. Use no seed for parallelism.")
# 	 2  /  14
# 	 3  /  14
# 	Stopping threshold met -- exiting after 3 iterations
# Mon Jun  9 22:48:58 2025 Finished Nearest Neighbor Search
# Mon Jun  9 22:48:58 2025 Construct embedding
# Epochs completed:   0%|            0/200 [00:00]
# 	completed  0  /  200 epochs
# 	completed  20  /  200 epochs
# 	completed  40  /  200 epochs
# 	completed  60  /  200 epochs
# 	completed  80  /  200 epochs
# 	completed  100  /  200 epochs
# 	completed  120  /  200 epochs
# 	completed  140  /  200 epochs
# 	completed  160  /  200 epochs
# 	completed  180  /  200 epochs
# Mon Jun  9 22:49:06 2025 Finished embedding
# The fraction that are not clustered: 0.0058
# Total number of clusters: 3
# UMAP(min_dist=0, n_jobs=1, n_neighbors=25, random_state=1118, verbose=True)
# Mon Jun  9 22:49:07 2025 Construct fuzzy simplicial set
# Mon Jun  9 22:49:07 2025 Finding Nearest Neighbors
# Mon Jun  9 22:49:07 2025 Building RP forest with 11 trees
# Mon Jun  9 22:49:07 2025 NN descent for 14 iterations
# 	 1  /  14
# /home/zz367/miniconda3/envs/wseg_VAE/lib/python3.10/site-packages/umap/umap_.py:1945: UserWarning: n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(f"n_jobs value {self.n_jobs} overridden to 1 by setting random_state. Use no seed for parallelism.")
# 	 2  /  14
# 	 3  /  14
# 	Stopping threshold met -- exiting after 3 iterations
# Mon Jun  9 22:49:07 2025 Finished Nearest Neighbor Search
# Mon Jun  9 22:49:07 2025 Construct embedding
# Epochs completed:   0%|            0/200 [00:00]
# 	completed  0  /  200 epochs
# 	completed  20  /  200 epochs
# 	completed  40  /  200 epochs
# 	completed  60  /  200 epochs
# 	completed  80  /  200 epochs
# 	completed  100  /  200 epochs
# 	completed  120  /  200 epochs
# 	completed  140  /  200 epochs
# 	completed  160  /  200 epochs
# 	completed  180  /  200 epochs
# Mon Jun  9 22:49:14 2025 Finished embedding
# Hopkins metric in UMAP: 0.9767
# Hopkins metric in VAE: 0.8310
# HDBSCAN Silhouette score in UMAP: 0.6009
# HDBSCAN Silhouette score in VAE: 0.0330
# Calinski–Harabasz index in UMAP: 19265.1940
# Calinski–Harabasz index in VAE: 868.0100
# {'n_neighbors': 25, 'min_dist': 0, 'metric': 'euclidean'}
# uc8
# UMAP(min_dist=0, n_components=8, n_jobs=1, n_neighbors=25, random_state=1118, verbose=True)
# Mon Jun  9 22:49:21 2025 Construct fuzzy simplicial set
# Mon Jun  9 22:49:21 2025 Finding Nearest Neighbors
# Mon Jun  9 22:49:21 2025 Building RP forest with 11 trees
# Mon Jun  9 22:49:21 2025 NN descent for 14 iterations
# 	 1  /  14
# /home/zz367/miniconda3/envs/wseg_VAE/lib/python3.10/site-packages/umap/umap_.py:1945: UserWarning: n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(f"n_jobs value {self.n_jobs} overridden to 1 by setting random_state. Use no seed for parallelism.")
# 	 2  /  14
# 	 3  /  14
# 	Stopping threshold met -- exiting after 3 iterations
# Mon Jun  9 22:49:22 2025 Finished Nearest Neighbor Search
# Mon Jun  9 22:49:22 2025 Construct embedding
# Epochs completed:   0%|            0/200 [00:00]
# 	completed  0  /  200 epochs
# 	completed  20  /  200 epochs
# 	completed  40  /  200 epochs
# 	completed  60  /  200 epochs
# 	completed  80  /  200 epochs
# 	completed  100  /  200 epochs
# 	completed  120  /  200 epochs
# 	completed  140  /  200 epochs
# 	completed  160  /  200 epochs
# 	completed  180  /  200 epochs
# Mon Jun  9 22:49:30 2025 Finished embedding
# The fraction that are not clustered: 0.0058
# Total number of clusters: 3
# UMAP(min_dist=0, n_jobs=1, n_neighbors=25, random_state=1118, verbose=True)
# Mon Jun  9 22:49:31 2025 Construct fuzzy simplicial set
# Mon Jun  9 22:49:31 2025 Finding Nearest Neighbors
# Mon Jun  9 22:49:31 2025 Building RP forest with 11 trees
# Mon Jun  9 22:49:31 2025 NN descent for 14 iterations
# 	 1  /  14
# /home/zz367/miniconda3/envs/wseg_VAE/lib/python3.10/site-packages/umap/umap_.py:1945: UserWarning: n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(f"n_jobs value {self.n_jobs} overridden to 1 by setting random_state. Use no seed for parallelism.")
# 	 2  /  14
# 	 3  /  14
# 	Stopping threshold met -- exiting after 3 iterations
# Mon Jun  9 22:49:32 2025 Finished Nearest Neighbor Search
# Mon Jun  9 22:49:32 2025 Construct embedding
# Epochs completed:   0%|            0/200 [00:00]
# 	completed  0  /  200 epochs
# 	completed  20  /  200 epochs
# 	completed  40  /  200 epochs
# 	completed  60  /  200 epochs
# 	completed  80  /  200 epochs
# 	completed  100  /  200 epochs
# 	completed  120  /  200 epochs
# 	completed  140  /  200 epochs
# 	completed  160  /  200 epochs
# 	completed  180  /  200 epochs
# Mon Jun  9 22:49:38 2025 Finished embedding
# Hopkins metric in UMAP: 0.9767
# Hopkins metric in VAE: 0.8310
# HDBSCAN Silhouette score in UMAP: 0.6089
# HDBSCAN Silhouette score in VAE: 0.0328
# Calinski–Harabasz index in UMAP: 20178.5246
# Calinski–Harabasz index in VAE: 866.8851
# {'n_neighbors': 25, 'min_dist': 0, 'metric': 'euclidean'}
# uc10
# UMAP(min_dist=0, n_components=10, n_jobs=1, n_neighbors=25, random_state=1118, verbose=True)
# Mon Jun  9 22:49:45 2025 Construct fuzzy simplicial set
# Mon Jun  9 22:49:45 2025 Finding Nearest Neighbors
# Mon Jun  9 22:49:45 2025 Building RP forest with 11 trees
# Mon Jun  9 22:49:46 2025 NN descent for 14 iterations
# 	 1  /  14
# /home/zz367/miniconda3/envs/wseg_VAE/lib/python3.10/site-packages/umap/umap_.py:1945: UserWarning: n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(f"n_jobs value {self.n_jobs} overridden to 1 by setting random_state. Use no seed for parallelism.")
# 	 2  /  14
# 	 3  /  14
# 	Stopping threshold met -- exiting after 3 iterations
# Mon Jun  9 22:49:46 2025 Finished Nearest Neighbor Search
# Mon Jun  9 22:49:46 2025 Construct embedding
# Epochs completed:   0%|            0/200 [00:00]
# 	completed  0  /  200 epochs
# 	completed  20  /  200 epochs
# 	completed  40  /  200 epochs
# 	completed  60  /  200 epochs
# 	completed  80  /  200 epochs
# 	completed  100  /  200 epochs
# 	completed  120  /  200 epochs
# 	completed  140  /  200 epochs
# 	completed  160  /  200 epochs
# 	completed  180  /  200 epochs
# Mon Jun  9 22:49:56 2025 Finished embedding
# The fraction that are not clustered: 0.0058
# Total number of clusters: 3
# UMAP(min_dist=0, n_jobs=1, n_neighbors=25, random_state=1118, verbose=True)
# Mon Jun  9 22:49:56 2025 Construct fuzzy simplicial set
# Mon Jun  9 22:49:56 2025 Finding Nearest Neighbors
# Mon Jun  9 22:49:56 2025 Building RP forest with 11 trees
# Mon Jun  9 22:49:56 2025 NN descent for 14 iterations
# 	 1  /  14
# /home/zz367/miniconda3/envs/wseg_VAE/lib/python3.10/site-packages/umap/umap_.py:1945: UserWarning: n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(f"n_jobs value {self.n_jobs} overridden to 1 by setting random_state. Use no seed for parallelism.")
# 	 2  /  14
# 	 3  /  14
# 	Stopping threshold met -- exiting after 3 iterations
# Mon Jun  9 22:49:57 2025 Finished Nearest Neighbor Search
# Mon Jun  9 22:49:57 2025 Construct embedding
# Epochs completed:   0%|            0/200 [00:00]
# 	completed  0  /  200 epochs
# 	completed  20  /  200 epochs
# 	completed  40  /  200 epochs
# 	completed  60  /  200 epochs
# 	completed  80  /  200 epochs
# 	completed  100  /  200 epochs
# 	completed  120  /  200 epochs
# 	completed  140  /  200 epochs
# 	completed  160  /  200 epochs
# 	completed  180  /  200 epochs
# Mon Jun  9 22:50:04 2025 Finished embedding
# Hopkins metric in UMAP: 0.9773
# Hopkins metric in VAE: 0.8310
# HDBSCAN Silhouette score in UMAP: 0.6141
# HDBSCAN Silhouette score in VAE: 0.0327
# Calinski–Harabasz index in UMAP: 20172.2232
# Calinski–Harabasz index in VAE: 866.6273

# %%
# save the metrics
fn_metric = os.path.join(fd_save, 'UMAPonVAE.metrics.csv')
metrics.to_csv(fn_metric)
metrics
# Out:
#            birdID run_name  num_cluster  frac_unclustered  \
# 0   pair5RigCCU29      uc2            6          0.113124
# 1   pair5RigCCU29      uc3            4          0.056756
# 2   pair5RigCCU29      uc5            6          0.106583
# 3   pair5RigCCU29      uc8            4          0.041437
# 4   pair5RigCCU29     uc10            4          0.050602
# 5   pair4RigACU68      uc2            6          0.188674
# 6   pair4RigACU68      uc3            7          0.180863
# 7   pair4RigACU68      uc5            2          0.066173
# 8   pair4RigACU68      uc8            2          0.060150
# 9   pair4RigACU68     uc10            2          0.063891
# 10  pair4RigBCU53      uc2            5          0.203903
# 11  pair4RigBCU53      uc3            4          0.130913
# 12  pair4RigBCU53      uc5            2          0.006793
# 13  pair4RigBCU53      uc8            3          0.028714
# 14  pair4RigBCU53     uc10            2          0.012474
# 15  pair2RigBCU25      uc2            3          0.005835
# 16  pair2RigBCU25      uc3            3          0.000000
# 17  pair2RigBCU25      uc5            3          0.005835
# 18  pair2RigBCU25      uc8            3          0.005835
# 19  pair2RigBCU25     uc10            3          0.005835
#
#                                       cluster_persist  hopkins_umap  \
# 0   [0.15763438657619475, 0.318731627070003, 0.384...      0.985925
# 1   [0.1553072301391248, 0.1651824003363683, 0.411...      0.980649
# 2   [0.10725209075135414, 0.3109695866031071, 0.45...      0.980652
# 3   [0.18503574326290656, 0.43280776538199206, 0.2...      0.981802
# 4   [0.27652287939726033, 0.1767527132272387, 0.50...      0.982110
# 5   [0.4607926898236672, 0.4307462790363003, 0.496...      0.983814
# 6   [0.5483503602257879, 0.38555735870331426, 0.44...      0.981076
# 7             [0.6453673211162123, 0.252954585462781]      0.983054
# 8            [0.7979778936512333, 0.3870860102113969]      0.984385
# 9            [0.6421105337692679, 0.2624603079418215]      0.984442
# 10  [0.3834021988446942, 0.5671341512442932, 0.175...      0.969732
# 11  [0.6008311446147384, 0.5646238104427563, 0.460...      0.970820
# 12          [0.6957119483477769, 0.14791809947468074]      0.973941
# 13  [0.6916734156851955, 0.45595767031487905, 0.14...      0.976430
# 14           [0.770041259396549, 0.20724322599842762]      0.977411
# 15  [0.9287220427088437, 0.4155011546811405, 0.676...      0.984935
# 16  [0.9435204682930847, 0.5573309167044959, 0.469...      0.979168
# 17  [0.9366440422519026, 0.4938087312108531, 0.321...      0.976715
# 18  [0.9431553133194227, 0.5334363194866991, 0.352...      0.976685
# 19  [0.9423280845436919, 0.49190209941095064, 0.35...      0.977287
#
#     hopkins_vae  silhouette_umap  silhouette_vae  calinski_umap  calinski_vae  \
# 0      0.860745         0.368774        0.007379   13935.022315    894.482821
# 1      0.860745         0.403808        0.017195   12981.626007    993.265909
# 2      0.860745         0.362327        0.008512   10452.677863    862.163673
# 3      0.860745         0.402402        0.023537   12056.191386   1013.024335
# 4      0.860745         0.395068        0.017259   12104.445187   1001.267529
# 5      0.850167         0.361994        0.013354   18939.537783   1498.197714
# 6      0.850167         0.339779        0.011864   14154.932636   1321.606014
# 7      0.850167         0.108949       -0.033436    2922.482649    811.254896
# 8      0.850167         0.127954       -0.034314    2894.779764    824.972849
# 9      0.850167         0.119004       -0.033261    2873.860499    811.125609
# 10     0.824799         0.308996       -0.001803    7289.893201    601.120722
# 11     0.824799         0.403383        0.000485    7811.255749    628.860846
# 12     0.824799         0.271227        0.014784    2766.387197    456.037419
# 13     0.824799         0.330043       -0.009746    5011.904215    562.947459
# 14     0.824799         0.240343       -0.002334    3029.468630    455.577083
# 15     0.831036         0.450272        0.032453   14335.356019    864.109198
# 16     0.831036         0.595221        0.054972   22912.983565   1222.725121
# 17     0.831036         0.600937        0.033044   19265.194034    868.009983
# 18     0.831036         0.608905        0.032778   20178.524582    866.885063
# 19     0.831036         0.614116        0.032690   20172.223176    866.627319
#
#                                            param_umap  \
# 0   {'n_neighbors': 25, 'min_dist': 0, 'metric': '...
# 1   {'n_neighbors': 25, 'min_dist': 0, 'metric': '...
# 2   {'n_neighbors': 25, 'min_dist': 0, 'metric': '...
# 3   {'n_neighbors': 25, 'min_dist': 0, 'metric': '...
# 4   {'n_neighbors': 25, 'min_dist': 0, 'metric': '...
# 5   {'n_neighbors': 25, 'min_dist': 0, 'metric': '...
# 6   {'n_neighbors': 25, 'min_dist': 0, 'metric': '...
# 7   {'n_neighbors': 25, 'min_dist': 0, 'metric': '...
# 8   {'n_neighbors': 25, 'min_dist': 0, 'metric': '...
# 9   {'n_neighbors': 25, 'min_dist': 0, 'metric': '...
# 10  {'n_neighbors': 25, 'min_dist': 0, 'metric': '...
# 11  {'n_neighbors': 25, 'min_dist': 0, 'metric': '...
# 12  {'n_neighbors': 25, 'min_dist': 0, 'metric': '...
# 13  {'n_neighbors': 25, 'min_dist': 0, 'metric': '...
# 14  {'n_neighbors': 25, 'min_dist': 0, 'metric': '...
# 15  {'n_neighbors': 25, 'min_dist': 0, 'metric': '...
# 16  {'n_neighbors': 25, 'min_dist': 0, 'metric': '...
# 17  {'n_neighbors': 25, 'min_dist': 0, 'metric': '...
# 18  {'n_neighbors': 25, 'min_dist': 0, 'metric': '...
# 19  {'n_neighbors': 25, 'min_dist': 0, 'metric': '...
#
#                                         param_hdbscan
# 0   {'min_cluster_size_frac': 0.05, 'min_samples':...
# 1   {'min_cluster_size_frac': 0.05, 'min_samples':...
# 2   {'min_cluster_size_frac': 0.05, 'min_samples':...
# 3   {'min_cluster_size_frac': 0.05, 'min_samples':...
# 4   {'min_cluster_size_frac': 0.05, 'min_samples':...
# 5   {'min_cluster_size_frac': 0.05, 'min_samples':...
# 6   {'min_cluster_size_frac': 0.05, 'min_samples':...
# 7   {'min_cluster_size_frac': 0.05, 'min_samples':...
# 8   {'min_cluster_size_frac': 0.05, 'min_samples':...
# 9   {'min_cluster_size_frac': 0.05, 'min_samples':...
# 10  {'min_cluster_size_frac': 0.05, 'min_samples':...
# 11  {'min_cluster_size_frac': 0.05, 'min_samples':...
# 12  {'min_cluster_size_frac': 0.05, 'min_samples':...
# 13  {'min_cluster_size_frac': 0.05, 'min_samples':...
# 14  {'min_cluster_size_frac': 0.05, 'min_samples':...
# 15  {'min_cluster_size_frac': 0.05, 'min_samples':...
# 16  {'min_cluster_size_frac': 0.05, 'min_samples':...
# 17  {'min_cluster_size_frac': 0.05, 'min_samples':...
# 18  {'min_cluster_size_frac': 0.05, 'min_samples':...
# 19  {'min_cluster_size_frac': 0.05, 'min_samples':...

# %% [markdown]
# ## 3. Plot summary metrics

# %%
bird_ids = birdIDs
cmap = plt.get_cmap('tab20')
col_list = [cmap(i) for i in range(len(run_names))]
run_name_to_color = {run: col_list[i] for i, run in enumerate(run_names)}

# Setup
fig, axes = plt.subplots(1, 3, figsize=(15, 5), gridspec_kw={'width_ratios': [1, 1, 0.3]})
metrics_to_plot = ['silhouette_umap', 'calinski_umap']
width = 0.8 / len(run_names)
x = np.arange(len(bird_ids))

# Plot loop
for ax, metric in zip(axes[:2], metrics_to_plot):
    for i, run in enumerate(run_names):
        vals = [
            metrics.loc[(metrics['birdID'] == bird) & (metrics['run_name'] == run), metric].values[0]
            if not metrics[(metrics['birdID'] == bird) & (metrics['run_name'] == run)].empty else np.nan
            for bird in bird_ids
        ]
        ax.bar(x + i * width, vals, width, label=run, color=run_name_to_color[run])
    ax.set_title(metric.capitalize())
    ax.set_xticks(x + width * (len(run_names) - 1) / 2)
    ax.set_xticklabels(bird_ids)
    ax.set_ylabel(metric.capitalize())

# Legend in third panel
axes[2].axis('off')  # Hide axis
handles, labels = axes[0].get_legend_handles_labels()
axes[2].legend(handles, labels, title='run_name', loc='center')

plt.tight_layout()
plt.show()

# %%
# Combine the HDBSCAN clustering plot
# bi = 0
for bi in range(len(birdIDs)):
# for bi in range(1):
    bd = birdIDs[bi]
    # one figure for each bird
    fig, axes = plt.subplots(nrows=1, ncols=5, figsize=[14, 3.5])

    for ri in range(len(run_names)):
        rn = run_names[ri]
        fd_save = os.path.join(fd_data, bd, 'UMAPonVAE4', sylStr)
        fn_embed = os.path.join(fd_save, f'{bd}.{rn}.UMAPonVAE.embedding.csv')
        embed = pd.read_csv(fn_embed, index_col=0)

        ax = axes[ri]
        # color calls according to hdbscan labels
        col_long = sns.color_palette('hls', n_colors=max(embed['hdbscan_cluster'])+1)
        # plot embedding
        for hi in range(-1, max(embed['hdbscan_cluster'])+1):
            embed_s = embed[embed['hdbscan_cluster']==hi]
            if hi==-1:
                ax.scatter(embed_s['2umap1'], embed_s['2umap2'], s=0.3, alpha=0.25, color='#737373')
            else:
                ax.scatter(embed_s['2umap1'], embed_s['2umap2'], s=0.3, alpha=0.25, color=col_long[hi])
                # add syl label
                ax.text(np.mean(embed_s['2umap1']), np.mean(embed_s['2umap2']), hi, fontsize=12)
        sil = metrics.loc[(metrics['birdID'] == bd) & (metrics['run_name'] == rn), 'silhouette_umap'].iloc[0]
        ax.set_title(f'{rn}:{sil:.4f}', fontsize=6)
        ax.set_xlabel('UMAP axis 1', fontsize=6)
        ax.set_ylabel('UMAP axis 2', fontsize=6)
    plt.tight_layout()
    # save plot
    fn_fig = os.path.join(fd_save, f'{bd}.HDBSCANcomb.pdf')
    fig.savefig(fn_fig)
